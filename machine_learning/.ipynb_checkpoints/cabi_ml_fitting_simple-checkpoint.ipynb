# %% [markdown]
# # CaBi ML fitting sandbox

# %% [markdown]
# ## 0. Data load, shaping, and split
# * Read in data from AWS
#   * Check for high pairwise correlation
# * Encode time variable (day_of_year) as cyclical
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Specify feature and target columns

# %%
# Read in data from AWS

from util_functions import *
import numpy as np
import pandas as pd
import time
start_time = time.perf_counter()

set_env_path()
conn, cur = aws_connect()

# fullquery contains all of the variables within consideration

fullquery = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
daylight_hours,
apparenttemperaturehigh,
apparenttemperaturelow,
cloudcover,
dewpoint,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
dc_bike_event,
dc_pop,
cabi_bikes_avail,
cabi_stations_alx,
cabi_stations_arl,
cabi_stations_ffx,
cabi_stations_mcn,
cabi_stations_mcs,
cabi_stations_wdc,
cabi_docks_alx,
cabi_docks_arl,
cabi_docks_ffx,
cabi_docks_mcn,
cabi_docks_mcs,
cabi_docks_wdc,
cabi_stations_tot,
cabi_docks_tot,
cabi_dur_empty_wdc,
cabi_dur_full_wdc,
cabi_dur_empty_arl,
cabi_dur_full_arl,
cabi_dur_full_alx,
cabi_dur_empty_alx,
cabi_dur_empty_mcs,
cabi_dur_full_mcs,
cabi_dur_full_mcn,
cabi_dur_empty_mcn,
cabi_dur_full_ffx,
cabi_dur_empty_ffx,
cabi_dur_empty_tot,
cabi_dur_full_tot,
cabi_active_members_day_key,
cabi_active_members_monthly,
cabi_active_members_annual,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""

query = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
daylight_hours,
apparenttemperaturehigh,
cloudcover,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
dc_bike_event,
dc_pop,
cabi_dur_empty_arl,
cabi_dur_full_arl,
cabi_dur_full_alx,
cabi_dur_empty_alx,
cabi_dur_empty_mcs,
cabi_dur_full_mcs,
cabi_dur_full_mcn,
cabi_dur_empty_mcn,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""

pd.options.display.max_rows = None
pd.options.display.max_columns = None

df = pd.read_sql(query, con=conn)

# Setting date to index for easier splitting
df.set_index(df.date, drop=True, inplace=True)
df.index = pd.to_datetime(df.index)

print("We have {} instances and {} features".format(*df.shape))
# Out:
# We have 2780 instances and 28 features

# %%
# Summary statistics

df.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                count        mean         std         min  \
# day_of_year                   2780.0     182.697     107.702       1.000
# daylight_hours                2780.0      12.077       2.021       9.000
# apparenttemperaturehigh       2780.0      64.306      20.594       2.240
# cloudcover                    2780.0       0.340       0.244       0.000
# humidity                      2780.0       0.669       0.137       0.210
# precipaccumulation            2780.0       0.045       0.527       0.000
# precipintensitymax            2780.0       0.029       0.072       0.000
# precipprobability             2780.0       0.282       0.373       0.000
# rain                          2780.0       0.454       0.498       0.000
# snow                          2780.0       0.040       0.196       0.000
# visibility                    2780.0       9.306       1.130       1.130
# windspeed                     2780.0       5.379       3.170       0.030
# us_holiday                    2780.0       0.031       0.173       0.000
# nats_single                   2780.0       0.200       0.400       0.000
# nats_double                   2780.0       0.006       0.078       0.000
# dc_bike_event                 2780.0       0.009       0.094       0.000
# dc_pop                        2780.0  662465.171   26420.230  607733.153
# cabi_dur_empty_arl            2780.0  103321.117  132383.807       0.000
# cabi_dur_full_arl             2780.0   43502.125   48157.214       0.000
# cabi_dur_full_alx             2780.0   10897.354   23990.773       0.000
# cabi_dur_empty_alx            2780.0    6092.551   15606.603       0.000
# cabi_dur_empty_mcs            2780.0   13949.235   40894.944       0.000
# cabi_dur_full_mcs             2780.0    2318.766    8130.878       0.000
# cabi_dur_full_mcn             2780.0    1401.324   10546.828       0.000
# cabi_dur_empty_mcn            2780.0    2644.020   15048.476       0.000
# cabi_trips_wdc_to_wdc         2780.0    6375.501    3185.075       0.000
# cabi_trips_wdc_to_wdc_casual  2780.0    1395.860    1339.656       0.000
#
#                                      50%          max
# day_of_year                      182.000      366.000
# daylight_hours                    12.000       15.000
# apparenttemperaturehigh           65.890      113.670
# cloudcover                         0.270        1.000
# humidity                           0.670        0.970
# precipaccumulation                 0.000       21.427
# precipintensitymax                 0.001        1.185
# precipprobability                  0.000        1.000
# rain                               0.000        1.000
# snow                               0.000        1.000
# visibility                         9.790       10.000
# windspeed                          4.850       25.460
# us_holiday                         0.000        1.000
# nats_single                        0.000        1.000
# nats_double                        0.000        1.000
# dc_bike_event                      0.000        1.000
# dc_pop                        665296.583   702021.562
# cabi_dur_empty_arl             54818.500  1170040.000
# cabi_dur_full_arl              31039.500   630049.000
# cabi_dur_full_alx                  0.000   311058.000
# cabi_dur_empty_alx                 0.000   388080.000
# cabi_dur_empty_mcs                 0.000   808844.000
# cabi_dur_full_mcs                  0.000   221578.000
# cabi_dur_full_mcn                  0.000   272821.000
# cabi_dur_empty_mcn                 0.000   324429.000
# cabi_trips_wdc_to_wdc           6240.000    16608.000
# cabi_trips_wdc_to_wdc_casual    1000.000     9130.000

# %%
def print_highly_correlated(df, features, threshold=0.75):
    """ 
    Prints highly correlated feature pairs in df.
    """
    corr_df = df[features].corr()
    # Select pairs above threshold
    correlated_features = np.where(np.abs(corr_df) > threshold)
    # Avoid duplication
    correlated_features = [(corr_df.iloc[x,y], x, y) for x, y in zip(*correlated_features) if x != y and x < y]
    # Sort by abs(correlation)
    s_corr_list = sorted(correlated_features, key=lambda x: -abs(x[0]))
    print("There are {} feature pairs with pairwise correlation above {}".format(len(s_corr_list), threshold))
    for v, i, j in s_corr_list:
        cols = df[features].columns
        print("{} and {} = {:0.3f}".format(corr_df.index[i], corr_df.columns[j], v))
        
print_highly_correlated(df, df.columns)
# Out:
# There are 1 feature pairs with pairwise correlation above 0.75
# cabi_trips_wdc_to_wdc and cabi_trips_wdc_to_wdc_casual = 0.770

# %%
# Encode day_of_year as cyclical
df['sin_day_of_year'] = np.sin(2*np.pi*df.day_of_year/365)
df['cos_day_of_year'] = np.cos(2*np.pi*df.day_of_year/365)

# %%
# %matplotlib inline

df.sample(100).plot.scatter('sin_day_of_year','cos_day_of_year').set_aspect('equal')

# %% [markdown]
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Training dates = 2013-01-01 to 2016-12-31
#   * Test dates = 2017-01-01 to 2017-09-08
#   * New data (coincides with beginning of dockless pilot) = 2017-09-09 to present

# %%
# Train test split
# This can be tweaked, but we use 5-fold cross-validation to pick the model so that shouldn't change

train = df.loc['2013-01-01':'2016-12-31']
test = df.loc['2017-01-01':'2017-09-08']
print(train.shape, test.shape)

tr = train.shape[0]
te = test.shape[0]
trpct = tr/(tr+te)
tepct = te/(tr+te)

print("{:0.3f} percent of the data is in the training set and {:0.3f} percent is in the test set".format(trpct, tepct))
# Out:
# (1461, 30) (251, 30)
# 0.853 percent of the data is in the training set and 0.147 percent is in the test set

# %%
# Specify columns to keep and drop for X and y
drop_cols = ['date', 'day_of_year']
y_cols = ['cabi_trips_wdc_to_wdc', 'cabi_trips_wdc_to_wdc_casual']

feature_cols = [col for col in df.columns if (col not in y_cols) & (col not in drop_cols)]

# X y split
Xtrain_raw = train[feature_cols]

# Our target variable here is all DC to DC trips
ytrain = train[y_cols[0]]
Xtest_raw = test[feature_cols]
ytest = test[y_cols[0]]
print(Xtrain_raw.shape, ytrain.shape, Xtest_raw.shape, ytest.shape)
# Out:
# (1461, 26) (1461,) (251, 26) (251,)

# %% [markdown]
# ### 1. Preprocessing
#
# We want to use PolynomialFeatures and StandardScaler in a Pipeline, but we only want to scale continuous features.
#
# Here, I do the polynomial transformation first and then feed it through a pipeline because I wasn't able to get it all working in one pipeline.
#
# * Use PolynomialFeatures to create quadratic and interaction terms
#   * Convert back to DataFrame
#   * Drop redundant variables
# * Use Pipeline and FeatureUnion to selectively scale/ignore certain variables
# * Fit and transform using pipeline to get final Xtrain and Xtest

# %%
# Imports and custom classes
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin

class Columns(BaseEstimator, TransformerMixin):
    """ 
    This is a custom transformer for splitting the data into subsets for FeatureUnion.
    """
    def __init__(self, names=None):
        self.names = names

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X):
        return X[self.names]

# %%
# Use PolynomialFeatures to create quadratic and interaction terms
# Should ultimately be part of a Pipeline, but I had issues because 
# PF returns an array and Columns requires a df

pf = PolynomialFeatures(2, include_bias=False)

Xtrain_pf_array = pf.fit_transform(Xtrain_raw)
Xtest_pf_array = pf.transform(Xtest_raw)

# Get feature names 
Xtrain_cols = pf.get_feature_names(Xtrain_raw.columns)

# Convert arrays to dfs with the new pf column names
Xtrain_pf = pd.DataFrame(Xtrain_pf_array, columns=Xtrain_cols)
Xtest_pf = pd.DataFrame(Xtest_pf_array, columns=Xtrain_cols)

print(Xtrain_pf.shape, Xtest_pf.shape)
# Out:
# (1461, 377) (251, 377)

# %%
# A lot of these variables are redundant, especially squared dummy variables
# All of these variables listed next are 'binary' but only some are meaningful

bin_vars = [col for col in Xtrain_pf.columns if Xtrain_pf[col].nunique() == 2]
bin_vars
# Out:
# ['rain',
#  'snow',
#  'us_holiday',
#  'nats_single',
#  'nats_double',
#  'dc_bike_event',
#  'rain^2',
#  'rain us_holiday',
#  'rain nats_single',
#  'rain nats_double',
#  'rain dc_bike_event',
#  'snow^2',
#  'snow us_holiday',
#  'us_holiday^2',
#  'us_holiday nats_single',
#  'us_holiday cabi_dur_full_mcn',
#  'nats_single^2',
#  'nats_single dc_bike_event',
#  'nats_double^2',
#  'dc_bike_event^2',
#  'dc_bike_event cabi_dur_full_mcn']

# %%
# Dropping squared dummies and nonsensical interaction terms
# This part can be expanded. There's a lot of noise after PF

to_drop = [
    'rain^2', 'snow^2', 'us_holiday^2', 'nats_single^2', 'nats_double^2', 
    'dc_bike_event^2', 'sin_day_of_year^2', 'cos_day_of_year^2',
    'sin_day_of_year cos_day_of_year'
]

Xtrain_pf2 = Xtrain_pf.drop(labels=to_drop, axis=1)
Xtest_pf2 = Xtest_pf.drop(labels=to_drop, axis=1)

print(Xtrain_pf2.shape, Xtest_pf2.shape)
# Out:
# (1461, 368) (251, 368)

# %%
# Defining binary and continuous variables
# We have normal 0,1 binary variables, binary variables outside 0,1 that were created by PF, and continuous variables
# We want to ignore the 0,1s, MinMaxScale the non 0,1 binary variables, and StandardScale the continuous variables

binary = ['rain', 'snow', 'us_holiday', 'nats_single', 'nats_double', 'dc_bike_event']
binarypf = [col for col in Xtrain_pf2.columns if (Xtrain_pf2[col].nunique() == 2) & (col not in binary)]
cont = [col for col in Xtrain_pf2.columns if (col not in binary) & (col not in binarypf)]

# FeatureUnion in our pipeline shifts the ordering of the variables so we need to save the ordering here
cols = binary + binarypf + cont

pipeline = Pipeline([
    ('features', FeatureUnion([
        ('binary', Pipeline([
            ('bincols', Columns(names=binary))
        ])),
        ('binarypf', Pipeline([
            ('binpfcols', Columns(names=binarypf)),
            ('minmax', MinMaxScaler())
        ])),
        ('continuous', Pipeline([
            ('contcols', Columns(names=cont)),
            ('scaler', StandardScaler())
        ]))
    ]))   
])

# %%
# Fit and transform to create our final Xtrain and Xtest

pipeline.fit(Xtrain_pf2)
Xtrain_scaled = pipeline.transform(Xtrain_pf2)
Xtest_scaled = pipeline.transform(Xtest_pf2)

# Put everything back into dfs
Xtrain = pd.DataFrame(Xtrain_scaled, columns=cols)
Xtest = pd.DataFrame(Xtest_scaled, columns=cols)
print(Xtrain.shape, Xtest.shape)
# Out:
# (1461, 368) (251, 368)

# %%
Xtrain.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                              count   mean    std     min  \
# rain                                        1461.0  0.449  0.498   0.000
# snow                                        1461.0  0.047  0.211   0.000
# us_holiday                                  1461.0  0.029  0.167   0.000
# nats_single                                 1461.0  0.211  0.408   0.000
# nats_double                                 1461.0  0.005  0.074   0.000
# dc_bike_event                               1461.0  0.012  0.110   0.000
# rain us_holiday                             1461.0  0.008  0.086   0.000
# rain nats_single                            1461.0  0.107  0.310   0.000
# rain nats_double                            1461.0  0.003  0.058   0.000
# rain dc_bike_event                          1461.0  0.007  0.082   0.000
# snow us_holiday                             1461.0  0.002  0.045   0.000
# us_holiday nats_single                      1461.0  0.006  0.078   0.000
# us_holiday cabi_dur_full_mcn                1461.0  0.001  0.026   0.000
# nats_single dc_bike_event                   1461.0  0.002  0.045   0.000
# dc_bike_event cabi_dur_full_mcn             1461.0  0.001  0.026   0.000
# daylight_hours                              1461.0 -0.000  1.000  -1.565
# apparenttemperaturehigh                     1461.0  0.000  1.000  -2.975
# cloudcover                                  1461.0  0.000  1.000  -1.296
# humidity                                    1461.0 -0.000  1.000  -2.774
# precipaccumulation                          1461.0  0.000  1.000  -0.093
# precipintensitymax                          1461.0  0.000  1.000  -0.402
# precipprobability                           1461.0  0.000  1.000  -0.754
# visibility                                  1461.0  0.000  1.000  -6.909
# windspeed                                   1461.0  0.000  1.000  -1.686
# dc_pop                                      1461.0  0.000  1.000  -1.851
# cabi_dur_empty_arl                          1461.0 -0.000  1.000  -1.032
# cabi_dur_full_arl                           1461.0 -0.000  1.000  -1.046
# cabi_dur_full_alx                           1461.0  0.000  1.000  -0.646
# cabi_dur_empty_alx                          1461.0  0.000  1.000  -0.529
# cabi_dur_empty_mcs                          1461.0  0.000  1.000  -0.503
# cabi_dur_full_mcs                           1461.0  0.000  1.000  -0.265
# cabi_dur_full_mcn                           1461.0 -0.000  1.000  -0.078
# cabi_dur_empty_mcn                          1461.0 -0.000  1.000  -0.144
# sin_day_of_year                             1461.0 -0.000  1.000  -1.415
# cos_day_of_year                             1461.0  0.000  1.000  -1.415
# daylight_hours^2                            1461.0  0.000  1.000  -1.449
# daylight_hours apparenttemperaturehigh      1461.0  0.000  1.000  -2.204
# daylight_hours cloudcover                   1461.0  0.000  1.000  -1.313
# daylight_hours humidity                     1461.0  0.000  1.000  -2.299
# daylight_hours precipaccumulation           1461.0 -0.000  1.000  -0.095
# daylight_hours precipintensitymax           1461.0  0.000  1.000  -0.386
# daylight_hours precipprobability            1461.0 -0.000  1.000  -0.750
# daylight_hours rain                         1461.0 -0.000  1.000  -0.882
# daylight_hours snow                         1461.0  0.000  1.000  -0.220
# daylight_hours visibility                   1461.0 -0.000  1.000  -4.152
# daylight_hours windspeed                    1461.0 -0.000  1.000  -1.708
# daylight_hours us_holiday                   1461.0  0.000  1.000  -0.168
# daylight_hours nats_single                  1461.0  0.000  1.000  -0.515
# daylight_hours nats_double                  1461.0  0.000  1.000  -0.074
# daylight_hours dc_bike_event                1461.0  0.000  1.000  -0.110
# daylight_hours dc_pop                       1461.0  0.000  1.000  -1.719
# daylight_hours cabi_dur_empty_arl           1461.0  0.000  1.000  -0.999
# daylight_hours cabi_dur_full_arl            1461.0  0.000  1.000  -0.973
# daylight_hours cabi_dur_full_alx            1461.0 -0.000  1.000  -0.620
# daylight_hours cabi_dur_empty_alx           1461.0 -0.000  1.000  -0.517
# daylight_hours cabi_dur_empty_mcs           1461.0  0.000  1.000  -0.493
# daylight_hours cabi_dur_full_mcs            1461.0  0.000  1.000  -0.238
# daylight_hours cabi_dur_full_mcn            1461.0  0.000  1.000  -0.072
# daylight_hours cabi_dur_empty_mcn           1461.0 -0.000  1.000  -0.132
# daylight_hours sin_day_of_year              1461.0 -0.000  1.000  -1.517
# daylight_hours cos_day_of_year              1461.0 -0.000  1.000  -1.572
# apparenttemperaturehigh^2                   1461.0 -0.000  1.000  -1.780
# apparenttemperaturehigh cloudcover          1461.0 -0.000  1.000  -1.387
# apparenttemperaturehigh humidity            1461.0 -0.000  1.000  -2.429
# apparenttemperaturehigh precipaccumulation  1461.0  0.000  1.000  -0.132
# apparenttemperaturehigh precipintensitymax  1461.0 -0.000  1.000  -0.363
# apparenttemperaturehigh precipprobability   1461.0 -0.000  1.000  -0.723
# apparenttemperaturehigh rain                1461.0  0.000  1.000  -0.849
# apparenttemperaturehigh snow                1461.0 -0.000  1.000  -0.209
# apparenttemperaturehigh visibility          1461.0 -0.000  1.000  -2.711
# apparenttemperaturehigh windspeed           1461.0 -0.000  1.000  -1.677
# apparenttemperaturehigh us_holiday          1461.0 -0.000  1.000  -0.161
# apparenttemperaturehigh nats_single         1461.0 -0.000  1.000  -0.510
# apparenttemperaturehigh nats_double         1461.0 -0.000  1.000  -0.074
# apparenttemperaturehigh dc_bike_event       1461.0  0.000  1.000  -0.109
# apparenttemperaturehigh dc_pop              1461.0  0.000  1.000  -2.953
# apparenttemperaturehigh cabi_dur_empty_arl  1461.0  0.000  1.000  -0.960
# apparenttemperaturehigh cabi_dur_full_arl   1461.0  0.000  1.000  -0.944
# apparenttemperaturehigh cabi_dur_full_alx   1461.0  0.000  1.000  -0.614
# apparenttemperaturehigh cabi_dur_empty_alx  1461.0  0.000  1.000  -0.504
# apparenttemperaturehigh cabi_dur_empty_mcs  1461.0  0.000  1.000  -0.489
# apparenttemperaturehigh cabi_dur_full_mcs   1461.0 -0.000  1.000  -0.272
# apparenttemperaturehigh cabi_dur_full_mcn   1461.0 -0.000  1.000  -0.083
# apparenttemperaturehigh cabi_dur_empty_mcn  1461.0 -0.000  1.000  -0.152
# apparenttemperaturehigh sin_day_of_year     1461.0 -0.000  1.000  -1.862
# apparenttemperaturehigh cos_day_of_year     1461.0  0.000  1.000  -1.924
# cloudcover^2                                1461.0  0.000  1.000  -0.632
# cloudcover humidity                         1461.0 -0.000  1.000  -1.070
# cloudcover precipaccumulation               1461.0 -0.000  1.000  -0.101
# cloudcover precipintensitymax               1461.0  0.000  1.000  -0.383
# cloudcover precipprobability                1461.0 -0.000  1.000  -0.582
# cloudcover rain                             1461.0 -0.000  1.000  -0.697
# cloudcover snow                             1461.0 -0.000  1.000  -0.171
# cloudcover visibility                       1461.0 -0.000  1.000  -1.480
# cloudcover windspeed                        1461.0 -0.000  1.000  -0.941
# cloudcover us_holiday                       1461.0  0.000  1.000  -0.134
# cloudcover nats_single                      1461.0  0.000  1.000  -0.409
# cloudcover nats_double                      1461.0  0.000  1.000  -0.055
# cloudcover dc_bike_event                    1461.0  0.000  1.000  -0.095
# cloudcover dc_pop                           1461.0 -0.000  1.000  -1.305
# cloudcover cabi_dur_empty_arl               1461.0  0.000  1.000  -0.889
# cloudcover cabi_dur_full_arl                1461.0  0.000  1.000  -0.851
# cloudcover cabi_dur_full_alx                1461.0  0.000  1.000  -0.546
# cloudcover cabi_dur_empty_alx               1461.0  0.000  1.000  -0.458
# cloudcover cabi_dur_empty_mcs               1461.0 -0.000  1.000  -0.449
# cloudcover cabi_dur_full_mcs                1461.0 -0.000  1.000  -0.228
# cloudcover cabi_dur_full_mcn                1461.0 -0.000  1.000  -0.071
# cloudcover cabi_dur_empty_mcn               1461.0 -0.000  1.000  -0.121
# cloudcover sin_day_of_year                  1461.0  0.000  1.000  -4.022
# cloudcover cos_day_of_year                  1461.0  0.000  1.000  -3.377
# humidity^2                                  1461.0  0.000  1.000  -2.107
# humidity precipaccumulation                 1461.0  0.000  1.000  -0.112
# humidity precipintensitymax                 1461.0  0.000  1.000  -0.391
# humidity precipprobability                  1461.0  0.000  1.000  -0.721
# humidity rain                               1461.0  0.000  1.000  -0.881
# humidity snow                               1461.0 -0.000  1.000  -0.215
# humidity visibility                         1461.0 -0.000  1.000  -4.733
# humidity windspeed                          1461.0  0.000  1.000  -1.818
# humidity us_holiday                         1461.0  0.000  1.000  -0.168
# humidity nats_single                        1461.0  0.000  1.000  -0.507
# humidity nats_double                        1461.0  0.000  1.000  -0.073
# humidity dc_bike_event                      1461.0  0.000  1.000  -0.110
# humidity dc_pop                             1461.0  0.000  1.000  -2.811
# humidity cabi_dur_empty_arl                 1461.0 -0.000  1.000  -1.029
# humidity cabi_dur_full_arl                  1461.0  0.000  1.000  -1.044
# humidity cabi_dur_full_alx                  1461.0  0.000  1.000  -0.646
# humidity cabi_dur_empty_alx                 1461.0 -0.000  1.000  -0.524
# humidity cabi_dur_empty_mcs                 1461.0  0.000  1.000  -0.500
# humidity cabi_dur_full_mcs                  1461.0 -0.000  1.000  -0.308
# humidity cabi_dur_full_mcn                  1461.0 -0.000  1.000  -0.094
# humidity cabi_dur_empty_mcn                 1461.0 -0.000  1.000  -0.169
# humidity sin_day_of_year                    1461.0  0.000  1.000  -1.964
# humidity cos_day_of_year                    1461.0  0.000  1.000  -1.826
# precipaccumulation^2                        1461.0  0.000  1.000  -0.038
# precipaccumulation precipintensitymax       1461.0  0.000  1.000  -0.047
# precipaccumulation precipprobability        1461.0 -0.000  1.000  -0.116
# precipaccumulation rain                     1461.0  0.000  0.000   0.000
# precipaccumulation snow                     1461.0  0.000  1.000  -0.093
# precipaccumulation visibility               1461.0  0.000  1.000  -0.075
# precipaccumulation windspeed                1461.0  0.000  1.000  -0.058
# precipaccumulation us_holiday               1461.0 -0.000  1.000  -0.037
# precipaccumulation nats_single              1461.0  0.000  0.000   0.000
# precipaccumulation nats_double              1461.0  0.000  0.000   0.000
# precipaccumulation dc_bike_event            1461.0  0.000  0.000   0.000
# precipaccumulation dc_pop                   1461.0  0.000  1.000  -0.092
# precipaccumulation cabi_dur_empty_arl       1461.0  0.000  1.000  -0.076
# precipaccumulation cabi_dur_full_arl        1461.0 -0.000  1.000  -0.058
# precipaccumulation cabi_dur_full_alx        1461.0 -0.000  1.000  -0.053
# precipaccumulation cabi_dur_empty_alx       1461.0  0.000  1.000  -0.032
# precipaccumulation cabi_dur_empty_mcs       1461.0 -0.000  1.000  -0.043
# precipaccumulation cabi_dur_full_mcs        1461.0 -0.000  1.000  -0.031
# precipaccumulation cabi_dur_full_mcn        1461.0  0.000  1.000  -0.026
# precipaccumulation cabi_dur_empty_mcn       1461.0 -0.000  1.000  -0.038
# precipaccumulation sin_day_of_year          1461.0 -0.000  1.000  -2.986
# precipaccumulation cos_day_of_year          1461.0  0.000  1.000  -0.092
# precipintensitymax^2                        1461.0 -0.000  1.000  -0.152
# precipintensitymax precipprobability        1461.0 -0.000  1.000  -0.385
# precipintensitymax rain                     1461.0  0.000  1.000  -0.385
# precipintensitymax snow                     1461.0 -0.000  1.000  -0.121
# precipintensitymax visibility               1461.0  0.000  1.000  -0.395
# precipintensitymax windspeed                1461.0  0.000  1.000  -0.372
# precipintensitymax us_holiday               1461.0  0.000  1.000  -0.073
# precipintensitymax nats_single              1461.0 -0.000  1.000  -0.159
# precipintensitymax nats_double              1461.0  0.000  1.000  -0.043
# precipintensitymax dc_bike_event            1461.0 -0.000  1.000  -0.049
# precipintensitymax dc_pop                   1461.0  0.000  1.000  -0.403
# precipintensitymax cabi_dur_empty_arl       1461.0  0.000  1.000  -0.288
# precipintensitymax cabi_dur_full_arl        1461.0  0.000  1.000  -0.267
# precipintensitymax cabi_dur_full_alx        1461.0  0.000  1.000  -0.190
# precipintensitymax cabi_dur_empty_alx       1461.0  0.000  1.000  -0.128
# precipintensitymax cabi_dur_empty_mcs       1461.0 -0.000  1.000  -0.182
# precipintensitymax cabi_dur_full_mcs        1461.0  0.000  1.000  -0.130
# precipintensitymax cabi_dur_full_mcn        1461.0 -0.000  1.000  -0.073
# precipintensitymax cabi_dur_empty_mcn       1461.0 -0.000  1.000  -0.080
# precipintensitymax sin_day_of_year          1461.0 -0.000  1.000 -15.316
# precipintensitymax cos_day_of_year          1461.0  0.000  1.000 -11.966
# precipprobability^2                         1461.0 -0.000  1.000  -0.635
# precipprobability rain                      1461.0  0.000  1.000  -0.702
# precipprobability snow                      1461.0  0.000  1.000  -0.183
# precipprobability visibility                1461.0 -0.000  1.000  -0.759
# precipprobability windspeed                 1461.0 -0.000  1.000  -0.621
# precipprobability us_holiday                1461.0  0.000  1.000  -0.089
# precipprobability nats_single               1461.0 -0.000  1.000  -0.291
# precipprobability nats_double               1461.0 -0.000  1.000  -0.052
# precipprobability dc_bike_event             1461.0 -0.000  1.000  -0.076
# precipprobability dc_pop                    1461.0 -0.000  1.000  -0.754
# precipprobability cabi_dur_empty_arl        1461.0 -0.000  1.000  -0.492
# precipprobability cabi_dur_full_arl         1461.0 -0.000  1.000  -0.509
# precipprobability cabi_dur_full_alx         1461.0 -0.000  1.000  -0.322
# precipprobability cabi_dur_empty_alx        1461.0 -0.000  1.000  -0.293
# precipprobability cabi_dur_empty_mcs        1461.0  0.000  1.000  -0.275
# precipprobability cabi_dur_full_mcs         1461.0  0.000  1.000  -0.191
# precipprobability cabi_dur_full_mcn         1461.0  0.000  1.000  -0.073
# precipprobability cabi_dur_empty_mcn        1461.0  0.000  1.000  -0.115
# precipprobability sin_day_of_year           1461.0  0.000  1.000  -3.230
# precipprobability cos_day_of_year           1461.0 -0.000  1.000  -2.907
# rain snow                                   1461.0  0.000  0.000   0.000
# rain visibility                             1461.0  0.000  1.000  -0.884
# rain windspeed                              1461.0  0.000  1.000  -0.710
# rain dc_pop                                 1461.0 -0.000  1.000  -0.902
# rain cabi_dur_empty_arl                     1461.0  0.000  1.000  -0.560
# rain cabi_dur_full_arl                      1461.0 -0.000  1.000  -0.540
# rain cabi_dur_full_alx                      1461.0 -0.000  1.000  -0.354
# rain cabi_dur_empty_alx                     1461.0  0.000  1.000  -0.324
# rain cabi_dur_empty_mcs                     1461.0 -0.000  1.000  -0.290
# rain cabi_dur_full_mcs                      1461.0 -0.000  1.000  -0.148
# rain cabi_dur_full_mcn                      1461.0  0.000  1.000  -0.056
# rain cabi_dur_empty_mcn                     1461.0 -0.000  1.000  -0.084
# rain sin_day_of_year                        1461.0 -0.000  1.000  -2.182
# rain cos_day_of_year                        1461.0  0.000  1.000  -1.968
# snow visibility                             1461.0  0.000  1.000  -0.215
# snow windspeed                              1461.0  0.000  1.000  -0.185
# snow nats_single                            1461.0  0.000  0.000   0.000
# snow nats_double                            1461.0  0.000  0.000   0.000
# snow dc_bike_event                          1461.0  0.000  0.000   0.000
# snow dc_pop                                 1461.0 -0.000  1.000  -0.221
# snow cabi_dur_empty_arl                     1461.0  0.000  1.000  -0.094
# snow cabi_dur_full_arl                      1461.0  0.000  1.000  -0.126
# snow cabi_dur_full_alx                      1461.0  0.000  1.000  -0.058
# snow cabi_dur_empty_alx                     1461.0 -0.000  1.000  -0.035
# snow cabi_dur_empty_mcs                     1461.0 -0.000  1.000  -0.054
# snow cabi_dur_full_mcs                      1461.0 -0.000  1.000  -0.039
# snow cabi_dur_full_mcn                      1461.0  0.000  1.000  -0.029
# snow cabi_dur_empty_mcn                     1461.0 -0.000  1.000  -0.054
# snow sin_day_of_year                        1461.0 -0.000  1.000  -5.222
# snow cos_day_of_year                        1461.0  0.000  1.000  -0.212
# visibility^2                                1461.0  0.000  1.000  -4.693
# visibility windspeed                        1461.0 -0.000  1.000  -1.605
# visibility us_holiday                       1461.0  0.000  1.000  -0.170
# visibility nats_single                      1461.0  0.000  1.000  -0.515
# visibility nats_double                      1461.0  0.000  1.000  -0.074
# visibility dc_bike_event                    1461.0 -0.000  1.000  -0.111
# visibility dc_pop                           1461.0  0.000  1.000  -6.841
# visibility cabi_dur_empty_arl               1461.0  0.000  1.000  -1.010
# visibility cabi_dur_full_arl                1461.0 -0.000  1.000  -1.020
# visibility cabi_dur_full_alx                1461.0 -0.000  1.000  -0.635
# visibility cabi_dur_empty_alx               1461.0  0.000  1.000  -0.524
# visibility cabi_dur_empty_mcs               1461.0  0.000  1.000  -0.498
# visibility cabi_dur_full_mcs                1461.0 -0.000  1.000  -0.257
# visibility cabi_dur_full_mcn                1461.0  0.000  1.000  -0.076
# visibility cabi_dur_empty_mcn               1461.0  0.000  1.000  -0.142
# visibility sin_day_of_year                  1461.0  0.000  1.000  -1.490
# visibility cos_day_of_year                  1461.0 -0.000  1.000  -1.498
# windspeed^2                                 1461.0 -0.000  1.000  -0.840
# windspeed us_holiday                        1461.0  0.000  1.000  -0.144
# windspeed nats_single                       1461.0  0.000  1.000  -0.452
# windspeed nats_double                       1461.0  0.000  1.000  -0.068
# windspeed dc_bike_event                     1461.0  0.000  1.000  -0.100
# windspeed dc_pop                            1461.0  0.000  1.000  -1.687
# windspeed cabi_dur_empty_arl                1461.0  0.000  1.000  -0.830
# windspeed cabi_dur_full_arl                 1461.0  0.000  1.000  -0.705
# windspeed cabi_dur_full_alx                 1461.0  0.000  1.000  -0.493
# windspeed cabi_dur_empty_alx                1461.0  0.000  1.000  -0.416
# windspeed cabi_dur_empty_mcs                1461.0  0.000  1.000  -0.385
# windspeed cabi_dur_full_mcs                 1461.0 -0.000  1.000  -0.141
# windspeed cabi_dur_full_mcn                 1461.0 -0.000  1.000  -0.048
# windspeed cabi_dur_empty_mcn                1461.0  0.000  1.000  -0.085
# windspeed sin_day_of_year                   1461.0 -0.000  1.000  -3.529
# windspeed cos_day_of_year                   1461.0  0.000  1.000  -2.769
# us_holiday nats_double                      1461.0  0.000  0.000   0.000
# us_holiday dc_bike_event                    1461.0  0.000  0.000   0.000
# us_holiday dc_pop                           1461.0  0.000  1.000  -0.172
# us_holiday cabi_dur_empty_arl               1461.0  0.000  1.000  -0.107
# us_holiday cabi_dur_full_arl                1461.0  0.000  1.000  -0.114
# us_holiday cabi_dur_full_alx                1461.0  0.000  1.000  -0.090
# us_holiday cabi_dur_empty_alx               1461.0  0.000  1.000  -0.074
# us_holiday cabi_dur_empty_mcs               1461.0  0.000  1.000  -0.072
# us_holiday cabi_dur_full_mcs                1461.0  0.000  1.000  -0.054
# us_holiday cabi_dur_empty_mcn               1461.0  0.000  1.000  -0.026
# us_holiday sin_day_of_year                  1461.0 -0.000  1.000  -9.846
# us_holiday cos_day_of_year                  1461.0  0.000  1.000  -7.361
# nats_single nats_double                     1461.0  0.000  0.000   0.000
# nats_single dc_pop                          1461.0 -0.000  1.000  -0.517
# nats_single cabi_dur_empty_arl              1461.0 -0.000  1.000  -0.428
# nats_single cabi_dur_full_arl               1461.0  0.000  1.000  -0.408
# nats_single cabi_dur_full_alx               1461.0  0.000  1.000  -0.304
# nats_single cabi_dur_empty_alx              1461.0  0.000  1.000  -0.280
# nats_single cabi_dur_empty_mcs              1461.0  0.000  1.000  -0.269
# nats_single cabi_dur_full_mcs               1461.0 -0.000  1.000  -0.176
# nats_single cabi_dur_full_mcn               1461.0 -0.000  1.000  -0.069
# nats_single cabi_dur_empty_mcn              1461.0  0.000  1.000  -0.122
# nats_single sin_day_of_year                 1461.0  0.000  1.000  -3.048
# nats_single cos_day_of_year                 1461.0 -0.000  1.000  -2.950
# nats_double dc_bike_event                   1461.0  0.000  0.000   0.000
# nats_double dc_pop                          1461.0 -0.000  1.000  -0.074
# nats_double cabi_dur_empty_arl              1461.0  0.000  1.000  -0.069
# nats_double cabi_dur_full_arl               1461.0 -0.000  1.000  -0.063
# nats_double cabi_dur_full_alx               1461.0  0.000  1.000  -0.056
# nats_double cabi_dur_empty_alx              1461.0  0.000  1.000  -0.040
# nats_double cabi_dur_empty_mcs              1461.0 -0.000  1.000  -0.037
# nats_double cabi_dur_full_mcs               1461.0 -0.000  1.000  -0.036
# nats_double cabi_dur_full_mcn               1461.0  0.000  0.000   0.000
# nats_double cabi_dur_empty_mcn              1461.0  0.000  0.000   0.000
# nats_double sin_day_of_year                 1461.0  0.000  1.000 -17.039
# nats_double cos_day_of_year                 1461.0  0.000  1.000 -20.359
# dc_bike_event dc_pop                        1461.0 -0.000  1.000  -0.112
# dc_bike_event cabi_dur_empty_arl            1461.0 -0.000  1.000  -0.083
# dc_bike_event cabi_dur_full_arl             1461.0 -0.000  1.000  -0.070
# dc_bike_event cabi_dur_full_alx             1461.0  0.000  1.000  -0.076
# dc_bike_event cabi_dur_empty_alx            1461.0  0.000  1.000  -0.066
# dc_bike_event cabi_dur_empty_mcs            1461.0 -0.000  1.000  -0.061
# dc_bike_event cabi_dur_full_mcs             1461.0 -0.000  1.000  -0.040
# dc_bike_event cabi_dur_empty_mcn            1461.0 -0.000  1.000  -0.036
# dc_bike_event sin_day_of_year               1461.0  0.000  1.000 -11.723
# dc_bike_event cos_day_of_year               1461.0 -0.000  1.000 -11.313
# dc_pop^2                                    1461.0  0.000  1.000  -1.831
# dc_pop cabi_dur_empty_arl                   1461.0  0.000  1.000  -1.022
# dc_pop cabi_dur_full_arl                    1461.0  0.000  1.000  -1.037
# dc_pop cabi_dur_full_alx                    1461.0 -0.000  1.000  -0.642
# dc_pop cabi_dur_empty_alx                   1461.0 -0.000  1.000  -0.527
# dc_pop cabi_dur_empty_mcs                   1461.0 -0.000  1.000  -0.501
# dc_pop cabi_dur_full_mcs                    1461.0 -0.000  1.000  -0.265
# dc_pop cabi_dur_full_mcn                    1461.0  0.000  1.000  -0.078
# dc_pop cabi_dur_empty_mcn                   1461.0 -0.000  1.000  -0.144
# dc_pop sin_day_of_year                      1461.0 -0.000  1.000  -1.447
# dc_pop cos_day_of_year                      1461.0 -0.000  1.000  -1.447
# cabi_dur_empty_arl^2                        1461.0  0.000  1.000  -0.554
# cabi_dur_empty_arl cabi_dur_full_arl        1461.0  0.000  1.000  -0.500
# cabi_dur_empty_arl cabi_dur_full_alx        1461.0  0.000  1.000  -0.399
# cabi_dur_empty_arl cabi_dur_empty_alx       1461.0  0.000  1.000  -0.346
# cabi_dur_empty_arl cabi_dur_empty_mcs       1461.0 -0.000  1.000  -0.341
# cabi_dur_empty_arl cabi_dur_full_mcs        1461.0 -0.000  1.000  -0.115
# cabi_dur_empty_arl cabi_dur_full_mcn        1461.0  0.000  1.000  -0.046
# cabi_dur_empty_arl cabi_dur_empty_mcn       1461.0 -0.000  1.000  -0.075
# cabi_dur_empty_arl sin_day_of_year          1461.0 -0.000  1.000  -4.430
# cabi_dur_empty_arl cos_day_of_year          1461.0 -0.000  1.000  -5.444
# cabi_dur_full_arl^2                         1461.0 -0.000  1.000  -0.303
# cabi_dur_full_arl cabi_dur_full_alx         1461.0 -0.000  1.000  -0.234
# cabi_dur_full_arl cabi_dur_empty_alx        1461.0  0.000  1.000  -0.196
# cabi_dur_full_arl cabi_dur_empty_mcs        1461.0 -0.000  1.000  -0.197
# cabi_dur_full_arl cabi_dur_full_mcs         1461.0 -0.000  1.000  -0.059
# cabi_dur_full_arl cabi_dur_full_mcn         1461.0  0.000  1.000  -0.033
# cabi_dur_full_arl cabi_dur_empty_mcn        1461.0 -0.000  1.000  -0.045
# cabi_dur_full_arl sin_day_of_year           1461.0 -0.000  1.000  -3.997
# cabi_dur_full_arl cos_day_of_year           1461.0 -0.000  1.000 -10.112
# cabi_dur_full_alx^2                         1461.0  0.000  1.000  -0.270
# cabi_dur_full_alx cabi_dur_empty_alx        1461.0 -0.000  1.000  -0.189
# cabi_dur_full_alx cabi_dur_empty_mcs        1461.0  0.000  1.000  -0.205
# cabi_dur_full_alx cabi_dur_full_mcs         1461.0 -0.000  1.000  -0.058
# cabi_dur_full_alx cabi_dur_full_mcn         1461.0 -0.000  1.000  -0.034
# cabi_dur_full_alx cabi_dur_empty_mcn        1461.0 -0.000  1.000  -0.046
# cabi_dur_full_alx sin_day_of_year           1461.0  0.000  1.000  -7.874
# cabi_dur_full_alx cos_day_of_year           1461.0 -0.000  1.000  -9.694
# cabi_dur_empty_alx^2                        1461.0  0.000  1.000  -0.240
# cabi_dur_empty_alx cabi_dur_empty_mcs       1461.0 -0.000  1.000  -0.168
# cabi_dur_empty_alx cabi_dur_full_mcs        1461.0 -0.000  1.000  -0.050
# cabi_dur_empty_alx cabi_dur_full_mcn        1461.0  0.000  1.000  -0.034
# cabi_dur_empty_alx cabi_dur_empty_mcn       1461.0 -0.000  1.000  -0.042
# cabi_dur_empty_alx sin_day_of_year          1461.0  0.000  1.000  -8.838
# cabi_dur_empty_alx cos_day_of_year          1461.0 -0.000  1.000 -10.098
# cabi_dur_empty_mcs^2                        1461.0  0.000  1.000  -0.233
# cabi_dur_empty_mcs cabi_dur_full_mcs        1461.0 -0.000  1.000  -0.056
# cabi_dur_empty_mcs cabi_dur_full_mcn        1461.0 -0.000  1.000  -0.035
# cabi_dur_empty_mcs cabi_dur_empty_mcn       1461.0  0.000  1.000  -0.046
# cabi_dur_empty_mcs sin_day_of_year          1461.0  0.000  1.000  -8.025
# cabi_dur_empty_mcs cos_day_of_year          1461.0  0.000  1.000 -10.246
# cabi_dur_full_mcs^2                         1461.0  0.000  1.000  -0.050
# cabi_dur_full_mcs cabi_dur_full_mcn         1461.0 -0.000  1.000  -0.028
# cabi_dur_full_mcs cabi_dur_empty_mcn        1461.0 -0.000  1.000  -0.030
# cabi_dur_full_mcs sin_day_of_year           1461.0 -0.000  1.000  -7.116
# cabi_dur_full_mcs cos_day_of_year           1461.0  0.000  1.000 -26.506
# cabi_dur_full_mcn^2                         1461.0  0.000  1.000  -0.033
# cabi_dur_full_mcn cabi_dur_empty_mcn        1461.0 -0.000  1.000  -0.028
# cabi_dur_full_mcn sin_day_of_year           1461.0 -0.000  1.000  -6.402
# cabi_dur_full_mcn cos_day_of_year           1461.0  0.000  1.000 -31.595
# cabi_dur_empty_mcn^2                        1461.0 -0.000  1.000  -0.039
# cabi_dur_empty_mcn sin_day_of_year          1461.0 -0.000  1.000  -4.453
# cabi_dur_empty_mcn cos_day_of_year          1461.0 -0.000  1.000 -29.406
#
#                                               50%     max
# rain                                        0.000   1.000
# snow                                        0.000   1.000
# us_holiday                                  0.000   1.000
# nats_single                                 0.000   1.000
# nats_double                                 0.000   1.000
# dc_bike_event                               0.000   1.000
# rain us_holiday                             0.000   1.000
# rain nats_single                            0.000   1.000
# rain nats_double                            0.000   1.000
# rain dc_bike_event                          0.000   1.000
# snow us_holiday                             0.000   1.000
# us_holiday nats_single                      0.000   1.000
# us_holiday cabi_dur_full_mcn                0.000   1.000
# nats_single dc_bike_event                   0.000   1.000
# dc_bike_event cabi_dur_full_mcn             0.000   1.000
# daylight_hours                             -0.090   1.385
# apparenttemperaturehigh                     0.098   2.038
# cloudcover                                 -0.330   3.304
# humidity                                    0.072   2.188
# precipaccumulation                         -0.093  31.534
# precipintensitymax                         -0.390  12.790
# precipprobability                          -0.754   1.957
# visibility                                  0.426   0.604
# windspeed                                  -0.185   4.539
# dc_pop                                      0.134   1.474
# cabi_dur_empty_arl                         -0.250   4.663
# cabi_dur_full_arl                          -0.253  14.056
# cabi_dur_full_alx                          -0.428  10.966
# cabi_dur_empty_alx                         -0.529  10.915
# cabi_dur_empty_mcs                         -0.503  10.883
# cabi_dur_full_mcs                          -0.265  28.217
# cabi_dur_full_mcn                          -0.078  33.857
# cabi_dur_empty_mcn                         -0.144  31.363
# sin_day_of_year                            -0.000   1.415
# cos_day_of_year                             0.005   1.413
# daylight_hours^2                           -0.174   1.466
# daylight_hours apparenttemperaturehigh     -0.044   2.154
# daylight_hours cloudcover                  -0.272   4.088
# daylight_hours humidity                     0.006   2.584
# daylight_hours precipaccumulation          -0.095  31.123
# daylight_hours precipintensitymax          -0.377  13.434
# daylight_hours precipprobability           -0.750   2.564
# daylight_hours rain                        -0.882   1.460
# daylight_hours snow                        -0.220   5.235
# daylight_hours visibility                   0.176   1.482
# daylight_hours windspeed                   -0.161   4.266
# daylight_hours us_holiday                  -0.168   7.671
# daylight_hours nats_single                 -0.515   2.130
# daylight_hours nats_double                 -0.074  14.663
# daylight_hours dc_bike_event               -0.110  10.175
# daylight_hours dc_pop                       0.019   1.551
# daylight_hours cabi_dur_empty_arl          -0.269   5.286
# daylight_hours cabi_dur_full_arl           -0.257  15.448
# daylight_hours cabi_dur_full_alx           -0.426  12.266
# daylight_hours cabi_dur_empty_alx          -0.517  12.510
# daylight_hours cabi_dur_empty_mcs          -0.493  12.264
# daylight_hours cabi_dur_full_mcs           -0.238  30.402
# daylight_hours cabi_dur_full_mcn           -0.072  34.479
# daylight_hours cabi_dur_empty_mcn          -0.132  32.467
# daylight_hours sin_day_of_year             -0.029   1.467
# daylight_hours cos_day_of_year              0.165   1.311
# apparenttemperaturehigh^2                  -0.065   2.668
# apparenttemperaturehigh cloudcover         -0.210   4.466
# apparenttemperaturehigh humidity            0.070   1.977
# apparenttemperaturehigh precipaccumulation -0.132  15.670
# apparenttemperaturehigh precipintensitymax -0.355  14.378
# apparenttemperaturehigh precipprobability  -0.723   3.167
# apparenttemperaturehigh rain               -0.849   2.067
# apparenttemperaturehigh snow               -0.209   8.795
# apparenttemperaturehigh visibility          0.119   2.080
# apparenttemperaturehigh windspeed          -0.133   3.617
# apparenttemperaturehigh us_holiday         -0.161   8.897
# apparenttemperaturehigh nats_single        -0.510   2.723
# apparenttemperaturehigh nats_double        -0.074  15.284
# apparenttemperaturehigh dc_bike_event      -0.109  12.629
# apparenttemperaturehigh dc_pop              0.110   2.141
# apparenttemperaturehigh cabi_dur_empty_arl -0.290   4.354
# apparenttemperaturehigh cabi_dur_full_arl  -0.288  11.096
# apparenttemperaturehigh cabi_dur_full_alx  -0.447   8.876
# apparenttemperaturehigh cabi_dur_empty_alx -0.504   8.716
# apparenttemperaturehigh cabi_dur_empty_mcs -0.489   8.728
# apparenttemperaturehigh cabi_dur_full_mcs  -0.272  26.454
# apparenttemperaturehigh cabi_dur_full_mcn  -0.083  31.743
# apparenttemperaturehigh cabi_dur_empty_mcn -0.152  29.415
# apparenttemperaturehigh sin_day_of_year     0.100   1.923
# apparenttemperaturehigh cos_day_of_year     0.262   1.718
# cloudcover^2                               -0.412   4.355
# cloudcover humidity                        -0.359   3.930
# cloudcover precipaccumulation              -0.101  26.058
# cloudcover precipintensitymax              -0.378   9.569
# cloudcover precipprobability               -0.582   4.177
# cloudcover rain                            -0.697   3.328
# cloudcover snow                            -0.171  11.518
# cloudcover visibility                      -0.279   4.338
# cloudcover windspeed                       -0.312   7.389
# cloudcover us_holiday                      -0.134  16.382
# cloudcover nats_single                     -0.409   7.162
# cloudcover nats_double                     -0.055  27.145
# cloudcover dc_bike_event                   -0.095  18.609
# cloudcover dc_pop                          -0.311   3.458
# cloudcover cabi_dur_empty_arl              -0.296   7.710
# cloudcover cabi_dur_full_arl               -0.306  13.436
# cloudcover cabi_dur_full_alx               -0.413  12.012
# cloudcover cabi_dur_empty_alx              -0.458  11.625
# cloudcover cabi_dur_empty_mcs              -0.449  13.520
# cloudcover cabi_dur_full_mcs               -0.228  28.100
# cloudcover cabi_dur_full_mcn               -0.071  33.638
# cloudcover cabi_dur_empty_mcn              -0.121  32.582
# cloudcover sin_day_of_year                 -0.101   3.817
# cloudcover cos_day_of_year                 -0.055   3.782
# humidity^2                                 -0.030   2.597
# humidity precipaccumulation                -0.112  21.818
# humidity precipintensitymax                -0.382  12.344
# humidity precipprobability                 -0.721   2.478
# humidity rain                              -0.881   1.690
# humidity snow                              -0.215   6.433
# humidity visibility                         0.152   2.186
# humidity windspeed                         -0.128   6.003
# humidity us_holiday                        -0.168   8.176
# humidity nats_single                       -0.507   2.908
# humidity nats_double                       -0.073  16.377
# humidity dc_bike_event                     -0.110  11.647
# humidity dc_pop                             0.045   2.311
# humidity cabi_dur_empty_arl                -0.271   4.619
# humidity cabi_dur_full_arl                 -0.258   9.031
# humidity cabi_dur_full_alx                 -0.442   7.161
# humidity cabi_dur_empty_alx                -0.524   8.051
# humidity cabi_dur_empty_mcs                -0.500   7.984
# humidity cabi_dur_full_mcs                 -0.308  21.981
# humidity cabi_dur_full_mcn                 -0.094  28.921
# humidity cabi_dur_empty_mcn                -0.169  26.562
# humidity sin_day_of_year                    0.052   1.980
# humidity cos_day_of_year                    0.032   1.988
# precipaccumulation^2                       -0.038  37.789
# precipaccumulation precipintensitymax      -0.047  36.967
# precipaccumulation precipprobability       -0.116  19.989
# precipaccumulation rain                     0.000   0.000
# precipaccumulation snow                    -0.093  31.534
# precipaccumulation visibility              -0.075  35.327
# precipaccumulation windspeed               -0.058  35.586
# precipaccumulation us_holiday              -0.037  27.210
# precipaccumulation nats_single              0.000   0.000
# precipaccumulation nats_double              0.000   0.000
# precipaccumulation dc_bike_event            0.000   0.000
# precipaccumulation dc_pop                  -0.092  31.558
# precipaccumulation cabi_dur_empty_arl      -0.076  24.753
# precipaccumulation cabi_dur_full_arl       -0.058  33.566
# precipaccumulation cabi_dur_full_alx       -0.053  30.142
# precipaccumulation cabi_dur_empty_alx      -0.032  37.976
# precipaccumulation cabi_dur_empty_mcs      -0.043  30.214
# precipaccumulation cabi_dur_full_mcs       -0.031  37.391
# precipaccumulation cabi_dur_full_mcn       -0.026  38.209
# precipaccumulation cabi_dur_empty_mcn      -0.038  35.382
# precipaccumulation sin_day_of_year         -0.076  32.506
# precipaccumulation cos_day_of_year         -0.092  30.594
# precipintensitymax^2                       -0.152  22.597
# precipintensitymax precipprobability       -0.385  11.722
# precipintensitymax rain                    -0.385  12.866
# precipintensitymax snow                    -0.121  21.738
# precipintensitymax visibility              -0.383  12.774
# precipintensitymax windspeed               -0.363  12.747
# precipintensitymax us_holiday              -0.073  27.198
# precipintensitymax nats_single             -0.159  22.159
# precipintensitymax nats_double             -0.043  33.035
# precipintensitymax dc_bike_event           -0.049  32.752
# precipintensitymax dc_pop                  -0.391  12.505
# precipintensitymax cabi_dur_empty_arl      -0.288  13.859
# precipintensitymax cabi_dur_full_arl       -0.267  16.748
# precipintensitymax cabi_dur_full_alx       -0.190  22.491
# precipintensitymax cabi_dur_empty_alx      -0.128  33.166
# precipintensitymax cabi_dur_empty_mcs      -0.182  20.798
# precipintensitymax cabi_dur_full_mcs       -0.130  24.885
# precipintensitymax cabi_dur_full_mcn       -0.073  23.184
# precipintensitymax cabi_dur_empty_mcn      -0.080  20.877
# precipintensitymax sin_day_of_year         -0.021   7.415
# precipintensitymax cos_day_of_year          0.107  11.337
# precipprobability^2                        -0.635   2.341
# precipprobability rain                     -0.702   2.062
# precipprobability snow                     -0.183   7.382
# precipprobability visibility               -0.759   2.456
# precipprobability windspeed                -0.621   5.999
# precipprobability us_holiday               -0.089  14.108
# precipprobability nats_single              -0.291   5.152
# precipprobability nats_double              -0.052  22.844
# precipprobability dc_bike_event            -0.076  14.502
# precipprobability dc_pop                   -0.754   2.033
# precipprobability cabi_dur_empty_arl       -0.492   8.857
# precipprobability cabi_dur_full_arl        -0.509   9.140
# precipprobability cabi_dur_full_alx        -0.322  11.507
# precipprobability cabi_dur_empty_alx       -0.293  12.457
# precipprobability cabi_dur_empty_mcs       -0.275  11.920
# precipprobability cabi_dur_full_mcs        -0.191  14.990
# precipprobability cabi_dur_full_mcn        -0.073  24.599
# precipprobability cabi_dur_empty_mcn       -0.115  18.210
# precipprobability sin_day_of_year          -0.099   3.047
# precipprobability cos_day_of_year          -0.006   2.988
# rain snow                                   0.000   0.000
# rain visibility                            -0.884   1.341
# rain windspeed                             -0.710   4.766
# rain dc_pop                                -0.902   1.166
# rain cabi_dur_empty_arl                    -0.560   6.790
# rain cabi_dur_full_arl                     -0.540  16.746
# rain cabi_dur_full_alx                     -0.354  15.931
# rain cabi_dur_empty_alx                    -0.324  16.491
# rain cabi_dur_empty_mcs                    -0.290  17.515
# rain cabi_dur_full_mcs                     -0.148  32.180
# rain cabi_dur_full_mcn                     -0.056  34.937
# rain cabi_dur_empty_mcn                    -0.084  34.139
# rain sin_day_of_year                       -0.038   2.106
# rain cos_day_of_year                        0.129   2.226
# snow visibility                            -0.215   5.389
# snow windspeed                             -0.185  10.636
# snow nats_single                            0.000   0.000
# snow nats_double                            0.000   0.000
# snow dc_bike_event                          0.000   0.000
# snow dc_pop                                -0.221   4.682
# snow cabi_dur_empty_arl                    -0.094  28.135
# snow cabi_dur_full_arl                     -0.126  19.641
# snow cabi_dur_full_alx                     -0.058  29.233
# snow cabi_dur_empty_alx                    -0.035  37.855
# snow cabi_dur_empty_mcs                    -0.054  32.978
# snow cabi_dur_full_mcs                     -0.039  31.043
# snow cabi_dur_full_mcn                     -0.029  37.889
# snow cabi_dur_empty_mcn                    -0.054  30.072
# snow sin_day_of_year                       -0.171   7.276
# snow cos_day_of_year                       -0.212   5.872
# visibility^2                                0.446   0.671
# visibility windspeed                       -0.195   4.680
# visibility us_holiday                      -0.170   6.218
# visibility nats_single                     -0.515   2.051
# visibility nats_double                     -0.074  14.671
# visibility dc_bike_event                   -0.111   9.596
# visibility dc_pop                           0.355   0.833
# visibility cabi_dur_empty_arl              -0.258   4.812
# visibility cabi_dur_full_arl               -0.255  14.449
# visibility cabi_dur_full_alx               -0.421  11.288
# visibility cabi_dur_empty_alx              -0.524  11.323
# visibility cabi_dur_empty_mcs              -0.498  11.141
# visibility cabi_dur_full_mcs               -0.257  28.681
# visibility cabi_dur_full_mcn               -0.076  34.172
# visibility cabi_dur_empty_mcn              -0.142  31.780
# visibility sin_day_of_year                  0.010   1.513
# visibility cos_day_of_year                  0.025   1.539
# windspeed^2                                -0.343   7.536
# windspeed us_holiday                       -0.144  15.615
# windspeed nats_single                      -0.452   6.040
# windspeed nats_double                      -0.068  22.523
# windspeed dc_bike_event                    -0.100  17.984
# windspeed dc_pop                           -0.179   4.573
# windspeed cabi_dur_empty_arl               -0.305  11.150
# windspeed cabi_dur_full_arl                -0.242  25.133
# windspeed cabi_dur_full_alx                -0.369  23.034
# windspeed cabi_dur_empty_alx               -0.416  23.566
# windspeed cabi_dur_empty_mcs               -0.385  22.342
# windspeed cabi_dur_full_mcs                -0.141  35.431
# windspeed cabi_dur_full_mcn                -0.048  37.600
# windspeed cabi_dur_empty_mcn               -0.085  36.263
# windspeed sin_day_of_year                  -0.062   3.887
# windspeed cos_day_of_year                  -0.057   3.485
# us_holiday nats_double                      0.000   0.000
# us_holiday dc_bike_event                    0.000   0.000
# us_holiday dc_pop                          -0.172   5.973
# us_holiday cabi_dur_empty_arl              -0.107  16.064
# us_holiday cabi_dur_full_arl               -0.114  18.758
# us_holiday cabi_dur_full_alx               -0.090  22.739
# us_holiday cabi_dur_empty_alx              -0.074  22.265
# us_holiday cabi_dur_empty_mcs              -0.072  24.717
# us_holiday cabi_dur_full_mcs               -0.054  28.449
# us_holiday cabi_dur_empty_mcn              -0.026  38.209
# us_holiday sin_day_of_year                  0.047   7.553
# us_holiday cos_day_of_year                 -0.061   7.241
# nats_single nats_double                     0.000   0.000
# nats_single dc_pop                         -0.517   1.997
# nats_single cabi_dur_empty_arl             -0.428   6.001
# nats_single cabi_dur_full_arl              -0.408   8.261
# nats_single cabi_dur_full_alx              -0.304  12.474
# nats_single cabi_dur_empty_alx             -0.280   9.322
# nats_single cabi_dur_empty_mcs             -0.269  13.396
# nats_single cabi_dur_full_mcs              -0.176  12.501
# nats_single cabi_dur_full_mcn              -0.069  29.274
# nats_single cabi_dur_empty_mcn             -0.122  19.476
# nats_single sin_day_of_year                 0.012   3.073
# nats_single cos_day_of_year                 0.452   0.584
# nats_double dc_bike_event                   0.000   0.000
# nats_double dc_pop                         -0.074  13.880
# nats_double cabi_dur_empty_arl             -0.069  18.761
# nats_double cabi_dur_full_arl              -0.063  25.170
# nats_double cabi_dur_full_alx              -0.056  30.396
# nats_double cabi_dur_empty_alx             -0.040  27.297
# nats_double cabi_dur_empty_mcs             -0.037  35.772
# nats_double cabi_dur_full_mcs              -0.036  33.225
# nats_double cabi_dur_full_mcn               0.000   0.000
# nats_double cabi_dur_empty_mcn              0.000   0.000
# nats_double sin_day_of_year                 0.032  12.529
# nats_double cos_day_of_year                 0.060   0.060
# dc_bike_event dc_pop                       -0.112   9.111
# dc_bike_event cabi_dur_empty_arl           -0.083  21.839
# dc_bike_event cabi_dur_full_arl            -0.070  22.123
# dc_bike_event cabi_dur_full_alx            -0.076  19.643
# dc_bike_event cabi_dur_empty_alx           -0.066  27.773
# dc_bike_event cabi_dur_empty_mcs           -0.061  26.944
# dc_bike_event cabi_dur_full_mcs            -0.040  32.330
# dc_bike_event cabi_dur_empty_mcn           -0.036  32.192
# dc_bike_event sin_day_of_year               0.000  11.755
# dc_bike_event cos_day_of_year               0.037  13.092
# dc_pop^2                                    0.125   1.489
# dc_pop cabi_dur_empty_arl                  -0.261   4.623
# dc_pop cabi_dur_full_arl                   -0.255  13.998
# dc_pop cabi_dur_full_alx                   -0.430  10.883
# dc_pop cabi_dur_empty_alx                  -0.527  10.843
# dc_pop cabi_dur_empty_mcs                  -0.501  10.769
# dc_pop cabi_dur_full_mcs                   -0.265  28.137
# dc_pop cabi_dur_full_mcn                   -0.078  33.800
# dc_pop cabi_dur_empty_mcn                  -0.144  31.301
# dc_pop sin_day_of_year                      0.004   1.446
# dc_pop cos_day_of_year                      0.005   1.453
# cabi_dur_empty_arl^2                       -0.390   8.142
# cabi_dur_empty_arl cabi_dur_full_arl       -0.323  25.680
# cabi_dur_empty_arl cabi_dur_full_alx       -0.366  21.315
# cabi_dur_empty_arl cabi_dur_empty_alx      -0.346  20.614
# cabi_dur_empty_arl cabi_dur_empty_mcs      -0.341  20.066
# cabi_dur_empty_arl cabi_dur_full_mcs       -0.115  36.225
# cabi_dur_empty_arl cabi_dur_full_mcn       -0.046  37.261
# cabi_dur_empty_arl cabi_dur_empty_mcn      -0.075  36.248
# cabi_dur_empty_arl sin_day_of_year          0.148   5.268
# cabi_dur_empty_arl cos_day_of_year          0.380   4.287
# cabi_dur_full_arl^2                        -0.212  32.737
# cabi_dur_full_arl cabi_dur_full_alx        -0.214  33.782
# cabi_dur_full_arl cabi_dur_empty_alx       -0.196  34.120
# cabi_dur_full_arl cabi_dur_empty_mcs       -0.197  34.372
# cabi_dur_full_arl cabi_dur_full_mcs        -0.059  37.980
# cabi_dur_full_arl cabi_dur_full_mcn        -0.033  38.147
# cabi_dur_full_arl cabi_dur_empty_mcn       -0.045  37.903
# cabi_dur_full_arl sin_day_of_year           0.093  10.927
# cabi_dur_full_arl cos_day_of_year           0.268   6.692
# cabi_dur_full_alx^2                        -0.260  25.381
# cabi_dur_full_alx cabi_dur_empty_alx       -0.189  32.315
# cabi_dur_full_alx cabi_dur_empty_mcs       -0.205  31.760
# cabi_dur_full_alx cabi_dur_full_mcs        -0.058  37.866
# cabi_dur_full_alx cabi_dur_full_mcn        -0.034  38.022
# cabi_dur_full_alx cabi_dur_empty_mcn       -0.046  37.794
# cabi_dur_full_alx sin_day_of_year           0.118  10.025
# cabi_dur_full_alx cos_day_of_year           0.247   3.363
# cabi_dur_empty_alx^2                       -0.240  24.292
# cabi_dur_empty_alx cabi_dur_empty_mcs      -0.168  30.586
# cabi_dur_empty_alx cabi_dur_full_mcs       -0.050  38.018
# cabi_dur_empty_alx cabi_dur_full_mcn       -0.034  38.006
# cabi_dur_empty_alx cabi_dur_empty_mcn      -0.042  37.888
# cabi_dur_empty_alx sin_day_of_year          0.177  10.473
# cabi_dur_empty_alx cos_day_of_year          0.213   6.571
# cabi_dur_empty_mcs^2                       -0.233  23.891
# cabi_dur_empty_mcs cabi_dur_full_mcs       -0.056  37.690
# cabi_dur_empty_mcs cabi_dur_full_mcn       -0.035  37.970
# cabi_dur_empty_mcs cabi_dur_empty_mcn      -0.046  37.770
# cabi_dur_empty_mcs sin_day_of_year          0.138  10.411
# cabi_dur_empty_mcs cos_day_of_year          0.261   3.801
# cabi_dur_full_mcs^2                        -0.050  37.957
# cabi_dur_full_mcs cabi_dur_full_mcn        -0.028  38.197
# cabi_dur_full_mcs cabi_dur_empty_mcn       -0.030  38.192
# cabi_dur_full_mcs sin_day_of_year           0.090  28.591
# cabi_dur_full_mcs cos_day_of_year           0.056   5.498
# cabi_dur_full_mcn^2                        -0.033  37.952
# cabi_dur_full_mcn cabi_dur_empty_mcn       -0.028  38.192
# cabi_dur_full_mcn sin_day_of_year          -0.005  35.888
# cabi_dur_full_mcn cos_day_of_year           0.046   5.902
# cabi_dur_empty_mcn^2                       -0.039  38.007
# cabi_dur_empty_mcn sin_day_of_year          0.001  32.795
# cabi_dur_empty_mcn cos_day_of_year          0.073   7.562

# %%
# Appending train and test to get full dataset for cross-validation

Xfull = Xtrain.append(Xtest)
yfull = ytrain.append(ytest)
print(Xfull.shape, yfull.shape)
# Out:
# (1712, 368) (1712,)

# %% [markdown]
# ### 2. Model Fitting

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import median_absolute_error as medae
from sklearn.metrics import explained_variance_score as evs
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import KFold

def score_model(model, alpha=False):
    """ 
    Fits a model using the training set, predicts using the test set, and then calculates 
    and reports goodness of fit metrics and alpha if specified and available.
    """
    model.fit(Xtrain, ytrain)
    yhat = model.predict(Xtest)
    r2 = r2_score(ytest, yhat)
    me = mse(ytest, yhat)
    ae = mae(ytest, yhat)
    mede = medae(ytest, yhat)
    ev = evs(ytest, yhat)
    
    if alpha == True:
        print("Results from {}: \nr2={:0.3f} \nMSE={:0.3f} \
              \nMAE={:0.3f} \nMEDAE={:0.3f} \nEVS={:0.3f} \nalpha={:0.3f}".format(model, r2, me, 
                                                                                  ae, mede, ev, model.alpha_))
    else:
        print("Results from {}: \nr2={:0.3f} \nMSE={:0.3f} \
              \nMAE={:0.3f} \nMEDAE={:0.3f} \nEVS={:0.3f}".format(model, r2, me, ae, mede, ev))

def cv_score(model, cv=5):
    """
    Evaluates a model by 5-fold cross-validation and prints mean and 2*stdev of scores.
    Shuffles before cross-validation but sets random_state=7 for reproducibility.
    """
    kf = KFold(n_splits=cv, shuffle=True, random_state=7)
    scores = cross_val_score(model, Xfull, yfull, cv=kf)
    print(scores)
    print("Accuracy: {:0.3f} (+/- {:0.3f})".format(scores.mean(), scores.std() * 2))

# %%
'''Elastic Net'''
from sklearn.linear_model import ElasticNetCV

t = time.perf_counter()

# Alphas to search over
# Our alpha is usually in the low double digits
# This sets our search space to 250 steps between 10^0=1 and 10^2=100
alphas = np.logspace(0, 2, 250)

# Suggested l1_ratio from docs
l1_ratio = [.1, .5, .7, .9, .95, .99, 1]

en = ElasticNetCV(l1_ratio=l1_ratio, alphas=alphas, fit_intercept=True, normalize=False)

score_model(en, alpha=True)
print("L1 ratio=",en.l1_ratio_)

elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Results from ElasticNetCV(alphas=array([  1.     ,   1.01867, ...,  98.16753, 100.     ]),
#        copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=1000,
#        n_alphas=100, n_jobs=1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='cyclic',
#        tol=0.0001, verbose=0):
# r2=0.695
# MSE=2900493.709
# MAE=1232.440
# MEDAE=904.068
# EVS=0.706
# alpha=17.578
# L1 ratio= 1.0
# This cell took 0.78 minutes to run
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
'''Lasso'''
from sklearn.linear_model import LassoCV

t = time.perf_counter()

lasso = LassoCV(alphas=alphas, n_alphas=250, fit_intercept=True, normalize=False)
score_model(lasso, alpha=True)

elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Results from LassoCV(alphas=array([  1.     ,   1.01867, ...,  98.16753, 100.     ]),
#     copy_X=True, cv=None, eps=0.001, fit_intercept=True, max_iter=1000,
#     n_alphas=250, n_jobs=1, normalize=False, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=False):
# r2=0.695
# MSE=2900493.709
# MAE=1232.440
# MEDAE=904.068
# EVS=0.706
# alpha=17.578
# This cell took 0.22 minutes to run
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
# Which variables were selected?

# Put coefficients and variable names in df
lassodf = pd.DataFrame(lasso.coef_, index=Xtrain.columns)

# Select nonzeros
results = lassodf[(lassodf.T != 0).any()]

# Sort by magnitude
results['sorted'] = results[0].abs()
results.sort_values(by='sorted', inplace=True, ascending=False)

print("Lasso chooses {} variables".format(len(results)))
print(results)
# Out:
# Lasso chooses 73 variables
#                                                    0       sorted
# cabi_dur_empty_arl                       1102.419467  1102.419467
# apparenttemperaturehigh cos_day_of_year   865.538859   865.538859
# visibility cos_day_of_year               -847.114806   847.114806
# humidity precipprobability               -533.499043   533.499043
# apparenttemperaturehigh dc_pop            486.114288   486.114288
# cos_day_of_year                          -429.329733   429.329733
# cabi_dur_empty_arl^2                     -421.096951   421.096951
# sin_day_of_year                          -395.431284   395.431284
# apparenttemperaturehigh visibility        374.557298   374.557298
# cabi_dur_full_arl^2                      -266.962070   266.962070
# cabi_dur_full_alx                         232.265298   232.265298
# daylight_hours dc_pop                     229.218891   229.218891
# cabi_dur_full_arl                         192.863458   192.863458
# cloudcover precipintensitymax            -188.922722   188.922722
# precipprobability cabi_dur_full_arl       151.986588   151.986588
# cabi_dur_full_alx sin_day_of_year         119.937641   119.937641
# humidity^2                               -118.376750   118.376750
# us_holiday cos_day_of_year               -115.256456   115.256456
# dc_pop                                    108.011910   108.011910
# cabi_dur_empty_arl sin_day_of_year        105.465161   105.465161
# cabi_dur_empty_mcs                        104.005180   104.005180
# humidity us_holiday                       -96.552113    96.552113
# precipprobability nats_single              90.878478    90.878478
# precipaccumulation precipprobability      -85.352078    85.352078
# cabi_dur_full_alx cos_day_of_year          74.705998    74.705998
# precipintensitymax cos_day_of_year         74.161091    74.161091
# cloudcover windspeed                      -72.390888    72.390888
# cabi_dur_empty_alx cos_day_of_year         71.333833    71.333833
# nats_single sin_day_of_year                68.226139    68.226139
# cabi_dur_empty_mcs sin_day_of_year         66.237177    66.237177
# snow cabi_dur_empty_arl                   -64.747470    64.747470
# dc_pop cos_day_of_year                    -63.690157    63.690157
# precipintensitymax^2                       60.952591    60.952591
# rain cos_day_of_year                       53.324925    53.324925
# daylight_hours visibility                  47.805969    47.805969
# snow sin_day_of_year                      -47.370573    47.370573
# cloudcover cabi_dur_empty_alx              47.098215    47.098215
# cloudcover cabi_dur_empty_mcs              46.941203    46.941203
# cloudcover cabi_dur_full_arl               44.943315    44.943315
# cabi_dur_empty_mcs cos_day_of_year         40.082684    40.082684
# cabi_dur_empty_arl cabi_dur_full_arl      -33.451811    33.451811
# precipintensitymax sin_day_of_year         31.962905    31.962905
# precipprobability snow                     30.373258    30.373258
# dc_bike_event cabi_dur_full_mcs           -26.857684    26.857684
# cabi_dur_empty_alx sin_day_of_year         26.332274    26.332274
# cloudcover snow                            25.963020    25.963020
# us_holiday cabi_dur_full_arl               23.765430    23.765430
# precipaccumulation cabi_dur_empty_alx     -22.348541    22.348541
# dc_bike_event cabi_dur_full_alx            21.853036    21.853036
# nats_double cabi_dur_full_alx              21.617722    21.617722
# nats_single cabi_dur_full_mcn             -18.739659    18.739659
# precipaccumulation sin_day_of_year        -15.737835    15.737835
# cloudcover us_holiday                     -15.696317    15.696317
# dc_bike_event cabi_dur_empty_mcn           15.277609    15.277609
# cloudcover dc_bike_event                  -15.138609    15.138609
# precipprobability cabi_dur_empty_mcn       13.039510    13.039510
# apparenttemperaturehigh rain              -12.876906    12.876906
# precipintensitymax cabi_dur_empty_mcs     -11.451731    11.451731
# rain cabi_dur_empty_mcs                   -11.422029    11.422029
# cabi_dur_full_mcs cos_day_of_year           8.168946     8.168946
# nats_single dc_pop                          7.372455     7.372455
# us_holiday cabi_dur_full_mcs                7.193125     7.193125
# precipaccumulation cabi_dur_full_arl       -6.592852     6.592852
# cloudcover precipprobability               -6.457796     6.457796
# precipprobability sin_day_of_year           6.376832     6.376832
# nats_single cabi_dur_full_alx               5.175504     5.175504
# us_holiday cabi_dur_empty_mcn               5.014777     5.014777
# snow cabi_dur_empty_mcn                    -4.770505     4.770505
# cloudcover rain                            -4.663006     4.663006
# nats_double sin_day_of_year                -2.860937     2.860937
# dc_pop cabi_dur_full_arl                    1.897239     1.897239
# visibility us_holiday                      -1.447495     1.447495
# dc_bike_event cabi_dur_full_arl             1.047110     1.047110
# C:\Users\Sebastian\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Sebastian\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
'''Ridge'''
from sklearn.linear_model import RidgeCV

t = time.perf_counter()

rr = RidgeCV(alphas=alphas, fit_intercept=True, normalize=False)

score_model(rr, alpha=True)

cv_score(rr)

elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# Results from RidgeCV(alphas=array([  1.     ,   1.01867, ...,  98.16753, 100.     ]),
#     cv=None, fit_intercept=True, gcv_mode=None, normalize=False,
#     scoring=None, store_cv_values=False):
# r2=0.301
# MSE=6654858.628
# MAE=1534.113
# MEDAE=1100.226
# EVS=0.301
# alpha=100.000
# [0.77584136 0.85975288 0.81177338 0.85366058 0.86416417]
# Accuracy: 0.833 (+/- 0.068)
# This cell took 0.24 minutes to run

# %%
'''RF'''
from sklearn.ensemble import RandomForestRegressor

t = time.perf_counter()

rf = RandomForestRegressor() 
score_model(rf)

cv_score(rf)

elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# Results from RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False):
# r2=0.841
# MSE=1511873.754
# MAE=969.216
# MEDAE=846.500
# EVS=0.848
# [0.90058279 0.90060952 0.88893882 0.89623753 0.91076297]
# Accuracy: 0.899 (+/- 0.014)
# This cell took 0.10 minutes to run

# %%
t = time.perf_counter()

# Cross-validation
cv_score(lasso, cv=5)

elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# [0.8523053  0.85221829 0.83782696 0.84932459 0.8706892 ]
# Accuracy: 0.852 (+/- 0.021)
# This cell took 1.52 minutes to run

# %%
end_time = (time.perf_counter() - start_time)/60
print("This notebook took {:0.2f} minutes to run".format(end_time))
# Out:
# This notebook took 2.90 minutes to run

# %% [markdown]
# To do:
# * No polynomials, 3 polynomials
# * How to interpret the coefficients?
# * Modify train/test split size
