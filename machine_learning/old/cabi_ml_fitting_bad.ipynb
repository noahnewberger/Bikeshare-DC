# %% [markdown]
# # CaBi ML fitting
# In this notebook, I extend the ML framework that I used on the UCI data to the CaBi data.
#
# This version includes all variables labeled "for ML" in the data dictionary as an illustrative example.

# %% [markdown]
# ## 0. Data load, shaping, and split
# * Read in data from AWS
#   * Aside - note multicollinearity
# * Encode time variable (day_of_year) as cyclical
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Specify feature and target columns

# %%
# Read in data from AWS

from util_functions import *
import numpy as np
import pandas as pd

set_env_path()
conn, cur = aws_connect()

'''
For this nb, I only pull the date variable day_of_year for later transformation into cyclical time variables.
Not 100% sure on whether or not this precludes using things like OneHotEncoded day_of_week, but I omit that here.

I also omit actual temperature variables in favor of apparent temperature. 
Some other weather variables are omitted like moonphase and windbearing
'''

query = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
daylight_hours,
apparenttemperaturehigh,
apparenttemperaturelow,
cloudcover,
dewpoint,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
dc_bike_event,
dc_pop,
cabi_bikes_avail,
cabi_stations_alx,
cabi_stations_arl,
cabi_stations_ffx,
cabi_stations_mcn,
cabi_stations_mcs,
cabi_stations_wdc,
cabi_docks_alx,
cabi_docks_arl,
cabi_docks_ffx,
cabi_docks_mcn,
cabi_docks_mcs,
cabi_docks_wdc,
cabi_stations_tot,
cabi_docks_tot,
cabi_dur_empty_wdc,
cabi_dur_full_wdc,
cabi_dur_empty_arl,
cabi_dur_full_arl,
cabi_dur_full_alx,
cabi_dur_empty_alx,
cabi_dur_empty_mcs,
cabi_dur_full_mcs,
cabi_dur_full_mcn,
cabi_dur_empty_mcn,
cabi_dur_full_ffx,
cabi_dur_empty_ffx,
cabi_dur_empty_tot,
cabi_dur_full_tot,
cabi_active_members_day_key,
cabi_active_members_monthly,
cabi_active_members_annual,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""
pd.options.display.max_rows = None
pd.options.display.max_columns = None

df = pd.read_sql(query, con=conn)
df.set_index(df.date, drop=True, inplace=True)
df.index = pd.to_datetime(df.index)

print("We have {} instances and {} features".format(*df.shape))
# Out:
# We have 2780 instances and 54 features

# %%
df.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                count         mean         std         min  \
# day_of_year                   2780.0      182.697     107.702       1.000
# daylight_hours                2780.0       12.077       2.021       9.000
# apparenttemperaturehigh       2780.0       64.306      20.594       2.240
# apparenttemperaturelow        2780.0       48.574      19.685     -10.840
# cloudcover                    2780.0        0.340       0.244       0.000
# dewpoint                      2780.0       45.143      18.577      -9.730
# humidity                      2780.0        0.669       0.137       0.210
# precipaccumulation            2780.0        0.045       0.527       0.000
# precipintensitymax            2780.0        0.029       0.072       0.000
# precipprobability             2780.0        0.282       0.373       0.000
# rain                          2780.0        0.454       0.498       0.000
# snow                          2780.0        0.040       0.196       0.000
# visibility                    2780.0        9.306       1.130       1.130
# windspeed                     2780.0        5.379       3.170       0.030
# us_holiday                    2780.0        0.031       0.173       0.000
# nats_single                   2780.0        0.200       0.400       0.000
# nats_double                   2780.0        0.006       0.078       0.000
# dc_bike_event                 2780.0        0.009       0.094       0.000
# dc_pop                        2780.0   662465.171   26420.230  607733.153
# cabi_bikes_avail              2780.0     2866.512    1269.018      97.000
# cabi_stations_alx             2780.0       13.564      11.342       0.000
# cabi_stations_arl             2780.0       62.064      26.619      12.000
# cabi_stations_ffx             2780.0        4.657       9.353       0.000
# cabi_stations_mcn             2780.0       13.338      11.284       0.000
# cabi_stations_mcs             2780.0       20.396      17.397       0.000
# cabi_stations_wdc             2780.0      181.556      54.504      32.000
# cabi_docks_alx                2780.0      314.044     232.311       0.000
# cabi_docks_arl                2780.0     1072.877     450.922     191.000
# cabi_docks_ffx                2780.0       83.197     166.026       0.000
# cabi_docks_mcn                2780.0      304.464     255.731       0.000
# cabi_docks_mcs                2780.0      399.611     344.164       0.000
# cabi_docks_wdc                2780.0     3931.242    1150.827     678.000
# cabi_stations_tot             2780.0      295.576     124.747      44.000
# cabi_docks_tot                2780.0     6105.434    2491.431     869.000
# cabi_dur_empty_wdc            2780.0   913840.408  728084.990       0.000
# cabi_dur_full_wdc             2780.0   484001.312  372743.689       0.000
# cabi_dur_empty_arl            2780.0   103321.117  132383.807       0.000
# cabi_dur_full_arl             2780.0    43502.125   48157.214       0.000
# cabi_dur_full_alx             2780.0    10897.354   23990.773       0.000
# cabi_dur_empty_alx            2780.0     6092.551   15606.603       0.000
# cabi_dur_empty_mcs            2780.0    13949.235   40894.944       0.000
# cabi_dur_full_mcs             2780.0     2318.766    8130.878       0.000
# cabi_dur_full_mcn             2780.0     1401.324   10546.828       0.000
# cabi_dur_empty_mcn            2780.0     2644.020   15048.476       0.000
# cabi_dur_full_ffx             2780.0     1546.118   10040.419       0.000
# cabi_dur_empty_ffx            2780.0     1583.953   11546.049       0.000
# cabi_dur_empty_tot            2780.0  1041431.283  879616.717       0.000
# cabi_dur_full_tot             2780.0   543666.998  426828.316       0.000
# cabi_active_members_day_key   2780.0     4900.631    5473.407       0.000
# cabi_active_members_monthly   2780.0      210.085     134.731      15.000
# cabi_active_members_annual    2780.0    24822.440    8466.934    2148.000
# cabi_trips_wdc_to_wdc         2780.0     6375.501    3185.075       0.000
# cabi_trips_wdc_to_wdc_casual  2780.0     1395.860    1339.656       0.000
#
#                                      50%          max
# day_of_year                      182.000      366.000
# daylight_hours                    12.000       15.000
# apparenttemperaturehigh           65.890      113.670
# apparenttemperaturelow            50.885       90.060
# cloudcover                         0.270        1.000
# dewpoint                          46.435       75.840
# humidity                           0.670        0.970
# precipaccumulation                 0.000       21.427
# precipintensitymax                 0.001        1.185
# precipprobability                  0.000        1.000
# rain                               0.000        1.000
# snow                               0.000        1.000
# visibility                         9.790       10.000
# windspeed                          4.850       25.460
# us_holiday                         0.000        1.000
# nats_single                        0.000        1.000
# nats_double                        0.000        1.000
# dc_bike_event                      0.000        1.000
# dc_pop                        665296.583   702021.562
# cabi_bikes_avail                3115.000     4636.000
# cabi_stations_alx                  8.000       31.000
# cabi_stations_arl                 70.000       92.000
# cabi_stations_ffx                  0.000       25.000
# cabi_stations_mcn                 21.000       35.000
# cabi_stations_mcs                 28.000       46.000
# cabi_stations_wdc                193.000      269.000
# cabi_docks_alx                   251.000      650.000
# cabi_docks_arl                  1140.000     1611.000
# cabi_docks_ffx                     0.000      442.000
# cabi_docks_mcn                   498.000      764.000
# cabi_docks_mcs                   537.000      909.000
# cabi_docks_wdc                  4086.000     5839.000
# cabi_stations_tot                320.000      497.000
# cabi_docks_tot                  6512.000    10200.000
# cabi_dur_empty_wdc            766788.500  4059972.000
# cabi_dur_full_wdc             422573.500  2108359.000
# cabi_dur_empty_arl             54818.500  1170040.000
# cabi_dur_full_arl              31039.500   630049.000
# cabi_dur_full_alx                  0.000   311058.000
# cabi_dur_empty_alx                 0.000   388080.000
# cabi_dur_empty_mcs                 0.000   808844.000
# cabi_dur_full_mcs                  0.000   221578.000
# cabi_dur_full_mcn                  0.000   272821.000
# cabi_dur_empty_mcn                 0.000   324429.000
# cabi_dur_full_ffx                  0.000   229986.000
# cabi_dur_empty_ffx                 0.000   260102.000
# cabi_dur_empty_tot            833921.000  5404265.000
# cabi_dur_full_tot             470151.500  3053580.000
# cabi_active_members_day_key     2803.000    16216.000
# cabi_active_members_monthly      209.000      607.000
# cabi_active_members_annual     27873.000    38492.000
# cabi_trips_wdc_to_wdc           6240.000    16608.000
# cabi_trips_wdc_to_wdc_casual    1000.000     9130.000

# %%
def print_highly_correlated(df, features, threshold=0.75):
    """Prints highly correlated feature pairs in df"""
    corr_df = df[features].corr()
    # Select pairs above threshold
    correlated_features = np.where(np.abs(corr_df) > threshold)
    # Avoid duplication
    correlated_features = [(corr_df.iloc[x,y], x, y) for x, y in zip(*correlated_features) if x != y and x < y]
    # Sort by abs(correlation)
    s_corr_list = sorted(correlated_features, key=lambda x: -abs(x[0]))
    print("There are {} feature pairs with pairwise correlation above {}".format(len(corr_df.columns), threshold))
    for v, i, j in s_corr_list:
        cols = df[features].columns
        print("{} and {} = {:0.3f}".format(corr_df.index[i], corr_df.columns[j], v))

# %%
# Note multicollinearity

print_highly_correlated(df, df.columns, threshold=0.75)
# Out:
# There are 53 feature pairs with pairwise correlation above 0.75
# cabi_stations_mcs and cabi_docks_mcs = 1.000
# cabi_stations_tot and cabi_docks_tot = 1.000
# cabi_stations_ffx and cabi_docks_ffx = 0.999
# cabi_stations_wdc and cabi_docks_wdc = 0.999
# cabi_stations_arl and cabi_docks_arl = 0.998
# cabi_stations_mcn and cabi_docks_mcn = 0.997
# cabi_stations_wdc and cabi_docks_tot = 0.994
# cabi_stations_wdc and cabi_stations_tot = 0.994
# cabi_docks_wdc and cabi_docks_tot = 0.993
# cabi_dur_empty_wdc and cabi_dur_empty_tot = 0.992
# cabi_bikes_avail and cabi_stations_tot = 0.992
# cabi_dur_full_wdc and cabi_dur_full_tot = 0.992
# cabi_docks_wdc and cabi_stations_tot = 0.991
# cabi_bikes_avail and cabi_docks_tot = 0.991
# cabi_stations_alx and cabi_docks_alx = 0.990
# dc_pop and cabi_docks_arl = 0.989
# cabi_stations_mcn and cabi_stations_mcs = 0.988
# dc_pop and cabi_docks_tot = 0.988
# cabi_bikes_avail and cabi_stations_wdc = 0.988
# dc_pop and cabi_stations_wdc = 0.988
# dc_pop and cabi_docks_wdc = 0.987
# dc_pop and cabi_stations_tot = 0.986
# dc_pop and cabi_bikes_avail = 0.986
# cabi_stations_mcn and cabi_docks_mcs = 0.985
# cabi_bikes_avail and cabi_docks_wdc = 0.984
# cabi_stations_mcs and cabi_docks_mcn = 0.983
# dc_pop and cabi_stations_arl = 0.982
# cabi_stations_wdc and cabi_docks_arl = 0.980
# cabi_docks_mcn and cabi_docks_mcs = 0.979
# cabi_bikes_avail and cabi_docks_arl = 0.979
# cabi_docks_arl and cabi_active_members_annual = 0.978
# dc_pop and cabi_active_members_annual = 0.978
# cabi_bikes_avail and cabi_stations_arl = 0.977
# cabi_stations_arl and cabi_stations_wdc = 0.977
# cabi_docks_arl and cabi_docks_tot = 0.977
# cabi_docks_arl and cabi_docks_wdc = 0.976
# cabi_docks_arl and cabi_stations_tot = 0.976
# cabi_stations_arl and cabi_active_members_annual = 0.974
# cabi_stations_arl and cabi_stations_tot = 0.973
# cabi_stations_arl and cabi_docks_tot = 0.972
# cabi_stations_arl and cabi_docks_wdc = 0.970
# cabi_docks_mcs and cabi_stations_tot = 0.967
# cabi_stations_wdc and cabi_active_members_annual = 0.966
# cabi_stations_mcs and cabi_stations_tot = 0.966
# cabi_docks_wdc and cabi_active_members_annual = 0.963
# cabi_docks_mcs and cabi_docks_tot = 0.963
# cabi_docks_alx and cabi_docks_tot = 0.961
# cabi_bikes_avail and cabi_active_members_annual = 0.961
# cabi_stations_mcs and cabi_docks_tot = 0.961
# cabi_docks_tot and cabi_active_members_annual = 0.960
# cabi_bikes_avail and cabi_docks_alx = 0.959
# cabi_docks_alx and cabi_stations_tot = 0.959
# cabi_stations_tot and cabi_active_members_annual = 0.958
# cabi_stations_alx and cabi_active_members_day_key = 0.956
# cabi_bikes_avail and cabi_docks_mcs = 0.955
# cabi_bikes_avail and cabi_stations_mcs = 0.954
# cabi_docks_alx and cabi_docks_wdc = 0.953
# cabi_stations_alx and cabi_docks_tot = 0.953
# cabi_stations_wdc and cabi_docks_alx = 0.950
# cabi_stations_alx and cabi_stations_tot = 0.950
# dc_pop and cabi_docks_alx = 0.949
# cabi_bikes_avail and cabi_stations_alx = 0.948
# cabi_stations_mcn and cabi_stations_tot = 0.944
# cabi_stations_mcn and cabi_docks_tot = 0.939
# cabi_stations_wdc and cabi_docks_mcs = 0.938
# cabi_stations_alx and cabi_docks_wdc = 0.937
# cabi_stations_mcs and cabi_stations_wdc = 0.937
# apparenttemperaturehigh and apparenttemperaturelow = 0.936
# dc_pop and cabi_docks_mcs = 0.935
# cabi_docks_mcn and cabi_stations_tot = 0.934
# dc_pop and cabi_stations_mcs = 0.934
# dc_pop and cabi_stations_alx = 0.934
# cabi_stations_alx and cabi_stations_wdc = 0.933
# cabi_docks_alx and cabi_docks_arl = 0.931
# cabi_docks_mcs and cabi_docks_wdc = 0.930
# cabi_docks_mcn and cabi_docks_tot = 0.929
# cabi_stations_mcs and cabi_docks_wdc = 0.928
# apparenttemperaturelow and dewpoint = 0.928
# cabi_bikes_avail and cabi_stations_mcn = 0.928
# cabi_stations_arl and cabi_stations_mcs = 0.925
# apparenttemperaturehigh and dewpoint = 0.924
# cabi_stations_arl and cabi_docks_alx = 0.924
# cabi_bikes_avail and cabi_docks_mcn = 0.923
# cabi_stations_arl and cabi_docks_mcs = 0.922
# cabi_stations_mcs and cabi_docks_arl = 0.922
# cabi_docks_arl and cabi_docks_mcs = 0.921
# cabi_docks_alx and cabi_active_members_day_key = 0.919
# cabi_stations_arl and cabi_docks_mcn = 0.917
# cabi_stations_arl and cabi_stations_mcn = 0.917
# cabi_stations_mcn and cabi_stations_wdc = 0.916
# dc_pop and cabi_stations_mcn = 0.916
# cabi_docks_tot and cabi_active_members_day_key = 0.913
# dc_pop and cabi_docks_mcn = 0.911
# cabi_stations_tot and cabi_active_members_day_key = 0.910
# cabi_stations_mcn and cabi_docks_arl = 0.910
# cabi_stations_alx and cabi_docks_mcs = 0.909
# cabi_docks_arl and cabi_docks_mcn = 0.909
# cabi_docks_alx and cabi_active_members_annual = 0.907
# cabi_stations_alx and cabi_docks_arl = 0.906
# cabi_stations_wdc and cabi_docks_mcn = 0.905
# cabi_stations_mcn and cabi_docks_wdc = 0.905
# cabi_stations_mcs and cabi_active_members_annual = 0.905
# cabi_stations_alx and cabi_stations_mcs = 0.903
# cabi_docks_mcs and cabi_active_members_annual = 0.903
# cabi_docks_alx and cabi_docks_mcs = 0.902
# cabi_docks_mcs and cabi_active_members_day_key = 0.898
# cabi_stations_mcs and cabi_docks_alx = 0.898
# cabi_bikes_avail and cabi_active_members_day_key = 0.895
# cabi_stations_mcn and cabi_active_members_annual = 0.894
# cabi_docks_wdc and cabi_active_members_day_key = 0.894
# cabi_stations_alx and cabi_stations_arl = 0.893
# cabi_docks_mcn and cabi_active_members_annual = 0.893
# cabi_docks_mcn and cabi_docks_wdc = 0.892
# cabi_stations_mcs and cabi_active_members_day_key = 0.889
# cabi_stations_wdc and cabi_active_members_day_key = 0.886
# dc_pop and cabi_active_members_day_key = 0.882
# cabi_stations_alx and cabi_active_members_annual = 0.881
# cabi_dur_empty_arl and cabi_dur_empty_tot = 0.871
# cabi_dur_empty_tot and cabi_dur_full_tot = 0.866
# cabi_dur_empty_wdc and cabi_dur_full_tot = 0.861
# cabi_docks_ffx and cabi_active_members_day_key = 0.857
# cabi_stations_mcn and cabi_docks_alx = 0.856
# cabi_stations_alx and cabi_stations_mcn = 0.855
# cabi_stations_ffx and cabi_active_members_day_key = 0.854
# cabi_docks_alx and cabi_docks_mcn = 0.845
# cabi_stations_alx and cabi_docks_mcn = 0.843
# cabi_dur_empty_wdc and cabi_trips_wdc_to_wdc = 0.841
# cabi_dur_full_wdc and cabi_dur_empty_tot = 0.840
# cabi_dur_empty_wdc and cabi_dur_full_wdc = 0.840
# cabi_dur_empty_tot and cabi_trips_wdc_to_wdc = 0.839
# cabi_stations_mcn and cabi_active_members_day_key = 0.839
# daylight_hours and cabi_active_members_monthly = 0.839
# cabi_docks_arl and cabi_active_members_day_key = 0.828
# cabi_docks_mcn and cabi_active_members_day_key = 0.816
# cabi_dur_empty_wdc and cabi_dur_empty_arl = 0.810
# cabi_stations_arl and cabi_active_members_day_key = 0.810
# cabi_active_members_day_key and cabi_active_members_annual = 0.805
# cabi_trips_wdc_to_wdc and cabi_trips_wdc_to_wdc_casual = 0.770
# cabi_stations_alx and cabi_docks_ffx = 0.769
# cabi_stations_alx and cabi_stations_ffx = 0.764

# %%
# Encode day_of_year as cyclical
df['sin_day_of_year'] = np.sin(2*np.pi*df.day_of_year/365)
df['cos_day_of_year'] = np.cos(2*np.pi*df.day_of_year/365)

# %% [markdown]
# ### Notes about dates in our data
# Start date = earliest 1/1/2013, flexible
#
# Can use all of 2017 through September 8 as test set
#
# For cross-validation, randomly assigned
#
# Whatever % we use for train/test we should use for CV
#
# Put date into index and use loc to do train test split
#
#
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Training dates = 2013-01-01 to 2016-12-31
#   * Test dates = 2017-01-01 to 2017-09-08
#   * New data (coincides with beginning of dockless pilot) = 2017-09-09 to present

# %%
# Train test split
train = df.loc['2013-01-01':'2016-12-31']
test = df.loc['2017-01-01':'2017-09-08']
print(train.shape, test.shape)
tr = train.shape[0]
te = test.shape[0]
trpct = tr/(tr+te)
tepct = te/(tr+te)
print("{:0.3f} percent of the data is in the training set and {:0.3f} percent is in the test set".format(trpct, tepct))
# Out:
# (1461, 56) (251, 56)
# 0.853 percent of the data is in the training set and 0.147 percent is in the test set

# %%
# Specify columns to keep and drop for X and y
drop_cols = ['date', 'day_of_year']
y_cols = ['cabi_trips_wdc_to_wdc', 'cabi_trips_wdc_to_wdc_casual']

feature_cols = [col for col in df.columns if (col not in y_cols) & (col not in drop_cols)]

# Train test split
Xtrain_raw = train[feature_cols]
ytrain = train[y_cols[0]]
Xtest_raw = test[feature_cols]
ytest = test[y_cols[0]]
print(Xtrain_raw.shape, ytrain.shape, Xtest_raw.shape, ytest.shape)
# Out:
# (1461, 52) (1461,) (251, 52) (251,)

# %% [markdown]
# ### 1. Preprocessing
#
# We want to use PolynomialFeatures and StandardScaler in a Pipeline, but we only want to scale continuous features.
#
# We can do this by using FeatureUnion.
#
# Here, I do the polynomial transformation first and then feed it through a pipeline because I wasn't able to get it all working in one pipeline.
#
# * Use PolynomialFeatures to create quadratic and interaction terms
# * Create pipeline for selectively scaling certain variables
# * Fit and transform using pipeline to get final Xtrain and Xtest

# %%
# Imports and custom classes
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin

class Columns(BaseEstimator, TransformerMixin):
    ''' This is a custom transformer for splitting the data into subsets for FeatureUnion.
    '''
    def __init__(self, names=None):
        self.names = names

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X):
        return X[self.names]
    
class CustomPoly(BaseEstimator, TransformerMixin):
    ''' This is a custom transformer for making sure PolynomialFeatures
    outputs a labeled df instead of an array. It doesn't work as is, but
    I'm keeping the code here if we need it later.
    '''
    def __init__(self):
        self.pf = None
    
    def fit(self, X, y=None):
        self.pf = PolynomialFeatures(2, include_bias=False).fit(X)
        return self
    
    def transform(self, X):
        Xpf = self.pf.transform(X)
        colnames = self.pf.get_feature_names(X.columns)
        Xpoly = pd.DataFrame(Xpf, columns=colnames)
        return Xpoly

# %%
# PolynomialFeatures
# Should ultimately be part of a Pipeline, but I had issues because my custom Columns class takes a df
# CustomPoly above is an attempt to output a df
pf = PolynomialFeatures(2, include_bias=False)
Xtrain_pf_array = pf.fit_transform(Xtrain_raw)
Xtest_pf_array = pf.transform(Xtest_raw)

# Get feature names 
Xtrain_cols = pf.get_feature_names(Xtrain_raw.columns)

# Output two DataFrames with the new poly columns
Xtrain_pf = pd.DataFrame(Xtrain_pf_array, columns=Xtrain_cols)
Xtest_pf = pd.DataFrame(Xtest_pf_array, columns=Xtrain_cols)

print(Xtrain_pf.shape, Xtest_pf.shape)
# Out:
# (1461, 1430) (251, 1430)

# %%
# A lot of these variables are redundant, especially squared dummy variables
# All of these variables listed next are 'binary' but only a few are meaningful
# For now, let's just remove the squared terms
bin_vars = [col for col in Xtrain_pf.columns if Xtrain_pf[col].nunique() == 2]
bin_vars
# Out:
# ['rain',
#  'snow',
#  'us_holiday',
#  'nats_single',
#  'nats_double',
#  'dc_bike_event',
#  'cabi_dur_empty_ffx',
#  'daylight_hours cabi_dur_empty_ffx',
#  'apparenttemperaturehigh cabi_dur_empty_ffx',
#  'apparenttemperaturelow cabi_dur_empty_ffx',
#  'cloudcover cabi_dur_empty_ffx',
#  'dewpoint cabi_dur_empty_ffx',
#  'humidity cabi_dur_empty_ffx',
#  'precipintensitymax cabi_dur_full_ffx',
#  'precipintensitymax cabi_dur_empty_ffx',
#  'precipprobability cabi_dur_full_ffx',
#  'precipprobability cabi_dur_empty_ffx',
#  'rain^2',
#  'rain us_holiday',
#  'rain nats_single',
#  'rain nats_double',
#  'rain dc_bike_event',
#  'rain cabi_dur_full_ffx',
#  'rain cabi_dur_empty_ffx',
#  'snow^2',
#  'snow us_holiday',
#  'snow cabi_stations_ffx',
#  'snow cabi_docks_ffx',
#  'visibility cabi_dur_empty_ffx',
#  'windspeed cabi_dur_empty_ffx',
#  'us_holiday^2',
#  'us_holiday nats_single',
#  'us_holiday cabi_dur_full_mcn',
#  'nats_single^2',
#  'nats_single dc_bike_event',
#  'nats_double^2',
#  'dc_bike_event^2',
#  'dc_bike_event cabi_stations_ffx',
#  'dc_bike_event cabi_docks_ffx',
#  'dc_bike_event cabi_dur_full_mcn',
#  'dc_pop cabi_dur_empty_ffx',
#  'cabi_bikes_avail cabi_dur_empty_ffx',
#  'cabi_stations_alx cabi_dur_empty_ffx',
#  'cabi_stations_arl cabi_dur_empty_ffx',
#  'cabi_stations_ffx cabi_dur_empty_ffx',
#  'cabi_stations_mcn cabi_dur_empty_ffx',
#  'cabi_stations_mcs cabi_dur_empty_ffx',
#  'cabi_stations_wdc cabi_dur_empty_ffx',
#  'cabi_docks_alx cabi_dur_empty_ffx',
#  'cabi_docks_arl cabi_dur_empty_ffx',
#  'cabi_docks_ffx cabi_dur_empty_ffx',
#  'cabi_docks_mcn cabi_dur_empty_ffx',
#  'cabi_docks_mcs cabi_dur_empty_ffx',
#  'cabi_docks_wdc cabi_dur_empty_ffx',
#  'cabi_stations_tot cabi_dur_empty_ffx',
#  'cabi_docks_tot cabi_dur_empty_ffx',
#  'cabi_dur_empty_wdc cabi_dur_empty_ffx',
#  'cabi_dur_full_wdc cabi_dur_empty_ffx',
#  'cabi_dur_empty_arl cabi_dur_empty_ffx',
#  'cabi_dur_full_alx cabi_dur_empty_ffx',
#  'cabi_dur_full_mcs cabi_dur_full_ffx',
#  'cabi_dur_full_mcn cabi_dur_full_ffx',
#  'cabi_dur_empty_mcn cabi_dur_full_ffx',
#  'cabi_dur_empty_ffx^2',
#  'cabi_dur_empty_ffx cabi_dur_empty_tot',
#  'cabi_dur_empty_ffx cabi_dur_full_tot',
#  'cabi_dur_empty_ffx cabi_active_members_day_key',
#  'cabi_dur_empty_ffx cabi_active_members_monthly',
#  'cabi_dur_empty_ffx cabi_active_members_annual',
#  'cabi_dur_empty_ffx sin_day_of_year',
#  'cabi_dur_empty_ffx cos_day_of_year']

# %%
# Dropping squared dummies.
# Can expand to include things we deem not useful
# This part (or the initial SQL pull) can be expanded. There's a lot of noise after PF.
to_drop = ['rain^2', 'snow^2', 'us_holiday^2', 'nats_single^2', 'nats_double^2', 'dc_bike_event^2', 'cabi_dur_empty_ffx^2']

Xtrain_pf2 = Xtrain_pf.drop(labels=to_drop, axis=1)
Xtest_pf2 = Xtest_pf.drop(labels=to_drop, axis=1)

print(Xtrain_pf2.shape, Xtest_pf2.shape)
# Out:
# (1461, 1423) (251, 1423)

# %%
# Defining binary and continuous variables
# We have normal 0,1 binary variables, binary variables outside 0,1 that were created by PF, and continuous variables
# We want to ignore the 0,1s, MinMaxScale the non 0,1 binary variables, and StandardScale the continuous variables
binary = ['rain', 'snow', 'us_holiday', 'nats_single', 'nats_double', 'dc_bike_event']
binarypf = [col for col in Xtrain_pf2.columns if (Xtrain_pf2[col].nunique() == 2) & (col not in binary)]
cont = [col for col in Xtrain_pf2.columns if (col not in binary) & (col not in binarypf)]

# FeatureUnion in our pipeline shifts the ordering of the variables so we need to save the ordering here
cols = binary + binarypf + cont

pipeline = Pipeline([
    ('features', FeatureUnion([
        ('binary', Pipeline([
            ('bincols', Columns(names=binary))
        ])),
        ('binarypf', Pipeline([
            ('binpfcols', Columns(names=binarypf)),
            ('minmax', MinMaxScaler())
        ])),
        ('continuous', Pipeline([
            ('contcols', Columns(names=cont)),
            ('scaler', StandardScaler())
        ]))
    ]))   
])

# %%
# Fit and transform to create our final Xtrain and Xtest

pipeline.fit(Xtrain_pf2)
Xtrain_scaled = pipeline.transform(Xtrain_pf2)
Xtest_scaled = pipeline.transform(Xtest_pf2)

Xtrain = pd.DataFrame(Xtrain_scaled, columns=cols)
Xtest = pd.DataFrame(Xtest_scaled, columns=cols)
print(Xtrain.shape, Xtest.shape)
# Out:
# (1461, 1423) (251, 1423)

# %%
# Note a ton of extra, probably useless variables

Xtrain.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                                      count   mean    std  \
# rain                                                1461.0  0.449  0.498
# snow                                                1461.0  0.047  0.211
# us_holiday                                          1461.0  0.029  0.167
# nats_single                                         1461.0  0.211  0.408
# nats_double                                         1461.0  0.005  0.074
# dc_bike_event                                       1461.0  0.012  0.110
# cabi_dur_empty_ffx                                  1461.0  0.001  0.026
# daylight_hours cabi_dur_empty_ffx                   1461.0  0.001  0.026
# apparenttemperaturehigh cabi_dur_empty_ffx          1461.0  0.001  0.026
# apparenttemperaturelow cabi_dur_empty_ffx           1461.0  0.001  0.026
# cloudcover cabi_dur_empty_ffx                       1461.0  0.001  0.026
# dewpoint cabi_dur_empty_ffx                         1461.0  0.001  0.026
# humidity cabi_dur_empty_ffx                         1461.0  0.001  0.026
# precipintensitymax cabi_dur_full_ffx                1461.0  0.001  0.026
# precipintensitymax cabi_dur_empty_ffx               1461.0  0.001  0.026
# precipprobability cabi_dur_full_ffx                 1461.0  0.001  0.026
# precipprobability cabi_dur_empty_ffx                1461.0  0.001  0.026
# rain us_holiday                                     1461.0  0.008  0.086
# rain nats_single                                    1461.0  0.107  0.310
# rain nats_double                                    1461.0  0.003  0.058
# rain dc_bike_event                                  1461.0  0.007  0.082
# rain cabi_dur_full_ffx                              1461.0  0.001  0.026
# rain cabi_dur_empty_ffx                             1461.0  0.001  0.026
# snow us_holiday                                     1461.0  0.002  0.045
# snow cabi_stations_ffx                              1461.0  0.001  0.037
# snow cabi_docks_ffx                                 1461.0  0.001  0.037
# visibility cabi_dur_empty_ffx                       1461.0  0.001  0.026
# windspeed cabi_dur_empty_ffx                        1461.0  0.001  0.026
# us_holiday nats_single                              1461.0  0.006  0.078
# us_holiday cabi_dur_full_mcn                        1461.0  0.001  0.026
# nats_single dc_bike_event                           1461.0  0.002  0.045
# dc_bike_event cabi_stations_ffx                     1461.0  0.001  0.026
# dc_bike_event cabi_docks_ffx                        1461.0  0.001  0.026
# dc_bike_event cabi_dur_full_mcn                     1461.0  0.001  0.026
# dc_pop cabi_dur_empty_ffx                           1461.0  0.001  0.026
# cabi_bikes_avail cabi_dur_empty_ffx                 1461.0  0.001  0.026
# cabi_stations_alx cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_stations_arl cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_stations_ffx cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_stations_mcn cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_stations_mcs cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_stations_wdc cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_docks_alx cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_docks_arl cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_docks_ffx cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_docks_mcn cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_docks_mcs cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_docks_wdc cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_stations_tot cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_docks_tot cabi_dur_empty_ffx                   1461.0  0.001  0.026
# cabi_dur_empty_wdc cabi_dur_empty_ffx               1461.0  0.001  0.026
# cabi_dur_full_wdc cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_dur_empty_arl cabi_dur_empty_ffx               1461.0  0.001  0.026
# cabi_dur_full_alx cabi_dur_empty_ffx                1461.0  0.001  0.026
# cabi_dur_full_mcs cabi_dur_full_ffx                 1461.0  0.001  0.026
# cabi_dur_full_mcn cabi_dur_full_ffx                 1461.0  0.001  0.026
# cabi_dur_empty_mcn cabi_dur_full_ffx                1461.0  0.001  0.026
# cabi_dur_empty_ffx cabi_dur_empty_tot               1461.0  0.001  0.026
# cabi_dur_empty_ffx cabi_dur_full_tot                1461.0  0.001  0.026
# cabi_dur_empty_ffx cabi_active_members_day_key      1461.0  0.001  0.026
# cabi_dur_empty_ffx cabi_active_members_monthly      1461.0  0.001  0.026
# cabi_dur_empty_ffx cabi_active_members_annual       1461.0  0.001  0.026
# cabi_dur_empty_ffx sin_day_of_year                  1461.0  0.999  0.026
# cabi_dur_empty_ffx cos_day_of_year                  1461.0  0.001  0.026
# daylight_hours                                      1461.0 -0.000  1.000
# apparenttemperaturehigh                             1461.0  0.000  1.000
# apparenttemperaturelow                              1461.0  0.000  1.000
# cloudcover                                          1461.0  0.000  1.000
# dewpoint                                            1461.0  0.000  1.000
# humidity                                            1461.0 -0.000  1.000
# precipaccumulation                                  1461.0  0.000  1.000
# precipintensitymax                                  1461.0  0.000  1.000
# precipprobability                                   1461.0  0.000  1.000
# visibility                                          1461.0  0.000  1.000
# windspeed                                           1461.0  0.000  1.000
# dc_pop                                              1461.0  0.000  1.000
# cabi_bikes_avail                                    1461.0  0.000  1.000
# cabi_stations_alx                                   1461.0 -0.000  1.000
# cabi_stations_arl                                   1461.0 -0.000  1.000
# cabi_stations_ffx                                   1461.0 -0.000  1.000
# cabi_stations_mcn                                   1461.0  0.000  1.000
# cabi_stations_mcs                                   1461.0 -0.000  1.000
# cabi_stations_wdc                                   1461.0 -0.000  1.000
# cabi_docks_alx                                      1461.0  0.000  1.000
# cabi_docks_arl                                      1461.0  0.000  1.000
# cabi_docks_ffx                                      1461.0  0.000  1.000
# cabi_docks_mcn                                      1461.0 -0.000  1.000
# cabi_docks_mcs                                      1461.0  0.000  1.000
# cabi_docks_wdc                                      1461.0 -0.000  1.000
# cabi_stations_tot                                   1461.0  0.000  1.000
# cabi_docks_tot                                      1461.0  0.000  1.000
# cabi_dur_empty_wdc                                  1461.0 -0.000  1.000
# cabi_dur_full_wdc                                   1461.0 -0.000  1.000
# cabi_dur_empty_arl                                  1461.0 -0.000  1.000
# cabi_dur_full_arl                                   1461.0 -0.000  1.000
# cabi_dur_full_alx                                   1461.0  0.000  1.000
# cabi_dur_empty_alx                                  1461.0  0.000  1.000
# cabi_dur_empty_mcs                                  1461.0  0.000  1.000
# cabi_dur_full_mcs                                   1461.0  0.000  1.000
# cabi_dur_full_mcn                                   1461.0 -0.000  1.000
# cabi_dur_empty_mcn                                  1461.0 -0.000  1.000
# cabi_dur_full_ffx                                   1461.0 -0.000  1.000
# cabi_dur_empty_tot                                  1461.0  0.000  1.000
# cabi_dur_full_tot                                   1461.0  0.000  1.000
# cabi_active_members_day_key                         1461.0  0.000  1.000
# cabi_active_members_monthly                         1461.0 -0.000  1.000
# cabi_active_members_annual                          1461.0  0.000  1.000
# sin_day_of_year                                     1461.0 -0.000  1.000
# cos_day_of_year                                     1461.0  0.000  1.000
# daylight_hours^2                                    1461.0  0.000  1.000
# daylight_hours apparenttemperaturehigh              1461.0  0.000  1.000
# daylight_hours apparenttemperaturelow               1461.0 -0.000  1.000
# daylight_hours cloudcover                           1461.0  0.000  1.000
# daylight_hours dewpoint                             1461.0 -0.000  1.000
# daylight_hours humidity                             1461.0  0.000  1.000
# daylight_hours precipaccumulation                   1461.0 -0.000  1.000
# daylight_hours precipintensitymax                   1461.0  0.000  1.000
# daylight_hours precipprobability                    1461.0 -0.000  1.000
# daylight_hours rain                                 1461.0 -0.000  1.000
# daylight_hours snow                                 1461.0  0.000  1.000
# daylight_hours visibility                           1461.0 -0.000  1.000
# daylight_hours windspeed                            1461.0 -0.000  1.000
# daylight_hours us_holiday                           1461.0  0.000  1.000
# daylight_hours nats_single                          1461.0  0.000  1.000
# daylight_hours nats_double                          1461.0  0.000  1.000
# daylight_hours dc_bike_event                        1461.0  0.000  1.000
# daylight_hours dc_pop                               1461.0  0.000  1.000
# daylight_hours cabi_bikes_avail                     1461.0 -0.000  1.000
# daylight_hours cabi_stations_alx                    1461.0 -0.000  1.000
# daylight_hours cabi_stations_arl                    1461.0 -0.000  1.000
# daylight_hours cabi_stations_ffx                    1461.0 -0.000  1.000
# daylight_hours cabi_stations_mcn                    1461.0  0.000  1.000
# daylight_hours cabi_stations_mcs                    1461.0  0.000  1.000
# daylight_hours cabi_stations_wdc                    1461.0  0.000  1.000
# daylight_hours cabi_docks_alx                       1461.0 -0.000  1.000
# daylight_hours cabi_docks_arl                       1461.0 -0.000  1.000
# daylight_hours cabi_docks_ffx                       1461.0 -0.000  1.000
# daylight_hours cabi_docks_mcn                       1461.0  0.000  1.000
# daylight_hours cabi_docks_mcs                       1461.0 -0.000  1.000
# daylight_hours cabi_docks_wdc                       1461.0  0.000  1.000
# daylight_hours cabi_stations_tot                    1461.0  0.000  1.000
# daylight_hours cabi_docks_tot                       1461.0  0.000  1.000
# daylight_hours cabi_dur_empty_wdc                   1461.0  0.000  1.000
# daylight_hours cabi_dur_full_wdc                    1461.0  0.000  1.000
# daylight_hours cabi_dur_empty_arl                   1461.0  0.000  1.000
# daylight_hours cabi_dur_full_arl                    1461.0  0.000  1.000
# daylight_hours cabi_dur_full_alx                    1461.0 -0.000  1.000
# daylight_hours cabi_dur_empty_alx                   1461.0 -0.000  1.000
# daylight_hours cabi_dur_empty_mcs                   1461.0  0.000  1.000
# daylight_hours cabi_dur_full_mcs                    1461.0  0.000  1.000
# daylight_hours cabi_dur_full_mcn                    1461.0  0.000  1.000
# daylight_hours cabi_dur_empty_mcn                   1461.0 -0.000  1.000
# daylight_hours cabi_dur_full_ffx                    1461.0 -0.000  1.000
# daylight_hours cabi_dur_empty_tot                   1461.0 -0.000  1.000
# daylight_hours cabi_dur_full_tot                    1461.0 -0.000  1.000
# daylight_hours cabi_active_members_day_key          1461.0  0.000  1.000
# daylight_hours cabi_active_members_monthly          1461.0 -0.000  1.000
# daylight_hours cabi_active_members_annual           1461.0 -0.000  1.000
# daylight_hours sin_day_of_year                      1461.0 -0.000  1.000
# daylight_hours cos_day_of_year                      1461.0 -0.000  1.000
# apparenttemperaturehigh^2                           1461.0 -0.000  1.000
# apparenttemperaturehigh apparenttemperaturelow      1461.0  0.000  1.000
# apparenttemperaturehigh cloudcover                  1461.0 -0.000  1.000
# apparenttemperaturehigh dewpoint                    1461.0 -0.000  1.000
# apparenttemperaturehigh humidity                    1461.0 -0.000  1.000
# apparenttemperaturehigh precipaccumulation          1461.0  0.000  1.000
# apparenttemperaturehigh precipintensitymax          1461.0 -0.000  1.000
# apparenttemperaturehigh precipprobability           1461.0 -0.000  1.000
# apparenttemperaturehigh rain                        1461.0  0.000  1.000
# apparenttemperaturehigh snow                        1461.0 -0.000  1.000
# apparenttemperaturehigh visibility                  1461.0 -0.000  1.000
# apparenttemperaturehigh windspeed                   1461.0 -0.000  1.000
# apparenttemperaturehigh us_holiday                  1461.0 -0.000  1.000
# apparenttemperaturehigh nats_single                 1461.0 -0.000  1.000
# apparenttemperaturehigh nats_double                 1461.0 -0.000  1.000
# apparenttemperaturehigh dc_bike_event               1461.0  0.000  1.000
# apparenttemperaturehigh dc_pop                      1461.0  0.000  1.000
# apparenttemperaturehigh cabi_bikes_avail            1461.0  0.000  1.000
# apparenttemperaturehigh cabi_stations_alx           1461.0  0.000  1.000
# apparenttemperaturehigh cabi_stations_arl           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_stations_ffx           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_stations_mcn           1461.0  0.000  1.000
# apparenttemperaturehigh cabi_stations_mcs           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_stations_wdc           1461.0  0.000  1.000
# apparenttemperaturehigh cabi_docks_alx              1461.0  0.000  1.000
# apparenttemperaturehigh cabi_docks_arl              1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_docks_ffx              1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_docks_mcn              1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_docks_mcs              1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_docks_wdc              1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_stations_tot           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_docks_tot              1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_empty_wdc          1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_full_wdc           1461.0  0.000  1.000
# apparenttemperaturehigh cabi_dur_empty_arl          1461.0  0.000  1.000
# apparenttemperaturehigh cabi_dur_full_arl           1461.0  0.000  1.000
# apparenttemperaturehigh cabi_dur_full_alx           1461.0  0.000  1.000
# apparenttemperaturehigh cabi_dur_empty_alx          1461.0  0.000  1.000
# apparenttemperaturehigh cabi_dur_empty_mcs          1461.0  0.000  1.000
# apparenttemperaturehigh cabi_dur_full_mcs           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_full_mcn           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_empty_mcn          1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_full_ffx           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_empty_tot          1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_dur_full_tot           1461.0 -0.000  1.000
# apparenttemperaturehigh cabi_active_members_day...  1461.0  0.000  1.000
# apparenttemperaturehigh cabi_active_members_mon...  1461.0  0.000  1.000
# apparenttemperaturehigh cabi_active_members_annual  1461.0  0.000  1.000
# apparenttemperaturehigh sin_day_of_year             1461.0 -0.000  1.000
# apparenttemperaturehigh cos_day_of_year             1461.0  0.000  1.000
# apparenttemperaturelow^2                            1461.0 -0.000  1.000
# apparenttemperaturelow cloudcover                   1461.0  0.000  1.000
# apparenttemperaturelow dewpoint                     1461.0  0.000  1.000
# apparenttemperaturelow humidity                     1461.0 -0.000  1.000
# apparenttemperaturelow precipaccumulation           1461.0  0.000  1.000
# apparenttemperaturelow precipintensitymax           1461.0 -0.000  1.000
# apparenttemperaturelow precipprobability            1461.0  0.000  1.000
# apparenttemperaturelow rain                         1461.0  0.000  1.000
# apparenttemperaturelow snow                         1461.0  0.000  1.000
# apparenttemperaturelow visibility                   1461.0 -0.000  1.000
# apparenttemperaturelow windspeed                    1461.0 -0.000  1.000
# apparenttemperaturelow us_holiday                   1461.0 -0.000  1.000
# apparenttemperaturelow nats_single                  1461.0 -0.000  1.000
# apparenttemperaturelow nats_double                  1461.0  0.000  1.000
# apparenttemperaturelow dc_bike_event                1461.0 -0.000  1.000
# apparenttemperaturelow dc_pop                       1461.0  0.000  1.000
# apparenttemperaturelow cabi_bikes_avail             1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_alx            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_arl            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_ffx            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_mcn            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_mcs            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_wdc            1461.0  0.000  1.000
# apparenttemperaturelow cabi_docks_alx               1461.0  0.000  1.000
# apparenttemperaturelow cabi_docks_arl               1461.0 -0.000  1.000
# apparenttemperaturelow cabi_docks_ffx               1461.0 -0.000  1.000
# apparenttemperaturelow cabi_docks_mcn               1461.0 -0.000  1.000
# apparenttemperaturelow cabi_docks_mcs               1461.0 -0.000  1.000
# apparenttemperaturelow cabi_docks_wdc               1461.0 -0.000  1.000
# apparenttemperaturelow cabi_stations_tot            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_docks_tot               1461.0 -0.000  1.000
# apparenttemperaturelow cabi_dur_empty_wdc           1461.0 -0.000  1.000
# apparenttemperaturelow cabi_dur_full_wdc            1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_empty_arl           1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_full_arl            1461.0 -0.000  1.000
# apparenttemperaturelow cabi_dur_full_alx            1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_empty_alx           1461.0 -0.000  1.000
# apparenttemperaturelow cabi_dur_empty_mcs           1461.0 -0.000  1.000
# apparenttemperaturelow cabi_dur_full_mcs            1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_full_mcn            1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_empty_mcn           1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_full_ffx            1461.0  0.000  1.000
# apparenttemperaturelow cabi_dur_empty_tot           1461.0 -0.000  1.000
# apparenttemperaturelow cabi_dur_full_tot            1461.0  0.000  1.000
# apparenttemperaturelow cabi_active_members_day_key  1461.0  0.000  1.000
# apparenttemperaturelow cabi_active_members_monthly  1461.0 -0.000  1.000
# apparenttemperaturelow cabi_active_members_annual   1461.0 -0.000  1.000
# apparenttemperaturelow sin_day_of_year              1461.0 -0.000  1.000
# apparenttemperaturelow cos_day_of_year              1461.0  0.000  1.000
# cloudcover^2                                        1461.0  0.000  1.000
# cloudcover dewpoint                                 1461.0  0.000  1.000
# cloudcover humidity                                 1461.0 -0.000  1.000
# cloudcover precipaccumulation                       1461.0 -0.000  1.000
# cloudcover precipintensitymax                       1461.0  0.000  1.000
# cloudcover precipprobability                        1461.0 -0.000  1.000
# cloudcover rain                                     1461.0 -0.000  1.000
# cloudcover snow                                     1461.0 -0.000  1.000
# cloudcover visibility                               1461.0 -0.000  1.000
# cloudcover windspeed                                1461.0 -0.000  1.000
# cloudcover us_holiday                               1461.0  0.000  1.000
# cloudcover nats_single                              1461.0  0.000  1.000
# cloudcover nats_double                              1461.0  0.000  1.000
# cloudcover dc_bike_event                            1461.0  0.000  1.000
# cloudcover dc_pop                                   1461.0 -0.000  1.000
# cloudcover cabi_bikes_avail                         1461.0 -0.000  1.000
# cloudcover cabi_stations_alx                        1461.0  0.000  1.000
# cloudcover cabi_stations_arl                        1461.0  0.000  1.000
# cloudcover cabi_stations_ffx                        1461.0 -0.000  1.000
# cloudcover cabi_stations_mcn                        1461.0  0.000  1.000
# cloudcover cabi_stations_mcs                        1461.0  0.000  1.000
# cloudcover cabi_stations_wdc                        1461.0 -0.000  1.000
# cloudcover cabi_docks_alx                           1461.0 -0.000  1.000
# cloudcover cabi_docks_arl                           1461.0  0.000  1.000
# cloudcover cabi_docks_ffx                           1461.0  0.000  1.000
# cloudcover cabi_docks_mcn                           1461.0 -0.000  1.000
# cloudcover cabi_docks_mcs                           1461.0 -0.000  1.000
# cloudcover cabi_docks_wdc                           1461.0 -0.000  1.000
# cloudcover cabi_stations_tot                        1461.0  0.000  1.000
# cloudcover cabi_docks_tot                           1461.0  0.000  1.000
# cloudcover cabi_dur_empty_wdc                       1461.0  0.000  1.000
# cloudcover cabi_dur_full_wdc                        1461.0  0.000  1.000
# cloudcover cabi_dur_empty_arl                       1461.0  0.000  1.000
# cloudcover cabi_dur_full_arl                        1461.0  0.000  1.000
# cloudcover cabi_dur_full_alx                        1461.0  0.000  1.000
# cloudcover cabi_dur_empty_alx                       1461.0  0.000  1.000
# cloudcover cabi_dur_empty_mcs                       1461.0 -0.000  1.000
# cloudcover cabi_dur_full_mcs                        1461.0 -0.000  1.000
# cloudcover cabi_dur_full_mcn                        1461.0 -0.000  1.000
# cloudcover cabi_dur_empty_mcn                       1461.0 -0.000  1.000
# cloudcover cabi_dur_full_ffx                        1461.0 -0.000  1.000
# cloudcover cabi_dur_empty_tot                       1461.0  0.000  1.000
# cloudcover cabi_dur_full_tot                        1461.0  0.000  1.000
# cloudcover cabi_active_members_day_key              1461.0 -0.000  1.000
# cloudcover cabi_active_members_monthly              1461.0 -0.000  1.000
# cloudcover cabi_active_members_annual               1461.0  0.000  1.000
# cloudcover sin_day_of_year                          1461.0  0.000  1.000
# cloudcover cos_day_of_year                          1461.0  0.000  1.000
# dewpoint^2                                          1461.0  0.000  1.000
# dewpoint humidity                                   1461.0  0.000  1.000
# dewpoint precipaccumulation                         1461.0 -0.000  1.000
# dewpoint precipintensitymax                         1461.0 -0.000  1.000
# dewpoint precipprobability                          1461.0 -0.000  1.000
# dewpoint rain                                       1461.0  0.000  1.000
# dewpoint snow                                       1461.0  0.000  1.000
# dewpoint visibility                                 1461.0 -0.000  1.000
# dewpoint windspeed                                  1461.0 -0.000  1.000
# dewpoint us_holiday                                 1461.0 -0.000  1.000
# dewpoint nats_single                                1461.0  0.000  1.000
# dewpoint nats_double                                1461.0 -0.000  1.000
# dewpoint dc_bike_event                              1461.0 -0.000  1.000
# dewpoint dc_pop                                     1461.0 -0.000  1.000
# dewpoint cabi_bikes_avail                           1461.0 -0.000  1.000
# dewpoint cabi_stations_alx                          1461.0  0.000  1.000
# dewpoint cabi_stations_arl                          1461.0 -0.000  1.000
# dewpoint cabi_stations_ffx                          1461.0  0.000  1.000
# dewpoint cabi_stations_mcn                          1461.0 -0.000  1.000
# dewpoint cabi_stations_mcs                          1461.0  0.000  1.000
# dewpoint cabi_stations_wdc                          1461.0  0.000  1.000
# dewpoint cabi_docks_alx                             1461.0 -0.000  1.000
# dewpoint cabi_docks_arl                             1461.0 -0.000  1.000
# dewpoint cabi_docks_ffx                             1461.0  0.000  1.000
# dewpoint cabi_docks_mcn                             1461.0  0.000  1.000
# dewpoint cabi_docks_mcs                             1461.0 -0.000  1.000
# dewpoint cabi_docks_wdc                             1461.0 -0.000  1.000
# dewpoint cabi_stations_tot                          1461.0 -0.000  1.000
# dewpoint cabi_docks_tot                             1461.0 -0.000  1.000
# dewpoint cabi_dur_empty_wdc                         1461.0  0.000  1.000
# dewpoint cabi_dur_full_wdc                          1461.0 -0.000  1.000
# dewpoint cabi_dur_empty_arl                         1461.0  0.000  1.000
# dewpoint cabi_dur_full_arl                          1461.0 -0.000  1.000
# dewpoint cabi_dur_full_alx                          1461.0 -0.000  1.000
# dewpoint cabi_dur_empty_alx                         1461.0  0.000  1.000
# dewpoint cabi_dur_empty_mcs                         1461.0 -0.000  1.000
# dewpoint cabi_dur_full_mcs                          1461.0 -0.000  1.000
# dewpoint cabi_dur_full_mcn                          1461.0  0.000  1.000
# dewpoint cabi_dur_empty_mcn                         1461.0  0.000  1.000
# dewpoint cabi_dur_full_ffx                          1461.0 -0.000  1.000
# dewpoint cabi_dur_empty_tot                         1461.0  0.000  1.000
# dewpoint cabi_dur_full_tot                          1461.0 -0.000  1.000
# dewpoint cabi_active_members_day_key                1461.0  0.000  1.000
# dewpoint cabi_active_members_monthly                1461.0  0.000  1.000
# dewpoint cabi_active_members_annual                 1461.0  0.000  1.000
# dewpoint sin_day_of_year                            1461.0 -0.000  1.000
# dewpoint cos_day_of_year                            1461.0 -0.000  1.000
# humidity^2                                          1461.0  0.000  1.000
# humidity precipaccumulation                         1461.0  0.000  1.000
# humidity precipintensitymax                         1461.0  0.000  1.000
# humidity precipprobability                          1461.0  0.000  1.000
# humidity rain                                       1461.0  0.000  1.000
# humidity snow                                       1461.0 -0.000  1.000
# humidity visibility                                 1461.0 -0.000  1.000
# humidity windspeed                                  1461.0  0.000  1.000
# humidity us_holiday                                 1461.0  0.000  1.000
# humidity nats_single                                1461.0  0.000  1.000
# humidity nats_double                                1461.0  0.000  1.000
# humidity dc_bike_event                              1461.0  0.000  1.000
# humidity dc_pop                                     1461.0  0.000  1.000
# humidity cabi_bikes_avail                           1461.0 -0.000  1.000
# humidity cabi_stations_alx                          1461.0  0.000  1.000
# humidity cabi_stations_arl                          1461.0 -0.000  1.000
# humidity cabi_stations_ffx                          1461.0 -0.000  1.000
# humidity cabi_stations_mcn                          1461.0 -0.000  1.000
# humidity cabi_stations_mcs                          1461.0  0.000  1.000
# humidity cabi_stations_wdc                          1461.0  0.000  1.000
# humidity cabi_docks_alx                             1461.0  0.000  1.000
# humidity cabi_docks_arl                             1461.0  0.000  1.000
# humidity cabi_docks_ffx                             1461.0 -0.000  1.000
# humidity cabi_docks_mcn                             1461.0  0.000  1.000
# humidity cabi_docks_mcs                             1461.0  0.000  1.000
# humidity cabi_docks_wdc                             1461.0 -0.000  1.000
# humidity cabi_stations_tot                          1461.0 -0.000  1.000
# humidity cabi_docks_tot                             1461.0 -0.000  1.000
# humidity cabi_dur_empty_wdc                         1461.0  0.000  1.000
# humidity cabi_dur_full_wdc                          1461.0  0.000  1.000
# humidity cabi_dur_empty_arl                         1461.0 -0.000  1.000
# humidity cabi_dur_full_arl                          1461.0  0.000  1.000
# humidity cabi_dur_full_alx                          1461.0  0.000  1.000
# humidity cabi_dur_empty_alx                         1461.0 -0.000  1.000
# humidity cabi_dur_empty_mcs                         1461.0  0.000  1.000
# humidity cabi_dur_full_mcs                          1461.0 -0.000  1.000
# humidity cabi_dur_full_mcn                          1461.0 -0.000  1.000
# humidity cabi_dur_empty_mcn                         1461.0 -0.000  1.000
# humidity cabi_dur_full_ffx                          1461.0 -0.000  1.000
# humidity cabi_dur_empty_tot                         1461.0 -0.000  1.000
# humidity cabi_dur_full_tot                          1461.0  0.000  1.000
# humidity cabi_active_members_day_key                1461.0 -0.000  1.000
# humidity cabi_active_members_monthly                1461.0  0.000  1.000
# humidity cabi_active_members_annual                 1461.0 -0.000  1.000
# humidity sin_day_of_year                            1461.0  0.000  1.000
# humidity cos_day_of_year                            1461.0  0.000  1.000
# precipaccumulation^2                                1461.0  0.000  1.000
# precipaccumulation precipintensitymax               1461.0  0.000  1.000
# precipaccumulation precipprobability                1461.0 -0.000  1.000
# precipaccumulation rain                             1461.0  0.000  0.000
# precipaccumulation snow                             1461.0  0.000  1.000
# precipaccumulation visibility                       1461.0  0.000  1.000
# precipaccumulation windspeed                        1461.0  0.000  1.000
# precipaccumulation us_holiday                       1461.0 -0.000  1.000
# precipaccumulation nats_single                      1461.0  0.000  0.000
# precipaccumulation nats_double                      1461.0  0.000  0.000
# precipaccumulation dc_bike_event                    1461.0  0.000  0.000
# precipaccumulation dc_pop                           1461.0  0.000  1.000
# precipaccumulation cabi_bikes_avail                 1461.0  0.000  1.000
# precipaccumulation cabi_stations_alx                1461.0 -0.000  1.000
# precipaccumulation cabi_stations_arl                1461.0 -0.000  1.000
# precipaccumulation cabi_stations_ffx                1461.0 -0.000  1.000
# precipaccumulation cabi_stations_mcn                1461.0 -0.000  1.000
# precipaccumulation cabi_stations_mcs                1461.0 -0.000  1.000
# precipaccumulation cabi_stations_wdc                1461.0 -0.000  1.000
# precipaccumulation cabi_docks_alx                   1461.0 -0.000  1.000
# precipaccumulation cabi_docks_arl                   1461.0  0.000  1.000
# precipaccumulation cabi_docks_ffx                   1461.0 -0.000  1.000
# precipaccumulation cabi_docks_mcn                   1461.0 -0.000  1.000
# precipaccumulation cabi_docks_mcs                   1461.0 -0.000  1.000
# precipaccumulation cabi_docks_wdc                   1461.0  0.000  1.000
# precipaccumulation cabi_stations_tot                1461.0 -0.000  1.000
# precipaccumulation cabi_docks_tot                   1461.0 -0.000  1.000
# precipaccumulation cabi_dur_empty_wdc               1461.0 -0.000  1.000
# precipaccumulation cabi_dur_full_wdc                1461.0  0.000  1.000
# precipaccumulation cabi_dur_empty_arl               1461.0  0.000  1.000
# precipaccumulation cabi_dur_full_arl                1461.0 -0.000  1.000
# precipaccumulation cabi_dur_full_alx                1461.0 -0.000  1.000
# precipaccumulation cabi_dur_empty_alx               1461.0  0.000  1.000
# precipaccumulation cabi_dur_empty_mcs               1461.0 -0.000  1.000
# precipaccumulation cabi_dur_full_mcs                1461.0 -0.000  1.000
# precipaccumulation cabi_dur_full_mcn                1461.0  0.000  1.000
# precipaccumulation cabi_dur_empty_mcn               1461.0 -0.000  1.000
# precipaccumulation cabi_dur_full_ffx                1461.0  0.000  0.000
# precipaccumulation cabi_dur_empty_ffx               1461.0  0.000  0.000
# precipaccumulation cabi_dur_empty_tot               1461.0 -0.000  1.000
# precipaccumulation cabi_dur_full_tot                1461.0 -0.000  1.000
# precipaccumulation cabi_active_members_day_key      1461.0  0.000  1.000
# precipaccumulation cabi_active_members_monthly      1461.0  0.000  1.000
# precipaccumulation cabi_active_members_annual       1461.0  0.000  1.000
# precipaccumulation sin_day_of_year                  1461.0 -0.000  1.000
# precipaccumulation cos_day_of_year                  1461.0  0.000  1.000
# precipintensitymax^2                                1461.0 -0.000  1.000
# precipintensitymax precipprobability                1461.0 -0.000  1.000
# precipintensitymax rain                             1461.0  0.000  1.000
# precipintensitymax snow                             1461.0 -0.000  1.000
# precipintensitymax visibility                       1461.0  0.000  1.000
# precipintensitymax windspeed                        1461.0  0.000  1.000
# precipintensitymax us_holiday                       1461.0  0.000  1.000
# precipintensitymax nats_single                      1461.0 -0.000  1.000
# precipintensitymax nats_double                      1461.0  0.000  1.000
# precipintensitymax dc_bike_event                    1461.0 -0.000  1.000
# precipintensitymax dc_pop                           1461.0  0.000  1.000
# precipintensitymax cabi_bikes_avail                 1461.0  0.000  1.000
# precipintensitymax cabi_stations_alx                1461.0  0.000  1.000
# precipintensitymax cabi_stations_arl                1461.0 -0.000  1.000
# precipintensitymax cabi_stations_ffx                1461.0 -0.000  1.000
# precipintensitymax cabi_stations_mcn                1461.0  0.000  1.000
# precipintensitymax cabi_stations_mcs                1461.0 -0.000  1.000
# precipintensitymax cabi_stations_wdc                1461.0 -0.000  1.000
# precipintensitymax cabi_docks_alx                   1461.0  0.000  1.000
# precipintensitymax cabi_docks_arl                   1461.0  0.000  1.000
# precipintensitymax cabi_docks_ffx                   1461.0  0.000  1.000
# precipintensitymax cabi_docks_mcn                   1461.0 -0.000  1.000
# precipintensitymax cabi_docks_mcs                   1461.0 -0.000  1.000
# precipintensitymax cabi_docks_wdc                   1461.0 -0.000  1.000
# precipintensitymax cabi_stations_tot                1461.0 -0.000  1.000
# precipintensitymax cabi_docks_tot                   1461.0  0.000  1.000
# precipintensitymax cabi_dur_empty_wdc               1461.0 -0.000  1.000
# precipintensitymax cabi_dur_full_wdc                1461.0 -0.000  1.000
# precipintensitymax cabi_dur_empty_arl               1461.0  0.000  1.000
# precipintensitymax cabi_dur_full_arl                1461.0  0.000  1.000
# precipintensitymax cabi_dur_full_alx                1461.0  0.000  1.000
# precipintensitymax cabi_dur_empty_alx               1461.0  0.000  1.000
# precipintensitymax cabi_dur_empty_mcs               1461.0 -0.000  1.000
# precipintensitymax cabi_dur_full_mcs                1461.0  0.000  1.000
# precipintensitymax cabi_dur_full_mcn                1461.0 -0.000  1.000
# precipintensitymax cabi_dur_empty_mcn               1461.0 -0.000  1.000
# precipintensitymax cabi_dur_empty_tot               1461.0  0.000  1.000
# precipintensitymax cabi_dur_full_tot                1461.0 -0.000  1.000
# precipintensitymax cabi_active_members_day_key      1461.0  0.000  1.000
# precipintensitymax cabi_active_members_monthly      1461.0 -0.000  1.000
# precipintensitymax cabi_active_members_annual       1461.0 -0.000  1.000
# precipintensitymax sin_day_of_year                  1461.0 -0.000  1.000
# precipintensitymax cos_day_of_year                  1461.0  0.000  1.000
# precipprobability^2                                 1461.0 -0.000  1.000
# precipprobability rain                              1461.0  0.000  1.000
# precipprobability snow                              1461.0  0.000  1.000
# precipprobability visibility                        1461.0 -0.000  1.000
# precipprobability windspeed                         1461.0 -0.000  1.000
# precipprobability us_holiday                        1461.0  0.000  1.000
# precipprobability nats_single                       1461.0 -0.000  1.000
# precipprobability nats_double                       1461.0 -0.000  1.000
# precipprobability dc_bike_event                     1461.0 -0.000  1.000
# precipprobability dc_pop                            1461.0 -0.000  1.000
# precipprobability cabi_bikes_avail                  1461.0  0.000  1.000
# precipprobability cabi_stations_alx                 1461.0 -0.000  1.000
# precipprobability cabi_stations_arl                 1461.0 -0.000  1.000
# precipprobability cabi_stations_ffx                 1461.0 -0.000  1.000
# precipprobability cabi_stations_mcn                 1461.0 -0.000  1.000
# precipprobability cabi_stations_mcs                 1461.0  0.000  1.000
# precipprobability cabi_stations_wdc                 1461.0  0.000  1.000
# precipprobability cabi_docks_alx                    1461.0  0.000  1.000
# precipprobability cabi_docks_arl                    1461.0 -0.000  1.000
# precipprobability cabi_docks_ffx                    1461.0  0.000  1.000
# precipprobability cabi_docks_mcn                    1461.0  0.000  1.000
# precipprobability cabi_docks_mcs                    1461.0  0.000  1.000
# precipprobability cabi_docks_wdc                    1461.0  0.000  1.000
# precipprobability cabi_stations_tot                 1461.0  0.000  1.000
# precipprobability cabi_docks_tot                    1461.0 -0.000  1.000
# precipprobability cabi_dur_empty_wdc                1461.0  0.000  1.000
# precipprobability cabi_dur_full_wdc                 1461.0 -0.000  1.000
# precipprobability cabi_dur_empty_arl                1461.0 -0.000  1.000
# precipprobability cabi_dur_full_arl                 1461.0 -0.000  1.000
# precipprobability cabi_dur_full_alx                 1461.0 -0.000  1.000
# precipprobability cabi_dur_empty_alx                1461.0 -0.000  1.000
# precipprobability cabi_dur_empty_mcs                1461.0  0.000  1.000
# precipprobability cabi_dur_full_mcs                 1461.0  0.000  1.000
# precipprobability cabi_dur_full_mcn                 1461.0  0.000  1.000
# precipprobability cabi_dur_empty_mcn                1461.0  0.000  1.000
# precipprobability cabi_dur_empty_tot                1461.0  0.000  1.000
# precipprobability cabi_dur_full_tot                 1461.0  0.000  1.000
# precipprobability cabi_active_members_day_key       1461.0  0.000  1.000
# precipprobability cabi_active_members_monthly       1461.0 -0.000  1.000
# precipprobability cabi_active_members_annual        1461.0 -0.000  1.000
# precipprobability sin_day_of_year                   1461.0  0.000  1.000
# precipprobability cos_day_of_year                   1461.0 -0.000  1.000
# rain snow                                           1461.0  0.000  0.000
# rain visibility                                     1461.0  0.000  1.000
# rain windspeed                                      1461.0  0.000  1.000
# rain dc_pop                                         1461.0 -0.000  1.000
# rain cabi_bikes_avail                               1461.0  0.000  1.000
# rain cabi_stations_alx                              1461.0  0.000  1.000
# rain cabi_stations_arl                              1461.0 -0.000  1.000
# rain cabi_stations_ffx                              1461.0 -0.000  1.000
# rain cabi_stations_mcn                              1461.0 -0.000  1.000
# rain cabi_stations_mcs                              1461.0 -0.000  1.000
# rain cabi_stations_wdc                              1461.0 -0.000  1.000
# rain cabi_docks_alx                                 1461.0 -0.000  1.000
# rain cabi_docks_arl                                 1461.0  0.000  1.000
# rain cabi_docks_ffx                                 1461.0 -0.000  1.000
# rain cabi_docks_mcn                                 1461.0 -0.000  1.000
# rain cabi_docks_mcs                                 1461.0 -0.000  1.000
# rain cabi_docks_wdc                                 1461.0 -0.000  1.000
# rain cabi_stations_tot                              1461.0  0.000  1.000
# rain cabi_docks_tot                                 1461.0 -0.000  1.000
# rain cabi_dur_empty_wdc                             1461.0  0.000  1.000
# rain cabi_dur_full_wdc                              1461.0  0.000  1.000
# rain cabi_dur_empty_arl                             1461.0  0.000  1.000
# rain cabi_dur_full_arl                              1461.0 -0.000  1.000
# rain cabi_dur_full_alx                              1461.0 -0.000  1.000
# rain cabi_dur_empty_alx                             1461.0  0.000  1.000
# rain cabi_dur_empty_mcs                             1461.0 -0.000  1.000
# rain cabi_dur_full_mcs                              1461.0 -0.000  1.000
# rain cabi_dur_full_mcn                              1461.0  0.000  1.000
# rain cabi_dur_empty_mcn                             1461.0 -0.000  1.000
# rain cabi_dur_empty_tot                             1461.0  0.000  1.000
# rain cabi_dur_full_tot                              1461.0 -0.000  1.000
# rain cabi_active_members_day_key                    1461.0 -0.000  1.000
# rain cabi_active_members_monthly                    1461.0  0.000  1.000
# rain cabi_active_members_annual                     1461.0  0.000  1.000
# rain sin_day_of_year                                1461.0 -0.000  1.000
# rain cos_day_of_year                                1461.0  0.000  1.000
# snow visibility                                     1461.0  0.000  1.000
# snow windspeed                                      1461.0  0.000  1.000
# snow nats_single                                    1461.0  0.000  0.000
# snow nats_double                                    1461.0  0.000  0.000
# snow dc_bike_event                                  1461.0  0.000  0.000
# snow dc_pop                                         1461.0 -0.000  1.000
# snow cabi_bikes_avail                               1461.0 -0.000  1.000
# snow cabi_stations_alx                              1461.0 -0.000  1.000
# snow cabi_stations_arl                              1461.0 -0.000  1.000
# snow cabi_stations_mcn                              1461.0 -0.000  1.000
# snow cabi_stations_mcs                              1461.0  0.000  1.000
# snow cabi_stations_wdc                              1461.0 -0.000  1.000
# snow cabi_docks_alx                                 1461.0  0.000  1.000
# snow cabi_docks_arl                                 1461.0  0.000  1.000
# snow cabi_docks_mcn                                 1461.0  0.000  1.000
# snow cabi_docks_mcs                                 1461.0 -0.000  1.000
# snow cabi_docks_wdc                                 1461.0  0.000  1.000
# snow cabi_stations_tot                              1461.0 -0.000  1.000
# snow cabi_docks_tot                                 1461.0 -0.000  1.000
# snow cabi_dur_empty_wdc                             1461.0  0.000  1.000
# snow cabi_dur_full_wdc                              1461.0  0.000  1.000
# snow cabi_dur_empty_arl                             1461.0  0.000  1.000
# snow cabi_dur_full_arl                              1461.0  0.000  1.000
# snow cabi_dur_full_alx                              1461.0  0.000  1.000
# snow cabi_dur_empty_alx                             1461.0 -0.000  1.000
# snow cabi_dur_empty_mcs                             1461.0 -0.000  1.000
# snow cabi_dur_full_mcs                              1461.0 -0.000  1.000
# snow cabi_dur_full_mcn                              1461.0  0.000  1.000
# snow cabi_dur_empty_mcn                             1461.0 -0.000  1.000
# snow cabi_dur_full_ffx                              1461.0  0.000  0.000
# snow cabi_dur_empty_ffx                             1461.0  0.000  0.000
# snow cabi_dur_empty_tot                             1461.0 -0.000  1.000
# snow cabi_dur_full_tot                              1461.0  0.000  1.000
# snow cabi_active_members_day_key                    1461.0  0.000  1.000
# snow cabi_active_members_monthly                    1461.0  0.000  1.000
# snow cabi_active_members_annual                     1461.0 -0.000  1.000
# snow sin_day_of_year                                1461.0 -0.000  1.000
# snow cos_day_of_year                                1461.0  0.000  1.000
# visibility^2                                        1461.0  0.000  1.000
# visibility windspeed                                1461.0 -0.000  1.000
# visibility us_holiday                               1461.0  0.000  1.000
# visibility nats_single                              1461.0  0.000  1.000
# visibility nats_double                              1461.0  0.000  1.000
# visibility dc_bike_event                            1461.0 -0.000  1.000
# visibility dc_pop                                   1461.0  0.000  1.000
# visibility cabi_bikes_avail                         1461.0 -0.000  1.000
# visibility cabi_stations_alx                        1461.0  0.000  1.000
# visibility cabi_stations_arl                        1461.0  0.000  1.000
# visibility cabi_stations_ffx                        1461.0 -0.000  1.000
# visibility cabi_stations_mcn                        1461.0  0.000  1.000
# visibility cabi_stations_mcs                        1461.0 -0.000  1.000
# visibility cabi_stations_wdc                        1461.0  0.000  1.000
# visibility cabi_docks_alx                           1461.0  0.000  1.000
# visibility cabi_docks_arl                           1461.0 -0.000  1.000
# visibility cabi_docks_ffx                           1461.0 -0.000  1.000
# visibility cabi_docks_mcn                           1461.0 -0.000  1.000
# visibility cabi_docks_mcs                           1461.0 -0.000  1.000
# visibility cabi_docks_wdc                           1461.0  0.000  1.000
# visibility cabi_stations_tot                        1461.0 -0.000  1.000
# visibility cabi_docks_tot                           1461.0 -0.000  1.000
# visibility cabi_dur_empty_wdc                       1461.0 -0.000  1.000
# visibility cabi_dur_full_wdc                        1461.0 -0.000  1.000
# visibility cabi_dur_empty_arl                       1461.0  0.000  1.000
# ...
# cabi_stations_tot cabi_dur_empty_arl                -0.951 -0.329   4.616
# cabi_stations_tot cabi_dur_full_arl                 -0.964 -0.294  13.298
# cabi_stations_tot cabi_dur_full_alx                 -0.615 -0.438  10.151
# cabi_stations_tot cabi_dur_empty_alx                -0.511 -0.511  10.210
# cabi_stations_tot cabi_dur_empty_mcs                -0.487 -0.487   9.811
# cabi_stations_tot cabi_dur_full_mcs                 -0.269 -0.269  27.480
# cabi_stations_tot cabi_dur_full_mcn                 -0.080 -0.080  33.179
# cabi_stations_tot cabi_dur_empty_mcn                -0.148 -0.148  30.544
# cabi_stations_tot cabi_dur_full_ffx                 -0.031 -0.031  37.303
# cabi_stations_tot cabi_dur_empty_tot                -1.426 -0.166   3.470
# cabi_stations_tot cabi_dur_full_tot                 -1.377 -0.224   6.121
# cabi_stations_tot cabi_active_members_day_key       -1.155 -0.257   2.442
# cabi_stations_tot cabi_active_members_monthly       -1.254 -0.184   2.834
# cabi_stations_tot cabi_active_members_annual        -1.989  0.241   1.915
# cabi_stations_tot sin_day_of_year                   -1.709  0.042   1.632
# cabi_stations_tot cos_day_of_year                   -1.671 -0.002   1.834
# cabi_docks_tot^2                                    -1.870  0.228   2.096
# cabi_docks_tot cabi_dur_empty_wdc                   -1.482 -0.137   3.530
# cabi_docks_tot cabi_dur_full_wdc                    -1.388 -0.222   4.011
# cabi_docks_tot cabi_dur_empty_arl                   -0.951 -0.322   4.618
# cabi_docks_tot cabi_dur_full_arl                    -0.965 -0.296  13.320
# cabi_docks_tot cabi_dur_full_alx                    -0.615 -0.436  10.157
# cabi_docks_tot cabi_dur_empty_alx                   -0.511 -0.511  10.218
# cabi_docks_tot cabi_dur_empty_mcs                   -0.486 -0.486   9.810
# cabi_docks_tot cabi_dur_full_mcs                    -0.269 -0.269  27.503
# cabi_docks_tot cabi_dur_full_mcn                    -0.080 -0.080  33.185
# cabi_docks_tot cabi_dur_empty_mcn                   -0.147 -0.147  30.563
# cabi_docks_tot cabi_dur_full_ffx                    -0.031 -0.031  37.303
# cabi_docks_tot cabi_dur_empty_tot                   -1.429 -0.164   3.514
# cabi_docks_tot cabi_dur_full_tot                    -1.381 -0.227   6.138
# cabi_docks_tot cabi_active_members_day_key          -1.153 -0.258   2.432
# cabi_docks_tot cabi_active_members_monthly          -1.247 -0.195   2.840
# cabi_docks_tot cabi_active_members_annual           -1.941  0.233   1.938
# cabi_docks_tot sin_day_of_year                      -1.726  0.039   1.628
# cabi_docks_tot cos_day_of_year                      -1.673 -0.002   1.828
# cabi_dur_empty_wdc^2                                -1.011 -0.287   5.220
# cabi_dur_empty_wdc cabi_dur_full_wdc                -0.990 -0.351   4.195
# cabi_dur_empty_wdc cabi_dur_empty_arl               -0.782 -0.357   5.434
# cabi_dur_empty_wdc cabi_dur_full_arl                -0.760 -0.336  14.201
# cabi_dur_empty_wdc cabi_dur_full_alx                -0.527 -0.435  11.455
# cabi_dur_empty_wdc cabi_dur_empty_alx               -0.434 -0.434  10.940
# cabi_dur_empty_wdc cabi_dur_empty_mcs               -0.421 -0.421  10.682
# cabi_dur_empty_wdc cabi_dur_full_mcs                -0.221 -0.221  30.429
# cabi_dur_empty_wdc cabi_dur_full_mcn                -0.071 -0.071  34.028
# cabi_dur_empty_wdc cabi_dur_empty_mcn               -0.130 -0.130  31.758
# cabi_dur_empty_wdc cabi_dur_full_ffx                -0.034 -0.034  35.612
# cabi_dur_empty_wdc cabi_dur_empty_tot               -0.992 -0.303   4.745
# cabi_dur_empty_wdc cabi_dur_full_tot                -0.984 -0.349   6.100
# cabi_dur_empty_wdc cabi_active_members_day_key      -0.868 -0.389   4.322
# cabi_dur_empty_wdc cabi_active_members_monthly      -1.083 -0.188   3.898
# cabi_dur_empty_wdc cabi_active_members_annual       -1.543 -0.101   3.305
# cabi_dur_empty_wdc sin_day_of_year                  -2.989  0.156   2.784
# cabi_dur_empty_wdc cos_day_of_year                  -2.825  0.297   3.712
# cabi_dur_full_wdc^2                                 -0.857 -0.366   6.847
# cabi_dur_full_wdc cabi_dur_empty_arl                -0.713 -0.366   8.904
# cabi_dur_full_wdc cabi_dur_full_arl                 -0.629 -0.319  23.234
# cabi_dur_full_wdc cabi_dur_full_alx                 -0.463 -0.380  20.238
# cabi_dur_full_wdc cabi_dur_empty_alx                -0.397 -0.397  19.610
# cabi_dur_full_wdc cabi_dur_empty_mcs                -0.370 -0.370  18.809
# cabi_dur_full_wdc cabi_dur_full_mcs                 -0.143 -0.143  35.461
# cabi_dur_full_wdc cabi_dur_full_mcn                 -0.051 -0.051  37.113
# cabi_dur_full_wdc cabi_dur_empty_mcn                -0.089 -0.089  35.693
# cabi_dur_full_wdc cabi_dur_full_ffx                 -0.035 -0.035  33.778
# cabi_dur_full_wdc cabi_dur_empty_tot                -0.957 -0.349   5.579
# cabi_dur_full_wdc cabi_dur_full_tot                 -0.847 -0.358  10.327
# cabi_dur_full_wdc cabi_active_members_day_key       -0.860 -0.412   4.539
# cabi_dur_full_wdc cabi_active_members_monthly       -0.976 -0.301   5.863
# cabi_dur_full_wdc cabi_active_members_annual        -1.426 -0.202   4.007
# cabi_dur_full_wdc sin_day_of_year                   -2.873  0.076   3.566
# cabi_dur_full_wdc cos_day_of_year                   -3.841  0.275   3.075
# cabi_dur_empty_arl^2                                -0.554 -0.390   8.142
# cabi_dur_empty_arl cabi_dur_full_arl                -0.500 -0.323  25.680
# cabi_dur_empty_arl cabi_dur_full_alx                -0.399 -0.366  21.315
# cabi_dur_empty_arl cabi_dur_empty_alx               -0.346 -0.346  20.614
# cabi_dur_empty_arl cabi_dur_empty_mcs               -0.341 -0.341  20.066
# cabi_dur_empty_arl cabi_dur_full_mcs                -0.115 -0.115  36.225
# cabi_dur_empty_arl cabi_dur_full_mcn                -0.046 -0.046  37.261
# cabi_dur_empty_arl cabi_dur_empty_mcn               -0.075 -0.075  36.248
# cabi_dur_empty_arl cabi_dur_full_ffx                -0.033 -0.033  36.244
# cabi_dur_empty_arl cabi_dur_empty_tot               -0.746 -0.360   6.235
# cabi_dur_empty_arl cabi_dur_full_tot                -0.697 -0.360  12.941
# cabi_dur_empty_arl cabi_active_members_day_key      -0.696 -0.459   5.759
# cabi_dur_empty_arl cabi_active_members_monthly      -0.806 -0.334   7.057
# cabi_dur_empty_arl cabi_active_members_annual       -0.972 -0.303   4.695
# cabi_dur_empty_arl sin_day_of_year                  -4.430  0.148   5.268
# cabi_dur_empty_arl cos_day_of_year                  -5.444  0.380   4.287
# cabi_dur_full_arl^2                                 -0.303 -0.212  32.737
# cabi_dur_full_arl cabi_dur_full_alx                 -0.234 -0.214  33.782
# cabi_dur_full_arl cabi_dur_empty_alx                -0.196 -0.196  34.120
# cabi_dur_full_arl cabi_dur_empty_mcs                -0.197 -0.197  34.372
# cabi_dur_full_arl cabi_dur_full_mcs                 -0.059 -0.059  37.980
# cabi_dur_full_arl cabi_dur_full_mcn                 -0.033 -0.033  38.147
# cabi_dur_full_arl cabi_dur_empty_mcn                -0.045 -0.045  37.903
# cabi_dur_full_arl cabi_dur_full_ffx                 -0.030 -0.030  37.761
# cabi_dur_full_arl cabi_dur_empty_ffx                 0.000  0.000   0.000
# cabi_dur_full_arl cabi_dur_empty_tot                -0.708 -0.320  18.472
# cabi_dur_full_arl cabi_dur_full_tot                 -0.533 -0.272  27.950
# cabi_dur_full_arl cabi_active_members_day_key       -0.698 -0.424   7.825
# cabi_dur_full_arl cabi_active_members_monthly       -0.750 -0.335  14.455
# cabi_dur_full_arl cabi_active_members_annual        -0.981 -0.275  13.914
# cabi_dur_full_arl sin_day_of_year                   -3.997  0.093  10.927
# cabi_dur_full_arl cos_day_of_year                  -10.112  0.268   6.692
# cabi_dur_full_alx^2                                 -0.270 -0.260  25.381
# cabi_dur_full_alx cabi_dur_empty_alx                -0.189 -0.189  32.315
# cabi_dur_full_alx cabi_dur_empty_mcs                -0.205 -0.205  31.760
# cabi_dur_full_alx cabi_dur_full_mcs                 -0.058 -0.058  37.866
# cabi_dur_full_alx cabi_dur_full_mcn                 -0.034 -0.034  38.022
# cabi_dur_full_alx cabi_dur_empty_mcn                -0.046 -0.046  37.794
# cabi_dur_full_alx cabi_dur_full_ffx                 -0.035 -0.035  34.593
# cabi_dur_full_alx cabi_dur_empty_tot                -0.505 -0.420  15.026
# cabi_dur_full_alx cabi_dur_full_tot                 -0.409 -0.340  25.257
# cabi_dur_full_alx cabi_active_members_day_key       -0.506 -0.456   9.065
# cabi_dur_full_alx cabi_active_members_monthly       -0.521 -0.442  11.453
# cabi_dur_full_alx cabi_active_members_annual        -0.622 -0.437  10.739
# cabi_dur_full_alx sin_day_of_year                   -7.874  0.118  10.025
# cabi_dur_full_alx cos_day_of_year                   -9.694  0.247   3.363
# cabi_dur_empty_alx^2                                -0.240 -0.240  24.292
# cabi_dur_empty_alx cabi_dur_empty_mcs               -0.168 -0.168  30.586
# cabi_dur_empty_alx cabi_dur_full_mcs                -0.050 -0.050  38.018
# cabi_dur_empty_alx cabi_dur_full_mcn                -0.034 -0.034  38.006
# cabi_dur_empty_alx cabi_dur_empty_mcn               -0.042 -0.042  37.888
# cabi_dur_empty_alx cabi_dur_full_ffx                -0.035 -0.035  33.885
# cabi_dur_empty_alx cabi_dur_empty_ffx                0.000  0.000   0.000
# cabi_dur_empty_alx cabi_dur_empty_tot               -0.417 -0.417  14.212
# cabi_dur_empty_alx cabi_dur_full_tot                -0.354 -0.354  25.115
# cabi_dur_empty_alx cabi_active_members_day_key      -0.433 -0.433  10.093
# cabi_dur_empty_alx cabi_active_members_monthly      -0.457 -0.457  12.284
# cabi_dur_empty_alx cabi_active_members_annual       -0.516 -0.516  10.765
# cabi_dur_empty_alx sin_day_of_year                  -8.838  0.177  10.473
# cabi_dur_empty_alx cos_day_of_year                 -10.098  0.213   6.571
# cabi_dur_empty_mcs^2                                -0.233 -0.233  23.891
# cabi_dur_empty_mcs cabi_dur_full_mcs                -0.056 -0.056  37.690
# cabi_dur_empty_mcs cabi_dur_full_mcn                -0.035 -0.035  37.970
# cabi_dur_empty_mcs cabi_dur_empty_mcn               -0.046 -0.046  37.770
# cabi_dur_empty_mcs cabi_dur_full_ffx                -0.033 -0.033  36.364
# cabi_dur_empty_mcs cabi_dur_empty_ffx                0.000  0.000   0.000
# cabi_dur_empty_mcs cabi_dur_empty_tot               -0.405 -0.405  13.810
# cabi_dur_empty_mcs cabi_dur_full_tot                -0.336 -0.336  24.397
# cabi_dur_empty_mcs cabi_active_members_day_key      -0.422 -0.422   8.419
# cabi_dur_empty_mcs cabi_active_members_monthly      -0.449 -0.449  11.622
# cabi_dur_empty_mcs cabi_active_members_annual       -0.491 -0.491  10.483
# cabi_dur_empty_mcs sin_day_of_year                  -8.025  0.138  10.411
# cabi_dur_empty_mcs cos_day_of_year                 -10.246  0.261   3.801
# cabi_dur_full_mcs^2                                 -0.050 -0.050  37.957
# cabi_dur_full_mcs cabi_dur_full_mcn                 -0.028 -0.028  38.197
# cabi_dur_full_mcs cabi_dur_empty_mcn                -0.030 -0.030  38.192
# cabi_dur_full_mcs cabi_dur_empty_ffx                 0.000  0.000   0.000
# cabi_dur_full_mcs cabi_dur_empty_tot                -0.182 -0.182  33.348
# cabi_dur_full_mcs cabi_dur_full_tot                 -0.111 -0.111  36.791
# cabi_dur_full_mcs cabi_active_members_day_key       -0.287 -0.287  20.354
# cabi_dur_full_mcs cabi_active_members_monthly       -0.206 -0.206  31.208
# cabi_dur_full_mcs cabi_active_members_annual        -0.264 -0.264  28.204
# cabi_dur_full_mcs sin_day_of_year                   -7.116  0.090  28.591
# cabi_dur_full_mcs cos_day_of_year                  -26.506  0.056   5.498
# cabi_dur_full_mcn^2                                 -0.033 -0.033  37.952
# cabi_dur_full_mcn cabi_dur_empty_mcn                -0.028 -0.028  38.192
# cabi_dur_full_mcn cabi_dur_empty_ffx                 0.000  0.000   0.000
# cabi_dur_full_mcn cabi_dur_empty_tot                -0.062 -0.062  35.755
# cabi_dur_full_mcn cabi_dur_full_tot                 -0.044 -0.044  37.652
# cabi_dur_full_mcn cabi_active_members_day_key       -0.093 -0.093  27.450
# cabi_dur_full_mcn cabi_active_members_monthly       -0.068 -0.068  33.004
# cabi_dur_full_mcn cabi_active_members_annual        -0.078 -0.078  33.773
# cabi_dur_full_mcn sin_day_of_year                   -6.402 -0.005  35.888
# cabi_dur_full_mcn cos_day_of_year                  -31.595  0.046   5.902
# cabi_dur_empty_mcn^2                                -0.039 -0.039  38.007
# cabi_dur_empty_mcn cabi_dur_empty_ffx                0.000  0.000   0.000
# cabi_dur_empty_mcn cabi_dur_empty_tot               -0.110 -0.110  34.100
# cabi_dur_empty_mcn cabi_dur_full_tot                -0.072 -0.072  36.910
# cabi_dur_empty_mcn cabi_active_members_day_key      -0.162 -0.162  23.666
# cabi_dur_empty_mcn cabi_active_members_monthly      -0.122 -0.122  31.825
# cabi_dur_empty_mcn cabi_active_members_annual       -0.144 -0.144  31.214
# cabi_dur_empty_mcn sin_day_of_year                  -4.453  0.001  32.795
# cabi_dur_empty_mcn cos_day_of_year                 -29.406  0.073   7.562
# cabi_dur_full_ffx^2                                 -0.027 -0.027  38.163
# cabi_dur_full_ffx cabi_dur_empty_ffx                 0.000  0.000   0.000
# cabi_dur_full_ffx cabi_dur_empty_tot                -0.034 -0.034  35.659
# cabi_dur_full_ffx cabi_dur_full_tot                 -0.034 -0.034  35.547
# cabi_dur_full_ffx cabi_active_members_day_key       -0.031 -0.031  37.299
# cabi_dur_full_ffx cabi_active_members_monthly       -0.031 -0.031  37.299
# cabi_dur_full_ffx cabi_active_members_annual        -0.031 -0.031  37.299
# cabi_dur_full_ffx sin_day_of_year                  -37.202  0.032   0.032
# cabi_dur_full_ffx cos_day_of_year                   -0.031 -0.031  37.597
# cabi_dur_empty_tot^2                                -0.968 -0.298   4.695
# cabi_dur_empty_tot cabi_dur_full_tot                -0.946 -0.332   8.478
# cabi_dur_empty_tot cabi_active_members_day_key      -0.853 -0.391   4.321
# cabi_dur_empty_tot cabi_active_members_monthly      -1.058 -0.202   4.118
# cabi_dur_empty_tot cabi_active_members_annual       -1.486 -0.147   3.307
# cabi_dur_empty_tot sin_day_of_year                  -3.084  0.158   2.759
# cabi_dur_empty_tot cos_day_of_year                  -2.730  0.312   3.536
# cabi_dur_full_tot^2                                 -0.817 -0.344  14.931
# cabi_dur_full_tot cabi_active_members_day_key       -0.858 -0.417   4.215
# cabi_dur_full_tot cabi_active_members_monthly       -0.971 -0.293   6.413
# cabi_dur_full_tot cabi_active_members_annual        -1.419 -0.221   6.483
# cabi_dur_full_tot sin_day_of_year                   -2.906  0.081   4.499
# cabi_dur_full_tot cos_day_of_year                   -4.263  0.280   3.029
# cabi_active_members_day_key^2                       -0.809 -0.460   2.746
# cabi_active_members_day_key cabi_active_members...  -0.882 -0.442   3.096
# cabi_active_members_day_key cabi_active_members...  -1.207 -0.255   2.352
# cabi_active_members_day_key sin_day_of_year         -2.716  0.153   2.201
# cabi_active_members_day_key cos_day_of_year         -2.377 -0.012   2.952
# cabi_active_members_monthly^2                       -0.931 -0.229   3.503
# cabi_active_members_monthly cabi_active_members...  -1.262 -0.172   3.046
# cabi_active_members_monthly sin_day_of_year         -1.952  0.046   2.074
# cabi_active_members_monthly cos_day_of_year         -2.681  0.487   1.373
# cabi_active_members_annual^2                        -1.985  0.230   2.482
# cabi_active_members_annual sin_day_of_year          -1.726  0.035   1.759
# cabi_active_members_annual cos_day_of_year          -1.721  0.007   1.654
# sin_day_of_year^2                                   -1.413 -0.005   1.415
# sin_day_of_year cos_day_of_year                     -1.415 -0.000   1.415
# cos_day_of_year^2                                   -1.415  0.005   1.413

# %% [markdown]
# ### 2. Model Fitting

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import median_absolute_error as medae
from sklearn.metrics import explained_variance_score as evs
from sklearn.metrics import r2_score

# %%
def score_model(model, alpha=False):
    ''' 
    This function fits a model using the training set, predicts using the test set, and then calculates 
    and reports goodness of fit metrics and alpha if specified and available.
    
    All of the model parameters are also reported, which I find extremely useful.
    
    I wanted to include all of the available regression metrics to see how they compare and comove.
    I ran into an ValueError when trying to include MSLE (mean squared log error). 
    Could be related to ln0 being undefined?
    '''
    model.fit(Xtrain, ytrain)
    yhat = model.predict(Xtest)
    r2 = r2_score(ytest, yhat)
    me = mse(ytest, yhat)
    ae = mae(ytest, yhat)
    mede = medae(ytest, yhat)
    ev = evs(ytest, yhat)
    
    if alpha == True:
        print("Results from {}: \nr2={:0.3f} \nMSE={:0.3f} \
              \nMAE={:0.3f} \nMEDAE={:0.3f} \nEVS={:0.3f} \nalpha={:0.3f}".format(model, r2, me, 
                                                                                  ae, mede, ev, model.alpha_))
    else:
        print("Results from {}: \nr2={:0.3f} \nMSE={:0.3f} \
              \nMAE={:0.3f} \nMEDAE={:0.3f} \nEVS={:0.3f}".format(model, r2, me, ae, mede, ev))

# %%
'''Elastic Net'''
from sklearn.linear_model import ElasticNetCV

# Alphas to search over
alphas = np.logspace(-3, 2, 100)

# Suggested l1_ratio from docs
l1_ratio = [.1, .5, .7, .9, .95, .99, 1]

en = ElasticNetCV(l1_ratio=l1_ratio, alphas=alphas, fit_intercept=True, normalize=False)

score_model(en, alpha=True)
print("L1 ratio=",en.l1_ratio_)
# Out:
# C:\Users\slbau\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Results from ElasticNetCV(alphas=array([  1.00000e-03,   1.12332e-03, ...,   8.90215e+01,   1.00000e+02]),
#        copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#        l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=1000,
#        n_alphas=100, n_jobs=1, normalize=False, positive=False,
#        precompute='auto', random_state=None, selection='cyclic',
#        tol=0.0001, verbose=0):
# r2=-1.470
# MSE=23520247.706
# MAE=2313.386
# MEDAE=1282.846
# EVS=-1.455
# alpha=1.918
# L1 ratio= 1.0
# C:\Users\slbau\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
'''Lasso'''
from sklearn.linear_model import LassoCV

lasso = LassoCV(alphas=alphas, fit_intercept=True, normalize=False)
score_model(lasso, alpha=True)
# Out:
# C:\Users\slbau\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Results from LassoCV(alphas=array([  1.00000e-03,   1.12332e-03, ...,   8.90215e+01,   1.00000e+02]),
#     copy_X=True, cv=None, eps=0.001, fit_intercept=True, max_iter=1000,
#     n_alphas=100, n_jobs=1, normalize=False, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=False):
# r2=-1.470
# MSE=23520247.706
# MAE=2313.386
# MEDAE=1282.846
# EVS=-1.455
# alpha=1.918
# C:\Users\slbau\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:484: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
'''Ridge'''
from sklearn.linear_model import RidgeCV

rr = RidgeCV(alphas=alphas, fit_intercept=True, normalize=False)

score_model(rr, alpha=True)
# Out:
# Results from RidgeCV(alphas=array([  1.00000e-03,   1.12332e-03, ...,   8.90215e+01,   1.00000e+02]),
#     cv=None, fit_intercept=True, gcv_mode=None, normalize=False,
#     scoring=None, store_cv_values=False):
# r2=-1702.136
# MSE=16219220553.829
# MAE=28435.599
# MEDAE=1648.543
# EVS=-1674.823
# alpha=62.803

# %%
'''RF'''
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor() 
score_model(rf)
# Out:
# Results from RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False):
# r2=0.830
# MSE=1614735.668
# MAE=976.654
# MEDAE=766.600
# EVS=0.834
