# %% [markdown]
# # CaBi ML fitting - Random Forest
#
# Trying out Random Forest here since it seems so effective and quick to compute.

# %% [markdown]
# ## 0. Data load, shaping, and split
# * Read in data from AWS
# * Encode time variable (day_of_year) as cyclical
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Specify feature and target columns

# %%
# Read in data from AWS

from util_functions import *
import numpy as np
import pandas as pd
import time
start_time = time.perf_counter()

set_env_path()
conn, cur = aws_connect()

# fullquery contains pretty much everything

fullquery = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
year,
quarter,
month,
day_of_week,
daylight_hours,
apparenttemperaturehigh,
apparenttemperaturehightime,
apparenttemperaturelow,
apparenttemperaturelowtime,
precipintensitymaxtime,
sunrisetime,
sunsettime,
cloudcover,
dewpoint,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
nats_attendance,
dc_bike_event,
dc_pop,
cabi_bikes_avail,
cabi_stations_alx,
cabi_stations_arl,
cabi_stations_ffx,
cabi_stations_mcn,
cabi_stations_mcs,
cabi_stations_wdc,
cabi_docks_alx,
cabi_docks_arl,
cabi_docks_ffx,
cabi_docks_mcn,
cabi_docks_mcs,
cabi_docks_wdc,
cabi_stations_tot,
cabi_docks_tot,
cabi_dur_empty_wdc,
cabi_dur_full_wdc,
cabi_dur_empty_arl,
cabi_dur_full_arl,
cabi_dur_full_alx,
cabi_dur_empty_alx,
cabi_dur_empty_mcs,
cabi_dur_full_mcs,
cabi_dur_full_mcn,
cabi_dur_empty_mcn,
cabi_dur_full_ffx,
cabi_dur_empty_ffx,
cabi_dur_empty_tot,
cabi_dur_full_tot,
cabi_active_members_day_key,
cabi_active_members_monthly,
cabi_active_members_annual,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""

query = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
year,
quarter,
month,
day_of_week,
daylight_hours,
apparenttemperaturehigh,
apparenttemperaturehightime,
apparenttemperaturelow,
apparenttemperaturelowtime,
precipintensitymaxtime,
sunrisetime,
sunsettime,
cloudcover,
dewpoint,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
nats_attendance,
dc_bike_event,
dc_pop,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""

pd.options.display.max_rows = None
pd.options.display.max_columns = None

df = pd.read_sql(fullquery, con=conn)

# Setting date to index for easier splitting
df.set_index(df.date, drop=True, inplace=True)
df.index = pd.to_datetime(df.index)

print("We have {} instances and {} features".format(*df.shape))
# Out:
# We have 2780 instances and 64 features

# %%
# Summary statistics

df.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                count         mean         std         min  \
# day_of_year                   2780.0      182.697     107.702       1.000
# year                          2780.0     2014.024       2.228    2010.000
# quarter                       2780.0        2.505       1.140       1.000
# month                         2780.0        6.507       3.522       1.000
# day_of_week                   2780.0        2.999       2.000       0.000
# daylight_hours                2780.0       12.077       2.021       9.000
# apparenttemperaturehigh       2780.0       64.306      20.594       2.240
# apparenttemperaturehightime   2780.0       15.460       2.352       7.000
# cabi_active_members_monthly   2780.0      210.085     134.731      15.000
# cabi_active_members_annual    2780.0    24822.440    8466.934    2148.000
# cabi_trips_wdc_to_wdc         2780.0     6375.501    3185.075       0.000
# cabi_trips_wdc_to_wdc_casual  2780.0     1395.860    1339.656       0.000
#
#                                      50%          max
# day_of_year                      182.000      366.000
# year                            2014.000     2018.000
# quarter                            3.000        4.000
# month                              7.000       12.000
# day_of_week                        3.000        6.000
# daylight_hours                    12.000       15.000
# apparenttemperaturehigh           65.890      113.670
# apparenttemperaturehightime       16.000       19.000
# apparenttemperaturelow            50.885       90.060
# apparenttemperaturelowtime         6.000       23.000
# precipintensitymaxtime            19.000       23.000
# sunrisetime                        6.000        7.000
# sunsettime                        19.000       20.000
# cloudcover                         0.270        1.000
# dewpoint                          46.435       75.840
# humidity                           0.670        0.970
# precipaccumulation                 0.000       21.427
# precipintensitymax                 0.001        1.185
# precipprobability                  0.000        1.000
# rain                               0.000        1.000
# snow                               0.000        1.000
# visibility                         9.790       10.000
# windspeed                          4.850       25.460
# us_holiday                         0.000        1.000
# nats_single                        0.000        1.000
# nats_double                        0.000        1.000
# nats_attendance                    0.000    69925.000
# dc_bike_event                      0.000        1.000
# dc_pop                        665296.583   702021.562
# cabi_bikes_avail                3115.000     4636.000
# cabi_stations_alx                  8.000       31.000
# cabi_stations_arl                 70.000       92.000
# cabi_stations_ffx                  0.000       25.000
# cabi_stations_mcn                 21.000       35.000
# cabi_stations_mcs                 28.000       46.000
# cabi_stations_wdc                193.000      269.000
# cabi_docks_alx                   251.000      650.000
# cabi_docks_arl                  1140.000     1611.000
# cabi_docks_ffx                     0.000      442.000
# cabi_docks_mcn                   498.000      764.000
# cabi_docks_mcs                   537.000      909.000
# cabi_docks_wdc                  4086.000     5839.000
# cabi_stations_tot                320.000      497.000
# cabi_docks_tot                  6512.000    10200.000
# cabi_dur_empty_wdc            766788.500  4059972.000
# cabi_dur_full_wdc             422573.500  2108359.000
# cabi_dur_empty_arl             54818.500  1170040.000
# cabi_dur_full_arl              31039.500   630049.000
# cabi_dur_full_alx                  0.000   311058.000
# cabi_dur_empty_alx                 0.000   388080.000
# cabi_dur_empty_mcs                 0.000   808844.000
# cabi_dur_full_mcs                  0.000   221578.000
# cabi_dur_full_mcn                  0.000   272821.000
# cabi_dur_empty_mcn                 0.000   324429.000
# cabi_dur_full_ffx                  0.000   229986.000
# cabi_dur_empty_ffx                 0.000   260102.000
# cabi_dur_empty_tot            833921.000  5404265.000
# cabi_dur_full_tot             470151.500  3053580.000
# cabi_active_members_day_key     2803.000    16216.000
# cabi_active_members_monthly      209.000      607.000
# cabi_active_members_annual     27873.000    38492.000
# cabi_trips_wdc_to_wdc           6240.000    16608.000
# cabi_trips_wdc_to_wdc_casual    1000.000     9130.000

# %%
def print_highly_correlated(df, features, threshold=0.75):
    """ 
    Prints highly correlated feature pairs in df.
    """
    corr_df = df[features].corr()
    # Select pairs above threshold
    correlated_features = np.where(np.abs(corr_df) > threshold)
    # Avoid duplication
    correlated_features = [(corr_df.iloc[x,y], x, y) for x, y in zip(*correlated_features) if x != y and x < y]
    # Sort by abs(correlation)
    s_corr_list = sorted(correlated_features, key=lambda x: -abs(x[0]))
    print("There are {} feature pairs with pairwise correlation above {}".format(len(s_corr_list), threshold))
    for v, i, j in s_corr_list:
        cols = df[features].columns
        print("{} and {} = {:0.3f}".format(corr_df.index[i], corr_df.columns[j], v))
        
print_highly_correlated(df, df.columns)
# Out:
# There are 163 feature pairs with pairwise correlation above 0.75
# cabi_stations_mcs and cabi_docks_mcs = 1.000
# cabi_stations_tot and cabi_docks_tot = 1.000
# cabi_stations_ffx and cabi_docks_ffx = 0.999
# cabi_stations_wdc and cabi_docks_wdc = 0.999
# cabi_stations_arl and cabi_docks_arl = 0.998
# cabi_stations_mcn and cabi_docks_mcn = 0.997
# day_of_year and month = 0.997
# cabi_stations_wdc and cabi_docks_tot = 0.994
# cabi_stations_wdc and cabi_stations_tot = 0.994
# cabi_docks_wdc and cabi_docks_tot = 0.993
# cabi_dur_empty_wdc and cabi_dur_empty_tot = 0.992
# cabi_bikes_avail and cabi_stations_tot = 0.992
# cabi_dur_full_wdc and cabi_dur_full_tot = 0.992
# cabi_docks_wdc and cabi_stations_tot = 0.991
# cabi_bikes_avail and cabi_docks_tot = 0.991
# cabi_stations_alx and cabi_docks_alx = 0.990
# dc_pop and cabi_docks_arl = 0.989
# cabi_stations_mcn and cabi_stations_mcs = 0.988
# dc_pop and cabi_docks_tot = 0.988
# cabi_bikes_avail and cabi_stations_wdc = 0.988
# dc_pop and cabi_stations_wdc = 0.988
# dc_pop and cabi_docks_wdc = 0.987
# dc_pop and cabi_stations_tot = 0.986
# dc_pop and cabi_bikes_avail = 0.986
# cabi_stations_mcn and cabi_docks_mcs = 0.985
# cabi_bikes_avail and cabi_docks_wdc = 0.984
# year and cabi_docks_tot = 0.984
# year and dc_pop = 0.983
# cabi_stations_mcs and cabi_docks_mcn = 0.983
# dc_pop and cabi_stations_arl = 0.982
# year and cabi_stations_tot = 0.981
# cabi_stations_wdc and cabi_docks_arl = 0.980
# cabi_docks_mcn and cabi_docks_mcs = 0.979
# cabi_bikes_avail and cabi_docks_arl = 0.979
# cabi_docks_arl and cabi_active_members_annual = 0.978
# dc_pop and cabi_active_members_annual = 0.978
# year and cabi_docks_wdc = 0.978
# cabi_bikes_avail and cabi_stations_arl = 0.977
# cabi_stations_arl and cabi_stations_wdc = 0.977
# cabi_docks_arl and cabi_docks_tot = 0.977
# year and cabi_stations_wdc = 0.977
# cabi_docks_arl and cabi_docks_wdc = 0.976
# cabi_docks_arl and cabi_stations_tot = 0.976
# year and cabi_bikes_avail = 0.976
# cabi_stations_arl and cabi_active_members_annual = 0.974
# cabi_stations_arl and cabi_stations_tot = 0.973
# quarter and month = 0.972
# cabi_stations_arl and cabi_docks_tot = 0.972
# cabi_stations_arl and cabi_docks_wdc = 0.970
# day_of_year and quarter = 0.969
# daylight_hours and sunsettime = 0.967
# cabi_docks_mcs and cabi_stations_tot = 0.967
# cabi_stations_wdc and cabi_active_members_annual = 0.966
# cabi_stations_mcs and cabi_stations_tot = 0.966
# cabi_docks_wdc and cabi_active_members_annual = 0.963
# cabi_docks_mcs and cabi_docks_tot = 0.963
# cabi_docks_alx and cabi_docks_tot = 0.961
# cabi_bikes_avail and cabi_active_members_annual = 0.961
# cabi_stations_mcs and cabi_docks_tot = 0.961
# year and cabi_docks_arl = 0.961
# cabi_docks_tot and cabi_active_members_annual = 0.960
# cabi_bikes_avail and cabi_docks_alx = 0.959
# cabi_docks_alx and cabi_stations_tot = 0.959
# cabi_stations_tot and cabi_active_members_annual = 0.958
# cabi_stations_alx and cabi_active_members_day_key = 0.956
# cabi_bikes_avail and cabi_docks_mcs = 0.955
# cabi_bikes_avail and cabi_stations_mcs = 0.954
# cabi_docks_alx and cabi_docks_wdc = 0.953
# cabi_stations_alx and cabi_docks_tot = 0.953
# year and cabi_docks_alx = 0.952
# year and cabi_stations_arl = 0.951
# cabi_stations_wdc and cabi_docks_alx = 0.950
# cabi_stations_alx and cabi_stations_tot = 0.950
# year and cabi_stations_alx = 0.949
# dc_pop and cabi_docks_alx = 0.949
# cabi_bikes_avail and cabi_stations_alx = 0.948
# cabi_stations_mcn and cabi_stations_tot = 0.944
# year and cabi_active_members_annual = 0.943
# year and cabi_docks_mcs = 0.941
# cabi_stations_mcn and cabi_docks_tot = 0.939
# year and cabi_stations_mcs = 0.938
# cabi_stations_wdc and cabi_docks_mcs = 0.938
# cabi_stations_alx and cabi_docks_wdc = 0.937
# cabi_stations_mcs and cabi_stations_wdc = 0.937
# apparenttemperaturehigh and apparenttemperaturelow = 0.936
# dc_pop and cabi_docks_mcs = 0.935
# cabi_docks_mcn and cabi_stations_tot = 0.934
# dc_pop and cabi_stations_mcs = 0.934
# dc_pop and cabi_stations_alx = 0.934
# cabi_stations_alx and cabi_stations_wdc = 0.933
# cabi_docks_alx and cabi_docks_arl = 0.931
# cabi_docks_mcs and cabi_docks_wdc = 0.930
# cabi_docks_mcn and cabi_docks_tot = 0.929
# cabi_stations_mcs and cabi_docks_wdc = 0.928
# apparenttemperaturelow and dewpoint = 0.928
# cabi_bikes_avail and cabi_stations_mcn = 0.928
# cabi_stations_arl and cabi_stations_mcs = 0.925
# apparenttemperaturehigh and dewpoint = 0.924
# cabi_stations_arl and cabi_docks_alx = 0.924
# cabi_bikes_avail and cabi_docks_mcn = 0.923
# cabi_stations_arl and cabi_docks_mcs = 0.922
# year and cabi_active_members_day_key = 0.922
# cabi_stations_mcs and cabi_docks_arl = 0.922
# cabi_docks_arl and cabi_docks_mcs = 0.921
# cabi_docks_alx and cabi_active_members_day_key = 0.919
# cabi_stations_arl and cabi_docks_mcn = 0.917
# cabi_stations_arl and cabi_stations_mcn = 0.917
# cabi_stations_mcn and cabi_stations_wdc = 0.916
# dc_pop and cabi_stations_mcn = 0.916
# nats_single and nats_attendance = 0.914
# cabi_docks_tot and cabi_active_members_day_key = 0.913
# year and cabi_stations_mcn = 0.912
# dc_pop and cabi_docks_mcn = 0.911
# cabi_stations_tot and cabi_active_members_day_key = 0.910
# cabi_stations_mcn and cabi_docks_arl = 0.910
# cabi_stations_alx and cabi_docks_mcs = 0.909
# cabi_docks_arl and cabi_docks_mcn = 0.909
# cabi_docks_alx and cabi_active_members_annual = 0.907
# cabi_stations_alx and cabi_docks_arl = 0.906
# cabi_stations_wdc and cabi_docks_mcn = 0.905
# cabi_stations_mcn and cabi_docks_wdc = 0.905
# cabi_stations_mcs and cabi_active_members_annual = 0.905
# cabi_stations_alx and cabi_stations_mcs = 0.903
# cabi_docks_mcs and cabi_active_members_annual = 0.903
# cabi_docks_alx and cabi_docks_mcs = 0.902
# year and cabi_docks_mcn = 0.902
# cabi_docks_mcs and cabi_active_members_day_key = 0.898
# cabi_stations_mcs and cabi_docks_alx = 0.898
# cabi_bikes_avail and cabi_active_members_day_key = 0.895
# cabi_stations_mcn and cabi_active_members_annual = 0.894
# cabi_docks_wdc and cabi_active_members_day_key = 0.894
# cabi_stations_alx and cabi_stations_arl = 0.893
# cabi_docks_mcn and cabi_active_members_annual = 0.893
# cabi_docks_mcn and cabi_docks_wdc = 0.892
# cabi_stations_mcs and cabi_active_members_day_key = 0.889
# cabi_stations_wdc and cabi_active_members_day_key = 0.886
# dc_pop and cabi_active_members_day_key = 0.882
# cabi_stations_alx and cabi_active_members_annual = 0.881
# cabi_dur_empty_arl and cabi_dur_empty_tot = 0.871
# cabi_dur_empty_tot and cabi_dur_full_tot = 0.866
# daylight_hours and sunrisetime = -0.863
# cabi_dur_empty_wdc and cabi_dur_full_tot = 0.861
# cabi_docks_ffx and cabi_active_members_day_key = 0.857
# cabi_stations_mcn and cabi_docks_alx = 0.856
# cabi_stations_alx and cabi_stations_mcn = 0.855
# cabi_stations_ffx and cabi_active_members_day_key = 0.854
# cabi_docks_alx and cabi_docks_mcn = 0.845
# cabi_stations_alx and cabi_docks_mcn = 0.843
# cabi_dur_empty_wdc and cabi_trips_wdc_to_wdc = 0.841
# cabi_dur_full_wdc and cabi_dur_empty_tot = 0.840
# cabi_dur_empty_wdc and cabi_dur_full_wdc = 0.840
# cabi_dur_empty_tot and cabi_trips_wdc_to_wdc = 0.839
# cabi_stations_mcn and cabi_active_members_day_key = 0.839
# daylight_hours and cabi_active_members_monthly = 0.839
# cabi_docks_arl and cabi_active_members_day_key = 0.828
# cabi_docks_mcn and cabi_active_members_day_key = 0.816
# sunsettime and cabi_active_members_monthly = 0.810
# cabi_dur_empty_wdc and cabi_dur_empty_arl = 0.810
# cabi_stations_arl and cabi_active_members_day_key = 0.810
# cabi_active_members_day_key and cabi_active_members_annual = 0.805
# cabi_trips_wdc_to_wdc and cabi_trips_wdc_to_wdc_casual = 0.770
# cabi_stations_alx and cabi_docks_ffx = 0.769
# cabi_stations_alx and cabi_stations_ffx = 0.764

# %%
# Encode day_of_year as cyclical
df['sin_day_of_year'] = np.sin(2*np.pi*df.day_of_year/365)
df['cos_day_of_year'] = np.cos(2*np.pi*df.day_of_year/365)

# %%
df.sample(100).plot.scatter('sin_day_of_year','cos_day_of_year').set_aspect('equal')

# %% [markdown]
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Training dates = 2013-01-01 to 2016-12-31
#   * Test dates = 2017-01-01 to 2017-09-08
#   * New data (coincides with beginning of dockless pilot) = 2017-09-09 to present

# %%
# Train test split
# This can be tweaked, but we use 5-fold cross-validation to pick the model so that shouldn't change

train = df.loc['2013-01-01':'2016-12-31']
test = df.loc['2017-01-01':'2017-09-08']
print(train.shape, test.shape)

tr = train.shape[0]
te = test.shape[0]
trpct = tr/(tr+te)
tepct = te/(tr+te)

print("{:0.3f} percent of the data is in the training set and {:0.3f} percent is in the test set".format(trpct, tepct))
# Out:
# (1461, 66) (251, 66)
# 0.853 percent of the data is in the training set and 0.147 percent is in the test set

# %%
# Specify columns to keep and drop for X and y
drop_cols = ['date']
y_cols = ['cabi_trips_wdc_to_wdc', 'cabi_trips_wdc_to_wdc_casual']

feature_cols = [col for col in df.columns if (col not in y_cols) & (col not in drop_cols)]

# X y split
Xtrain_raw = train[feature_cols]

# Our target variable here is all DC to DC trips
ytrain = train[y_cols[0]]
Xtest_raw = test[feature_cols]
ytest = test[y_cols[0]]
print(Xtrain_raw.shape, ytrain.shape, Xtest_raw.shape, ytest.shape)
# Out:
# (1461, 63) (1461,) (251, 63) (251,)

# %% [markdown]
# ### 1. Preprocessing
#
# Trying it without any preprocessing first.

# %%
from sklearn.preprocessing import PolynomialFeatures

# Use PolynomialFeatures to create quadratic and interaction terms
# Should ultimately be part of a Pipeline, but I had issues because 
# PF returns an array and Columns requires a df

pf = PolynomialFeatures(1, include_bias=False)

Xtrain_pf_array = pf.fit_transform(Xtrain_raw)
Xtest_pf_array = pf.transform(Xtest_raw)

# Get feature names 
Xtrain_cols = pf.get_feature_names(Xtrain_raw.columns)

# Convert arrays to dfs with the new pf column names
Xtrain = pd.DataFrame(Xtrain_pf_array, columns=Xtrain_cols)
Xtest = pd.DataFrame(Xtest_pf_array, columns=Xtrain_cols)

print(Xtrain.shape, Xtest.shape)
# Out:
# (1461, 63) (251, 63)

# %%
Xtrain.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                               count         mean         std        min  \
# day_of_year                  1461.0      183.125     105.475       1.00
# year                         1461.0     2014.501       1.119    2013.00
# quarter                      1461.0        2.509       1.117       1.00
# cabi_dur_empty_ffx           1461.0        0.565      21.610       0.00
# cabi_dur_empty_tot           1461.0  1113158.534  682246.452       0.00
# cabi_dur_full_tot            1461.0   584708.817  376577.510       0.00
# cabi_active_members_day_key  1461.0     4520.515    3486.874       0.00
# cabi_active_members_monthly  1461.0      239.060     147.838      45.00
# cabi_active_members_annual   1461.0    27939.520    3743.114   19964.00
# sin_day_of_year              1461.0        0.000       0.707      -1.00
# cos_day_of_year              1461.0        0.001       0.708      -1.00
#
#                                      50%          max
# day_of_year                      183.000      366.000
# year                            2015.000     2016.000
# quarter                            3.000        4.000
# month                              7.000       12.000
# day_of_week                        3.000        6.000
# daylight_hours                    12.000       15.000
# apparenttemperaturehigh           66.660      107.320
# apparenttemperaturehightime       16.000       19.000
# apparenttemperaturelow            51.900       86.070
# apparenttemperaturelowtime         6.000       23.000
# precipintensitymaxtime            19.000       23.000
# sunrisetime                        6.000        7.000
# sunsettime                        19.000       20.000
# cloudcover                         0.210        1.000
# dewpoint                          47.380       75.840
# humidity                           0.680        0.970
# precipaccumulation                 0.000       21.427
# precipintensitymax                 0.001        0.971
# precipprobability                  0.000        1.000
# rain                               0.000        1.000
# snow                               0.000        1.000
# visibility                         9.790       10.000
# windspeed                          4.670       19.170
# us_holiday                         0.000        1.000
# nats_single                        0.000        1.000
# nats_double                        0.000        1.000
# nats_attendance                    0.000    69925.000
# dc_bike_event                      0.000        1.000
# dc_pop                        672200.000   689607.255
# cabi_bikes_avail                3203.000     4467.000
# cabi_stations_alx                 16.000       31.000
# cabi_stations_arl                 78.000       88.000
# cabi_stations_ffx                  0.000       18.000
# cabi_stations_mcn                 21.000       22.000
# cabi_stations_mcs                 30.000       36.000
# cabi_stations_wdc                200.000      238.000
# cabi_docks_alx                   367.000      650.000
# cabi_docks_arl                  1341.000     1521.000
# cabi_docks_ffx                     0.000      327.000
# cabi_docks_mcn                   498.000      513.000
# cabi_docks_mcs                   582.000      710.000
# cabi_docks_wdc                  4266.000     5132.000
# cabi_stations_tot                345.000      433.000
# cabi_docks_tot                  7054.000     8853.000
# cabi_dur_empty_wdc            972421.000  2854079.000
# cabi_dur_full_wdc             476925.000  1889029.000
# cabi_dur_empty_arl             83499.000   607963.000
# cabi_dur_full_arl              33053.000   630049.000
# cabi_dur_full_alx               2981.000   158976.000
# cabi_dur_empty_alx                 0.000   109221.000
# cabi_dur_empty_mcs                 0.000   180197.000
# cabi_dur_full_mcs                  0.000   221578.000
# cabi_dur_full_mcn                  0.000   153948.000
# cabi_dur_empty_mcn                 0.000   146724.000
# cabi_dur_full_ffx                  0.000    47275.000
# cabi_dur_empty_ffx                 0.000      826.000
# cabi_dur_empty_tot           1085844.000  3157674.000
# cabi_dur_full_tot             529128.000  3053580.000
# cabi_active_members_day_key     3749.000    11967.000
# cabi_active_members_monthly      245.000      607.000
# cabi_active_members_annual     28991.000    35915.000
# sin_day_of_year                    0.000        1.000
# cos_day_of_year                    0.004        1.000

# %%
# Appending train and test to get full dataset for cross-validation

Xfull = Xtrain.append(Xtest)
yfull = ytrain.append(ytest)
print(Xfull.shape, yfull.shape)
print("Final vars=", Xfull.shape[1])
# Out:
# (1712, 63) (1712,)
# Final vars= 63

# %% [markdown]
# ### 2. Model Fitting

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import median_absolute_error as medae
from sklearn.metrics import explained_variance_score as evs
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
def score_model(model):
    """ 
    Fits a model using the training set, predicts using the test set, and then calculates 
    and reports goodness of fit metrics.
    """
    model.fit(Xtrain, ytrain)
    yhat = model.predict(Xtest)
    r2 = r2_score(ytest, yhat)
    me = mse(ytest, yhat)
    ae = mae(ytest, yhat)
    mede = medae(ytest, yhat)
    ev = evs(ytest, yhat)
    print("Results from {}: \nr2={:0.3f} \nMSE={:0.3f} \
          \nMAE={:0.3f} \nMEDAE={:0.3f} \nEVS={:0.3f}".format(model, r2, me, ae, mede, ev))

def cv_score(model, cv=5):
    """
    Evaluates a model by 5-fold cross-validation and prints mean and 2*stdev of scores.
    Shuffles before cross-validation but sets random_state=7 for reproducibility.
    """
    kf = KFold(n_splits=cv, shuffle=True, random_state=7)
    scores = cross_val_score(model, Xfull, yfull, cv=kf)
    print(scores)
    print("Accuracy: {:0.3f} (+/- {:0.3f})".format(scores.mean(), scores.std() * 2))

# %%
from sklearn.ensemble import RandomForestRegressor

t = time.perf_counter()
rf = RandomForestRegressor(n_estimators=500) 
score_model(rf)
elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# Results from RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False):
# r2=0.824
# MSE=1680139.301
# MAE=1056.468
# MEDAE=917.658
# EVS=0.845
# This cell took 0.21 minutes to run

# %%
t = time.perf_counter()
cv_score(rf)
elapsed_time = (time.perf_counter() - t)/60
print("This cell took {:0.2f} minutes to run".format(elapsed_time))
# Out:
# [0.91857589 0.92305609 0.88748569 0.93329556 0.93926031]
# Accuracy: 0.920 (+/- 0.036)
# This cell took 1.02 minutes to run

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = Xtrain.columns,
                                   columns=['importance']).sort_values('importance', ascending=False)
feature_importances.head(20)
# Out:
#                              importance
# cabi_dur_empty_tot             0.649995
# apparenttemperaturehigh        0.098798
# cabi_dur_empty_arl             0.081270
# cabi_dur_empty_wdc             0.020685
# precipprobability              0.015374
# day_of_year                    0.013816
# cabi_active_members_monthly    0.013805
# precipintensitymax             0.010982
# cabi_dur_empty_mcs             0.007215
# visibility                     0.007192
# apparenttemperaturelow         0.006299
# cloudcover                     0.005820
# humidity                       0.005667
# sin_day_of_year                0.004673
# cos_day_of_year                0.004657
# cabi_dur_full_arl              0.004503
# day_of_week                    0.004462
# cabi_bikes_avail               0.004096
# cabi_dur_full_alx              0.003223
# dewpoint                       0.003039

# %%
end_time = (time.perf_counter() - start_time)/60
print("This notebook took {:0.2f} minutes to run".format(end_time))
# Out:
# This notebook took 1.27 minutes to run

# %% [markdown]
# To do:
# * No polynomials, 3 polynomials
# * How to interpret the coefficients?
# * Modify train/test split size
