# %% [markdown]
# # OLS regressions - baseline for Capstone analysis
# In this notebook, I perform OLS regressions using daily CaBi trips as the dependent variable.

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.tools.tools as tools
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style('darkgrid')
import statsmodels.graphics.gofplots as gofplots

# %matplotlib inline

df = pd.read_csv('~/CaBi/final_df.csv')
df.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# (2739, 803)

# %% [markdown]
# ### First specification attempt - theory based
# A lot of the variation in daily CaBi rides can be explained by weather.
# I decided on the following specification based on trial and error.
# It's fairly arbitrary and could probably be improved, but we shouldn't spend a huge amount of time on baseline stuff.

# %%
# Define a function to estimate OLS regression
def fitOLS(varlist, cov='nonrobust'):
    '''
    This function uses statsmodels.OLS (uppercase) to estimate OLS regressions
    using [Y, X] style syntax as opposed to R-style syntax.
    
    Args:
        varlist (list): A list of variables to include in the regression.
        cov      (str): A specific covariance matrix type. Default is 'nonrobust'. 
                        HC0-HC3 available for heteroskedasticity-robust standard errors.
    Returns:
        results: A RegressionResults object which summarizes the fit of a linear regression model.
    '''
    Y = df['cabi_trips']
    X = df[['dc_pop', 'daylight_hours', 'apparenttemperaturehigh', 'rain', 'snow']]
    X = sm.add_constant(X)
    for var in varlist:
        X = X.assign(new=df['{}'.format(var)])
        X.rename(columns={'new': '{}'.format(var)}, inplace=True)
    model = sm.OLS(Y, X)
    results = model.fit(cov_type='{}'.format(cov), use_t=True)
    return results

# %%
# Fit the model and print results
results = fitOLS(['nats_games'], cov='HC0')
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cabi_trips   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     1955.
# Date:                Thu, 26 Apr 2018   Prob (F-statistic):               0.00
# Time:                        19:54:55   Log-Likelihood:                -24410.
# No. Observations:                2739   AIC:                         4.883e+04
# Df Residuals:                    2732   BIC:                         4.887e+04
# Df Model:                           6
# Covariance Type:                  HC0
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    -5.77e+04    886.470    -65.095      0.000   -5.94e+04    -5.6e+04
# dc_pop                      0.0857      0.001     62.549      0.000       0.083       0.088
# daylight_hours            276.9391     27.441     10.092      0.000     223.131     330.747
# apparenttemperaturehigh    83.8724      2.853     29.397      0.000      78.278      89.467
# rain                    -1338.2651     72.392    -18.486      0.000   -1480.213   -1196.317
# snow                    -1396.9235    220.321     -6.340      0.000   -1828.936    -964.911
# nats_games                346.7508     89.896      3.857      0.000     170.480     523.022
# ==============================================================================
# Omnibus:                      115.050   Durbin-Watson:                   0.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.568
# Skew:                          -0.428   Prob(JB):                     1.22e-33
# Kurtosis:                       3.772   Cond. No.                     1.74e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 1.74e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Heteroskedasticity?
plt.title('Residuals vs Fitted Values')
sns.regplot(results.fittedvalues, results.resid)
plt.xlabel('Y-hat')
plt.ylabel('Residuals')
plt.show()

# How are our residuals distributed?
plt.title('Density Plot of Residuals')
sns.kdeplot(results.resid)
plt.show()

# How close are our residuals to normal?
fig = gofplots.qqplot(results.resid, line='s')
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# ### Second specification attempt - dockless?
# Here, I add dless_trips_all to the specification to see if there's any correlation.
# Its coefficient is not statistically significant.

# %%
results = fitOLS(['nats_games', 'dless_trips_all'], cov='HC0')
print(results.summary())

# Heteroskedasticity?
plt.title('Residuals vs Fitted Values')
sns.regplot(results.fittedvalues, results.resid)
plt.xlabel('Y-hat')
plt.ylabel('Residuals')
plt.show()

# How are our residuals distributed?
plt.title('Density Plot of Residuals')
sns.kdeplot(results.resid)
plt.show()

# How close are our residuals to normality?
fig = gofplots.qqplot(results.resid, line='s')
plt.title("Normal Q-Q plot")
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cabi_trips   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     1676.
# Date:                Thu, 26 Apr 2018   Prob (F-statistic):               0.00
# Time:                        19:55:15   Log-Likelihood:                -24409.
# No. Observations:                2739   AIC:                         4.883e+04
# Df Residuals:                    2731   BIC:                         4.888e+04
# Df Model:                           7
# Covariance Type:                  HC0
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                   -5.792e+04    923.161    -62.736      0.000   -5.97e+04   -5.61e+04
# dc_pop                      0.0861      0.001     59.211      0.000       0.083       0.089
# daylight_hours            272.0585     28.027      9.707      0.000     217.102     327.015
# apparenttemperaturehigh    84.1148      2.860     29.415      0.000      78.508      89.722
# rain                    -1339.8374     72.299    -18.532      0.000   -1481.604   -1198.071
# snow                    -1399.6226    220.579     -6.345      0.000   -1832.142    -967.103
# nats_games                344.9173     89.821      3.840      0.000     168.793     521.042
# dless_trips_all            -0.0977      0.126     -0.773      0.439      -0.345       0.150
# ==============================================================================
# Omnibus:                      115.592   Durbin-Watson:                   0.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.658
# Skew:                          -0.428   Prob(JB):                     7.09e-34
# Kurtosis:                       3.777   Cond. No.                     1.80e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 1.8e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
'''Sandbox cell for messing around'''

results = fitOLS([], cov='HC0')
print(results.summary())

# Heteroskedasticity?
plt.title('Residuals vs Fitted Values')
sns.regplot(results.fittedvalues, results.resid)
plt.xlabel('Y-hat')
plt.ylabel('Residuals')
plt.show()

# How are our residuals distributed?
plt.title('Density Plot of Residuals')
sns.kdeplot(results.resid)
plt.show()

# How close are our residuals to normality?
fig = gofplots.qqplot(results.resid, line='s')
plt.title("Normal Q-Q plot")
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             cabi_trips   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     2319.
# Date:                Fri, 27 Apr 2018   Prob (F-statistic):               0.00
# Time:                        17:23:21   Log-Likelihood:                -24417.
# No. Observations:                2739   AIC:                         4.885e+04
# Df Residuals:                    2733   BIC:                         4.888e+04
# Df Model:                           5
# Covariance Type:                  HC0
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                   -5.803e+04    889.938    -65.212      0.000   -5.98e+04   -5.63e+04
# dc_pop                      0.0858      0.001     62.332      0.000       0.083       0.088
# daylight_hours            301.3104     26.829     11.231      0.000     248.702     353.918
# apparenttemperaturehigh    84.8960      2.854     29.746      0.000      79.300      90.492
# rain                    -1330.3387     72.579    -18.329      0.000   -1472.654   -1188.023
# snow                    -1386.8871    221.132     -6.272      0.000   -1820.490    -953.285
# ==============================================================================
# Omnibus:                      106.978   Durbin-Watson:                   0.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.786
# Skew:                          -0.409   Prob(JB):                     4.42e-31
# Kurtosis:                       3.745   Cond. No.                     1.73e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 1.73e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
