# %% [markdown]
# # CaBi ML fitting - Lasso - Total rides
#
# In this notebook I use lasso to fit on our training data, 1/1/2013 to 9/8/2017, score the model using 5-fold cross-validation, then predict on our test data, 9/9/2017 to 4/30/2018.
#
# Dependent variable = total DC to DC CaBi rides.

# %% [markdown]
# ## 0. Data load, shaping, and split
# * Read in data from AWS
#   * Check for high pairwise correlation
# * Encode time variable (day_of_year) as cyclical
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Specify feature and target columns

# %%
# Read in data from AWS

from util_functions import *
import numpy as np
import pandas as pd
import time
start_time = time.perf_counter()

set_env_path()
conn, cur = aws_connect()

# fullquery contains all of the variables within consideration

fullquery = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
daylight_hours,
apparenttemperaturehigh,
apparenttemperaturelow,
cloudcover,
dewpoint,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
dc_bike_event,
dc_pop,
cabi_bikes_avail,
cabi_stations_alx,
cabi_stations_arl,
cabi_stations_ffx,
cabi_stations_mcn,
cabi_stations_mcs,
cabi_stations_wdc,
cabi_docks_alx,
cabi_docks_arl,
cabi_docks_ffx,
cabi_docks_mcn,
cabi_docks_mcs,
cabi_docks_wdc,
cabi_stations_tot,
cabi_docks_tot,
cabi_dur_empty_wdc,
cabi_dur_full_wdc,
cabi_dur_empty_arl,
cabi_dur_full_arl,
cabi_dur_full_alx,
cabi_dur_empty_alx,
cabi_dur_empty_mcs,
cabi_dur_full_mcs,
cabi_dur_full_mcn,
cabi_dur_empty_mcn,
cabi_dur_full_ffx,
cabi_dur_empty_ffx,
cabi_dur_empty_tot,
cabi_dur_full_tot,
cabi_active_members_day_key,
cabi_active_members_monthly,
cabi_active_members_annual,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""

# query used

query = """
SELECT 
EXTRACT(DOY FROM date) as day_of_year,
date,
daylight_hours,
apparenttemperaturehigh,
cloudcover,
humidity,
precipaccumulation,
precipintensitymax,
precipprobability,
rain,
snow,
visibility,
windspeed,
us_holiday,
nats_single,
nats_double,
dc_bike_event,
dc_pop,
cabi_trips_wdc_to_wdc,
cabi_trips_wdc_to_wdc_casual
from final_db"""

pd.options.display.max_rows = None
pd.options.display.max_columns = None

df = pd.read_sql(query, con=conn)

# Setting date to index for easier splitting
df.set_index(df.date, drop=True, inplace=True)
df.index = pd.to_datetime(df.index)

print("We have {} instances and {} features".format(*df.shape))
# Out:
# We have 2780 instances and 20 features

# %%
# Summary statistics

df.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                count        mean        std         min  \
# day_of_year                   2780.0     182.697    107.702       1.000
# daylight_hours                2780.0      12.077      2.021       9.000
# apparenttemperaturehigh       2780.0      64.306     20.594       2.240
# cloudcover                    2780.0       0.340      0.244       0.000
# humidity                      2780.0       0.669      0.137       0.210
# precipaccumulation            2780.0       0.045      0.527       0.000
# precipintensitymax            2780.0       0.029      0.072       0.000
# precipprobability             2780.0       0.282      0.373       0.000
# rain                          2780.0       0.454      0.498       0.000
# snow                          2780.0       0.040      0.196       0.000
# visibility                    2780.0       9.306      1.130       1.130
# windspeed                     2780.0       5.379      3.170       0.030
# us_holiday                    2780.0       0.031      0.173       0.000
# nats_single                   2780.0       0.200      0.400       0.000
# nats_double                   2780.0       0.006      0.078       0.000
# dc_bike_event                 2780.0       0.009      0.094       0.000
# dc_pop                        2780.0  662465.171  26420.230  607733.153
# cabi_trips_wdc_to_wdc         2780.0    6375.501   3185.075       0.000
# cabi_trips_wdc_to_wdc_casual  2780.0    1395.860   1339.656       0.000
#
#                                      50%         max
# day_of_year                      182.000     366.000
# daylight_hours                    12.000      15.000
# apparenttemperaturehigh           65.890     113.670
# cloudcover                         0.270       1.000
# humidity                           0.670       0.970
# precipaccumulation                 0.000      21.427
# precipintensitymax                 0.001       1.185
# precipprobability                  0.000       1.000
# rain                               0.000       1.000
# snow                               0.000       1.000
# visibility                         9.790      10.000
# windspeed                          4.850      25.460
# us_holiday                         0.000       1.000
# nats_single                        0.000       1.000
# nats_double                        0.000       1.000
# dc_bike_event                      0.000       1.000
# dc_pop                        665296.583  702021.562
# cabi_trips_wdc_to_wdc           6240.000   16608.000
# cabi_trips_wdc_to_wdc_casual    1000.000    9130.000

# %%
df.tail()
# Out:
#             day_of_year        date  daylight_hours  apparenttemperaturehigh  \
# date
# 2018-04-26        116.0  2018-04-26            13.0                    69.70
# 2018-04-27        117.0  2018-04-27            13.0                    61.85
# 2018-04-28        118.0  2018-04-28            13.0                    75.37
# 2018-04-29        119.0  2018-04-29            13.0                    54.68
# 2018-04-30        120.0  2018-04-30            14.0                    71.27
#
#             cloudcover  humidity  precipaccumulation  precipintensitymax  \
# date
# 2018-04-26        0.13      0.51                 0.0              0.0000
# 2018-04-27        0.46      0.80                 0.0              0.1564
# 2018-04-28        0.27      0.69                 0.0              0.0034
# 2018-04-29        0.28      0.49                 0.0              0.0010
# 2018-04-30        0.07      0.39                 0.0              0.0000
#
#             precipprobability  rain  snow  visibility  windspeed  us_holiday  \
# date
# 2018-04-26                0.0   0.0   0.0        9.98       6.25         0.0
# 2018-04-27                1.0   1.0   0.0        8.59       2.89         0.0
# 2018-04-28                0.2   1.0   0.0        8.44       1.21         0.0
# 2018-04-29                0.1   1.0   0.0       10.00      13.66         0.0
# 2018-04-30                0.0   0.0   0.0       10.00       9.61         0.0
#
#             nats_single  nats_double  dc_bike_event        dc_pop  \
# date
# 2018-04-26          0.0          0.0            0.0  702021.56174
# 2018-04-27          1.0          0.0            0.0  702021.56174
# 2018-04-28          1.0          0.0            0.0  702021.56174
# 2018-04-29          1.0          0.0            0.0  702021.56174
# 2018-04-30          1.0          0.0            0.0  702021.56174
#
#             cabi_trips_wdc_to_wdc  cabi_trips_wdc_to_wdc_casual
# date
# 2018-04-26                11949.0                        2779.0
# 2018-04-27                 8985.0                        2245.0
# 2018-04-28                12946.0                        5955.0
# 2018-04-29                 7838.0                        2741.0
# 2018-04-30                10543.0                        2196.0

# %%
def print_highly_correlated(df, features, threshold=0.75):
    """ 
    Prints highly correlated feature pairs in df.
    """
    corr_df = df[features].corr()
    # Select pairs above threshold
    correlated_features = np.where(np.abs(corr_df) > threshold)
    # Avoid duplication
    correlated_features = [(corr_df.iloc[x,y], x, y) for x, y in zip(*correlated_features) if x != y and x < y]
    # Sort by abs(correlation)
    s_corr_list = sorted(correlated_features, key=lambda x: -abs(x[0]))
    print("There are {} feature pairs with pairwise correlation above {}".format(len(s_corr_list), threshold))
    for v, i, j in s_corr_list:
        cols = df[features].columns
        print("{} and {} = {:0.3f}".format(corr_df.index[i], corr_df.columns[j], v))
        
print_highly_correlated(df, df.columns)
# Out:
# There are 1 feature pairs with pairwise correlation above 0.75
# cabi_trips_wdc_to_wdc and cabi_trips_wdc_to_wdc_casual = 0.770

# %%
# Encode day_of_year as cyclical
df['sin_day_of_year'] = np.sin(2*np.pi*df.day_of_year/365)
df['cos_day_of_year'] = np.cos(2*np.pi*df.day_of_year/365)

# %%
# %matplotlib inline

df.sample(100).plot.scatter('sin_day_of_year','cos_day_of_year').set_aspect('equal')

# %% [markdown]
# * Split into Xtrain, Xtest, ytrain, ytest based on date
#   * Training dates = 2013-01-01 to 2017-09-08
#   * Test dates = 2017-09-09 to 2018-04-30
#     * Coincides with dockless pilot

# %%
train = df.loc['2013-01-01':'2017-09-08']
test = df.loc['2017-09-09':'2018-04-30']
print(train.shape, test.shape)

tr = train.shape[0]
te = test.shape[0]
trpct = tr/(tr+te)
tepct = te/(tr+te)

print("{:0.3f} percent of the data is in the training set and {:0.3f} percent is in the test set".format(trpct, tepct))
# Out:
# (1712, 22) (234, 22)
# 0.880 percent of the data is in the training set and 0.120 percent is in the test set

# %%
# Specify columns to keep and drop for X and y
drop_cols = ['date', 'day_of_year']
y_cols = ['cabi_trips_wdc_to_wdc', 'cabi_trips_wdc_to_wdc_casual']

feature_cols = [col for col in df.columns if (col not in y_cols) & (col not in drop_cols)]

# X y split
Xtrain_raw = train[feature_cols]

# Our target variable here is all DC to DC trips
ytrain = train[y_cols[0]]
Xtest_raw = test[feature_cols]
ytest = test[y_cols[0]]
print(Xtrain_raw.shape, ytrain.shape, Xtest_raw.shape, ytest.shape)
# Out:
# (1712, 18) (1712,) (234, 18) (234,)

# %% [markdown]
# ## 1. Preprocessing
#
# We want to use PolynomialFeatures and StandardScaler in a Pipeline, but we only want to scale continuous features.
#
# Here, I do the polynomial transformation first and then feed it through a pipeline because I wasn't able to get it all working in one pipeline.
#
# * Use PolynomialFeatures to create quadratic and interaction terms
#   * Convert back to DataFrame
#   * Drop redundant variables
# * Use Pipeline and FeatureUnion to selectively scale/ignore certain variables
# * Fit and transform using pipeline to get final Xtrain and Xtest

# %%
# Imports and custom classes
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin

class Columns(BaseEstimator, TransformerMixin):
    """ 
    This is a custom transformer for splitting the data into subsets for FeatureUnion.
    """
    def __init__(self, names=None):
        self.names = names

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X):
        return X[self.names]

# %%
# Use PolynomialFeatures to create quadratic and interaction terms
# Was supposed to be part of a Pipeline, but I had issues because 
# PF returns an array and Columns requires a df

pf = PolynomialFeatures(2, include_bias=False)

Xtrain_pf_array = pf.fit_transform(Xtrain_raw)
Xtest_pf_array = pf.transform(Xtest_raw)

# Get feature names 
Xtrain_cols = pf.get_feature_names(Xtrain_raw.columns)

# Convert arrays to dfs with the new pf column names
Xtrain_pf = pd.DataFrame(Xtrain_pf_array, columns=Xtrain_cols)
Xtest_pf = pd.DataFrame(Xtest_pf_array, columns=Xtrain_cols)

print(Xtrain_pf.shape, Xtest_pf.shape)
# Out:
# (1712, 189) (234, 189)

# %%
# Dropping squared dummies and nonsensical interaction terms

to_drop = [
    'rain^2', 'snow^2', 'us_holiday^2', 'nats_single^2', 'nats_double^2', 
    'dc_bike_event^2', 'sin_day_of_year^2', 'cos_day_of_year^2',
    'sin_day_of_year cos_day_of_year'
]

Xtrain_pf2 = Xtrain_pf.drop(labels=to_drop, axis=1)
Xtest_pf2 = Xtest_pf.drop(labels=to_drop, axis=1)

print(Xtrain_pf2.shape, Xtest_pf2.shape)
# Out:
# (1712, 180) (234, 180)

# %%
# Defining binary and continuous variables
# We have normal 0,1 binary variables, binary variables outside 0,1 that were created by PF, and continuous variables
# We want to MinMaxScale the binary variables and StandardScale the continuous variables

binary = [col for col in Xtrain_pf2.columns if Xtrain_pf2[col].nunique() == 2]
cont = [col for col in Xtrain_pf2.columns if col not in binary]

# FeatureUnion in our pipeline shifts the ordering of the variables so we need to save the ordering here
cols = binary + cont

pipeline = Pipeline([
    ('features', FeatureUnion([
        ('binary', Pipeline([
            ('bincols', Columns(names=binary)),
            ('minmax', MinMaxScaler())
        ])),
        ('continuous', Pipeline([
            ('contcols', Columns(names=cont)),
            ('scaler', StandardScaler())
        ]))
    ]))   
])

# %%
# Fit and transform to create our final Xtrain and Xtest

pipeline.fit(Xtrain_pf2)
Xtrain_scaled = pipeline.transform(Xtrain_pf2)
Xtest_scaled = pipeline.transform(Xtest_pf2)

# Put everything back into dfs
Xtrain = pd.DataFrame(Xtrain_scaled, columns=cols)
Xtest = pd.DataFrame(Xtest_scaled, columns=cols)
print(Xtrain.shape, Xtest.shape)
# Out:
# (1712, 180) (234, 180)

# %%
# Check to see if the transforms worked as intended

Xtrain.describe(percentiles=[.5]).round(3).transpose()
# Out:
#                                              count   mean    std     min  \
# rain                                        1712.0  0.455  0.498   0.000
# snow                                        1712.0  0.043  0.203   0.000
# us_holiday                                  1712.0  0.029  0.167   0.000
# nats_single                                 1712.0  0.216  0.411   0.000
# nats_double                                 1712.0  0.007  0.083   0.000
# dc_bike_event                               1712.0  0.013  0.113   0.000
# rain us_holiday                             1712.0  0.008  0.090   0.000
# rain nats_single                            1712.0  0.110  0.313   0.000
# rain nats_double                            1712.0  0.004  0.064   0.000
# rain dc_bike_event                          1712.0  0.008  0.087   0.000
# snow us_holiday                             1712.0  0.002  0.042   0.000
# us_holiday nats_single                      1712.0  0.006  0.076   0.000
# nats_single dc_bike_event                   1712.0  0.002  0.048   0.000
# daylight_hours                              1712.0 -0.000  1.000  -1.630
# apparenttemperaturehigh                     1712.0  0.000  1.000  -3.012
# cloudcover                                  1712.0  0.000  1.000  -1.330
# humidity                                    1712.0 -0.000  1.000  -2.818
# precipaccumulation                          1712.0 -0.000  1.000  -0.091
# precipintensitymax                          1712.0 -0.000  1.000  -0.411
# precipprobability                           1712.0  0.000  1.000  -0.754
# visibility                                  1712.0  0.000  1.000  -7.019
# windspeed                                   1712.0  0.000  1.000  -1.691
# dc_pop                                      1712.0  0.000  1.000  -1.893
# sin_day_of_year                             1712.0 -0.000  1.000  -1.492
# cos_day_of_year                             1712.0 -0.000  1.000  -1.363
# daylight_hours^2                            1712.0  0.000  1.000  -1.508
# daylight_hours apparenttemperaturehigh      1712.0  0.000  1.000  -2.242
# daylight_hours cloudcover                   1712.0  0.000  1.000  -1.349
# daylight_hours humidity                     1712.0  0.000  1.000  -2.293
# daylight_hours precipaccumulation           1712.0 -0.000  1.000  -0.093
# daylight_hours precipintensitymax           1712.0  0.000  1.000  -0.395
# daylight_hours precipprobability            1712.0 -0.000  1.000  -0.749
# daylight_hours rain                         1712.0  0.000  1.000  -0.894
# daylight_hours snow                         1712.0 -0.000  1.000  -0.212
# daylight_hours visibility                   1712.0  0.000  1.000  -4.224
# daylight_hours windspeed                    1712.0  0.000  1.000  -1.719
# daylight_hours us_holiday                   1712.0  0.000  1.000  -0.168
# daylight_hours nats_single                  1712.0  0.000  1.000  -0.522
# daylight_hours nats_double                  1712.0 -0.000  1.000  -0.084
# daylight_hours dc_bike_event                1712.0 -0.000  1.000  -0.113
# daylight_hours dc_pop                       1712.0  0.000  1.000  -1.784
# daylight_hours sin_day_of_year              1712.0 -0.000  1.000  -1.583
# daylight_hours cos_day_of_year              1712.0 -0.000  1.000  -1.513
# apparenttemperaturehigh^2                   1712.0 -0.000  1.000  -1.805
# apparenttemperaturehigh cloudcover          1712.0 -0.000  1.000  -1.432
# apparenttemperaturehigh humidity            1712.0 -0.000  1.000  -2.438
# apparenttemperaturehigh precipaccumulation  1712.0 -0.000  1.000  -0.126
# apparenttemperaturehigh precipintensitymax  1712.0  0.000  1.000  -0.371
# apparenttemperaturehigh precipprobability   1712.0 -0.000  1.000  -0.725
# apparenttemperaturehigh rain                1712.0  0.000  1.000  -0.860
# apparenttemperaturehigh snow                1712.0 -0.000  1.000  -0.201
# apparenttemperaturehigh visibility          1712.0  0.000  1.000  -2.747
# apparenttemperaturehigh windspeed           1712.0 -0.000  1.000  -1.693
# apparenttemperaturehigh us_holiday          1712.0  0.000  1.000  -0.161
# apparenttemperaturehigh nats_single         1712.0 -0.000  1.000  -0.517
# apparenttemperaturehigh nats_double         1712.0 -0.000  1.000  -0.084
# apparenttemperaturehigh dc_bike_event       1712.0  0.000  1.000  -0.111
# apparenttemperaturehigh dc_pop              1712.0  0.000  1.000  -2.983
# apparenttemperaturehigh sin_day_of_year     1712.0  0.000  1.000  -1.928
# apparenttemperaturehigh cos_day_of_year     1712.0 -0.000  1.000  -1.861
# cloudcover^2                                1712.0  0.000  1.000  -0.638
# cloudcover humidity                         1712.0  0.000  1.000  -1.088
# cloudcover precipaccumulation               1712.0 -0.000  1.000  -0.098
# cloudcover precipintensitymax               1712.0 -0.000  1.000  -0.390
# cloudcover precipprobability                1712.0 -0.000  1.000  -0.584
# cloudcover rain                             1712.0 -0.000  1.000  -0.708
# cloudcover snow                             1712.0 -0.000  1.000  -0.168
# cloudcover visibility                       1712.0 -0.000  1.000  -1.529
# cloudcover windspeed                        1712.0  0.000  1.000  -0.958
# cloudcover us_holiday                       1712.0 -0.000  1.000  -0.132
# cloudcover nats_single                      1712.0  0.000  1.000  -0.420
# cloudcover nats_double                      1712.0  0.000  1.000  -0.061
# cloudcover dc_bike_event                    1712.0  0.000  1.000  -0.098
# cloudcover dc_pop                           1712.0 -0.000  1.000  -1.339
# cloudcover sin_day_of_year                  1712.0 -0.000  1.000  -4.126
# cloudcover cos_day_of_year                  1712.0  0.000  1.000  -3.322
# humidity^2                                  1712.0  0.000  1.000  -2.120
# humidity precipaccumulation                 1712.0 -0.000  1.000  -0.108
# humidity precipintensitymax                 1712.0  0.000  1.000  -0.400
# humidity precipprobability                  1712.0  0.000  1.000  -0.721
# humidity rain                               1712.0  0.000  1.000  -0.890
# humidity snow                               1712.0 -0.000  1.000  -0.207
# humidity visibility                         1712.0  0.000  1.000  -4.698
# humidity windspeed                          1712.0  0.000  1.000  -1.808
# humidity us_holiday                         1712.0 -0.000  1.000  -0.168
# humidity nats_single                        1712.0  0.000  1.000  -0.514
# humidity nats_double                        1712.0 -0.000  1.000  -0.083
# humidity dc_bike_event                      1712.0  0.000  1.000  -0.112
# humidity dc_pop                             1712.0  0.000  1.000  -2.789
# humidity sin_day_of_year                    1712.0  0.000  1.000  -2.037
# humidity cos_day_of_year                    1712.0 -0.000  1.000  -1.806
# precipaccumulation^2                        1712.0  0.000  1.000  -0.037
# precipaccumulation precipintensitymax       1712.0 -0.000  1.000  -0.046
# precipaccumulation precipprobability        1712.0 -0.000  1.000  -0.111
# precipaccumulation rain                     1712.0  0.000  0.000   0.000
# precipaccumulation snow                     1712.0 -0.000  1.000  -0.091
# precipaccumulation visibility               1712.0 -0.000  1.000  -0.074
# precipaccumulation windspeed                1712.0  0.000  1.000  -0.058
# precipaccumulation us_holiday               1712.0  0.000  1.000  -0.034
# precipaccumulation nats_single              1712.0  0.000  0.000   0.000
# precipaccumulation nats_double              1712.0  0.000  0.000   0.000
# precipaccumulation dc_bike_event            1712.0  0.000  0.000   0.000
# precipaccumulation dc_pop                   1712.0 -0.000  1.000  -0.091
# precipaccumulation sin_day_of_year          1712.0  0.000  1.000  -3.118
# precipaccumulation cos_day_of_year          1712.0 -0.000  1.000  -0.087
# precipintensitymax^2                        1712.0  0.000  1.000  -0.158
# precipintensitymax precipprobability        1712.0 -0.000  1.000  -0.391
# precipintensitymax rain                     1712.0  0.000  1.000  -0.394
# precipintensitymax snow                     1712.0 -0.000  1.000  -0.118
# precipintensitymax visibility               1712.0  0.000  1.000  -0.404
# precipintensitymax windspeed                1712.0  0.000  1.000  -0.374
# precipintensitymax us_holiday               1712.0  0.000  1.000  -0.076
# precipintensitymax nats_single              1712.0 -0.000  1.000  -0.167
# precipintensitymax nats_double              1712.0 -0.000  1.000  -0.040
# precipintensitymax dc_bike_event            1712.0  0.000  1.000  -0.055
# precipintensitymax dc_pop                   1712.0 -0.000  1.000  -0.412
# precipintensitymax sin_day_of_year          1712.0  0.000  1.000 -15.601
# precipintensitymax cos_day_of_year          1712.0  0.000  1.000 -12.073
# precipprobability^2                         1712.0 -0.000  1.000  -0.634
# precipprobability rain                      1712.0  0.000  1.000  -0.706
# precipprobability snow                      1712.0 -0.000  1.000  -0.176
# precipprobability visibility                1712.0 -0.000  1.000  -0.759
# precipprobability windspeed                 1712.0  0.000  1.000  -0.619
# precipprobability us_holiday                1712.0 -0.000  1.000  -0.091
# precipprobability nats_single               1712.0 -0.000  1.000  -0.294
# precipprobability nats_double               1712.0  0.000  1.000  -0.050
# precipprobability dc_bike_event             1712.0  0.000  1.000  -0.081
# precipprobability dc_pop                    1712.0 -0.000  1.000  -0.754
# precipprobability sin_day_of_year           1712.0 -0.000  1.000  -3.264
# precipprobability cos_day_of_year           1712.0 -0.000  1.000  -2.891
# rain snow                                   1712.0  0.000  0.000   0.000
# rain visibility                             1712.0  0.000  1.000  -0.895
# rain windspeed                              1712.0  0.000  1.000  -0.715
# rain dc_pop                                 1712.0 -0.000  1.000  -0.913
# rain sin_day_of_year                        1712.0 -0.000  1.000  -2.215
# rain cos_day_of_year                        1712.0  0.000  1.000  -1.942
# snow visibility                             1712.0  0.000  1.000  -0.207
# snow windspeed                              1712.0 -0.000  1.000  -0.179
# snow nats_single                            1712.0  0.000  0.000   0.000
# snow nats_double                            1712.0  0.000  0.000   0.000
# snow dc_bike_event                          1712.0  0.000  0.000   0.000
# snow dc_pop                                 1712.0  0.000  1.000  -0.213
# snow sin_day_of_year                        1712.0  0.000  1.000  -5.348
# snow cos_day_of_year                        1712.0  0.000  1.000  -0.202
# visibility^2                                1712.0  0.000  1.000  -4.758
# visibility windspeed                        1712.0  0.000  1.000  -1.615
# visibility us_holiday                       1712.0  0.000  1.000  -0.170
# visibility nats_single                      1712.0  0.000  1.000  -0.522
# visibility nats_double                      1712.0  0.000  1.000  -0.084
# visibility dc_bike_event                    1712.0 -0.000  1.000  -0.114
# visibility dc_pop                           1712.0  0.000  1.000  -6.922
# visibility sin_day_of_year                  1712.0 -0.000  1.000  -1.568
# visibility cos_day_of_year                  1712.0  0.000  1.000  -1.446
# windspeed^2                                 1712.0 -0.000  1.000  -0.841
# windspeed us_holiday                        1712.0  0.000  1.000  -0.143
# windspeed nats_single                       1712.0  0.000  1.000  -0.456
# windspeed nats_double                       1712.0 -0.000  1.000  -0.078
# windspeed dc_bike_event                     1712.0 -0.000  1.000  -0.100
# windspeed dc_pop                            1712.0  0.000  1.000  -1.690
# windspeed sin_day_of_year                   1712.0 -0.000  1.000  -3.584
# windspeed cos_day_of_year                   1712.0  0.000  1.000  -2.697
# us_holiday nats_double                      1712.0  0.000  0.000   0.000
# us_holiday dc_bike_event                    1712.0  0.000  0.000   0.000
# us_holiday dc_pop                           1712.0 -0.000  1.000  -0.172
# us_holiday sin_day_of_year                  1712.0 -0.000  1.000 -10.069
# us_holiday cos_day_of_year                  1712.0 -0.000  1.000  -7.299
# nats_single nats_double                     1712.0  0.000  0.000   0.000
# nats_single dc_pop                          1712.0  0.000  1.000  -0.524
# nats_single sin_day_of_year                 1712.0  0.000  1.000  -3.071
# nats_single cos_day_of_year                 1712.0  0.000  1.000  -2.873
# nats_double dc_bike_event                   1712.0  0.000  0.000   0.000
# nats_double dc_pop                          1712.0  0.000  1.000  -0.084
# nats_double sin_day_of_year                 1712.0 -0.000  1.000 -15.689
# nats_double cos_day_of_year                 1712.0 -0.000  1.000 -16.913
# dc_bike_event dc_pop                        1712.0  0.000  1.000  -0.114
# dc_bike_event sin_day_of_year               1712.0  0.000  1.000 -11.495
# dc_bike_event cos_day_of_year               1712.0  0.000  1.000 -12.134
# dc_pop^2                                    1712.0  0.000  1.000  -1.870
# dc_pop sin_day_of_year                      1712.0 -0.000  1.000  -1.520
# dc_pop cos_day_of_year                      1712.0 -0.000  1.000  -1.405
#
#                                               50%     max
# rain                                        0.000   1.000
# snow                                        0.000   1.000
# us_holiday                                  0.000   1.000
# nats_single                                 0.000   1.000
# nats_double                                 0.000   1.000
# dc_bike_event                               0.000   1.000
# rain us_holiday                             0.000   1.000
# rain nats_single                            0.000   1.000
# rain nats_double                            0.000   1.000
# rain dc_bike_event                          0.000   1.000
# snow us_holiday                             0.000   1.000
# us_holiday nats_single                      0.000   1.000
# nats_single dc_bike_event                   0.000   1.000
# daylight_hours                              0.348   1.337
# apparenttemperaturehigh                     0.129   2.016
# cloudcover                                 -0.299   3.355
# humidity                                    0.068   2.160
# precipaccumulation                         -0.091  33.505
# precipintensitymax                         -0.398  12.976
# precipprobability                          -0.754   1.959
# visibility                                  0.428   0.600
# windspeed                                  -0.172   4.473
# dc_pop                                      0.204   1.574
# sin_day_of_year                             0.068   1.359
# cos_day_of_year                            -0.047   1.451
# daylight_hours^2                            0.278   1.415
# daylight_hours apparenttemperaturehigh     -0.019   2.111
# daylight_hours cloudcover                  -0.267   4.500
# daylight_hours humidity                     0.020   2.496
# daylight_hours precipaccumulation          -0.093  32.827
# daylight_hours precipintensitymax          -0.384  13.526
# daylight_hours precipprobability           -0.749   2.534
# daylight_hours rain                        -0.894   1.434
# daylight_hours snow                        -0.212   5.412
# daylight_hours visibility                   0.200   1.440
# daylight_hours windspeed                   -0.152   4.166
# daylight_hours us_holiday                  -0.168   7.636
# daylight_hours nats_single                 -0.522   2.093
# daylight_hours nats_double                 -0.084  12.880
# daylight_hours dc_bike_event               -0.113   9.881
# daylight_hours dc_pop                       0.164   1.545
# daylight_hours sin_day_of_year              0.044   1.410
# daylight_hours cos_day_of_year              0.106   1.343
# apparenttemperaturehigh^2                  -0.030   2.633
# apparenttemperaturehigh cloudcover         -0.208   4.511
# apparenttemperaturehigh humidity            0.083   2.415
# apparenttemperaturehigh precipaccumulation -0.126  15.993
# apparenttemperaturehigh precipintensitymax -0.362  14.514
# apparenttemperaturehigh precipprobability  -0.725   3.147
# apparenttemperaturehigh rain               -0.860   2.045
# apparenttemperaturehigh snow               -0.201   9.194
# apparenttemperaturehigh visibility          0.129   2.057
# apparenttemperaturehigh windspeed          -0.132   3.935
# apparenttemperaturehigh us_holiday         -0.161   8.813
# apparenttemperaturehigh nats_single        -0.517   2.697
# apparenttemperaturehigh nats_double        -0.084  13.263
# apparenttemperaturehigh dc_bike_event      -0.111  12.015
# apparenttemperaturehigh dc_pop              0.112   2.087
# apparenttemperaturehigh sin_day_of_year     0.128   1.859
# apparenttemperaturehigh cos_day_of_year     0.207   1.747
# cloudcover^2                               -0.393   4.422
# cloudcover humidity                        -0.350   4.012
# cloudcover precipaccumulation              -0.098  26.416
# cloudcover precipintensitymax              -0.385   9.608
# cloudcover precipprobability               -0.584   4.188
# cloudcover rain                            -0.708   3.338
# cloudcover snow                            -0.168  12.017
# cloudcover visibility                      -0.248   4.422
# cloudcover windspeed                       -0.315   7.332
# cloudcover us_holiday                      -0.132  15.282
# cloudcover nats_single                     -0.420   7.138
# cloudcover nats_double                     -0.061  28.424
# cloudcover dc_bike_event                   -0.098  18.532
# cloudcover dc_pop                          -0.293   3.524
# cloudcover sin_day_of_year                 -0.079   3.827
# cloudcover cos_day_of_year                 -0.062   3.794
# humidity^2                                 -0.035   2.562
# humidity precipaccumulation                -0.108  22.841
# humidity precipintensitymax                -0.390  12.466
# humidity precipprobability                 -0.721   2.472
# humidity rain                              -0.890   1.670
# humidity snow                              -0.207   6.729
# humidity visibility                         0.155   2.150
# humidity windspeed                         -0.146   5.859
# humidity us_holiday                        -0.168   8.128
# humidity nats_single                       -0.514   2.859
# humidity nats_double                       -0.083  14.997
# humidity dc_bike_event                     -0.112  11.409
# humidity dc_pop                             0.044   2.302
# humidity sin_day_of_year                    0.117   1.926
# humidity cos_day_of_year                    0.001   2.026
# precipaccumulation^2                       -0.037  40.862
# precipaccumulation precipintensitymax      -0.046  39.903
# precipaccumulation precipprobability       -0.111  20.595
# precipaccumulation rain                     0.000   0.000
# precipaccumulation snow                    -0.091  33.505
# precipaccumulation visibility              -0.074  37.713
# precipaccumulation windspeed               -0.058  37.982
# precipaccumulation us_holiday              -0.034  29.458
# precipaccumulation nats_single              0.000   0.000
# precipaccumulation nats_double              0.000   0.000
# precipaccumulation dc_bike_event            0.000   0.000
# precipaccumulation dc_pop                  -0.091  33.495
# precipaccumulation sin_day_of_year         -0.077  33.982
# precipaccumulation cos_day_of_year         -0.087  33.004
# precipintensitymax^2                       -0.158  24.006
# precipintensitymax precipprobability       -0.391  11.850
# precipintensitymax rain                    -0.394  13.045
# precipintensitymax snow                    -0.118  22.735
# precipintensitymax visibility              -0.390  12.939
# precipintensitymax windspeed               -0.365  12.632
# precipintensitymax us_holiday              -0.076  27.901
# precipintensitymax nats_single             -0.167  22.442
# precipintensitymax nats_double             -0.040  35.762
# precipintensitymax dc_bike_event           -0.055  33.156
# precipintensitymax dc_pop                  -0.399  12.624
# precipintensitymax sin_day_of_year         -0.029   7.542
# precipintensitymax cos_day_of_year          0.129  11.480
# precipprobability^2                        -0.634   2.343
# precipprobability rain                     -0.706   2.054
# precipprobability snow                     -0.176   7.770
# precipprobability visibility               -0.759   2.446
# precipprobability windspeed                -0.619   5.859
# precipprobability us_holiday               -0.091  13.982
# precipprobability nats_single              -0.294   4.934
# precipprobability nats_double              -0.050  24.682
# precipprobability dc_bike_event            -0.081  13.961
# precipprobability dc_pop                   -0.754   2.037
# precipprobability sin_day_of_year          -0.128   3.022
# precipprobability cos_day_of_year           0.022   3.027
# rain snow                                   0.000   0.000
# rain visibility                            -0.895   1.323
# rain windspeed                             -0.715   4.624
# rain dc_pop                                -0.913   1.162
# rain sin_day_of_year                       -0.082   2.051
# rain cos_day_of_year                        0.149   2.240
# snow visibility                            -0.207   5.576
# snow windspeed                             -0.179  10.658
# snow nats_single                            0.000   0.000
# snow nats_double                            0.000   0.000
# snow dc_bike_event                          0.000   0.000
# snow dc_pop                                -0.213   4.868
# snow sin_day_of_year                       -0.165   7.475
# snow cos_day_of_year                       -0.202   6.142
# visibility^2                                0.449   0.667
# visibility windspeed                       -0.198   4.619
# visibility us_holiday                      -0.170   6.275
# visibility nats_single                     -0.522   2.025
# visibility nats_double                     -0.084  12.698
# visibility dc_bike_event                   -0.114   9.375
# visibility dc_pop                           0.342   0.872
# visibility sin_day_of_year                  0.067   1.454
# visibility cos_day_of_year                 -0.033   1.575
# windspeed^2                                -0.334   7.348
# windspeed us_holiday                       -0.143  16.264
# windspeed nats_single                      -0.456   6.008
# windspeed nats_double                      -0.078  20.257
# windspeed dc_bike_event                    -0.100  17.838
# windspeed dc_pop                           -0.169   4.467
# windspeed sin_day_of_year                  -0.063   3.813
# windspeed cos_day_of_year                  -0.076   3.462
# us_holiday nats_double                      0.000   0.000
# us_holiday dc_bike_event                    0.000   0.000
# us_holiday dc_pop                          -0.172   6.021
# us_holiday sin_day_of_year                  0.037   7.935
# us_holiday cos_day_of_year                 -0.057   7.186
# nats_single nats_double                     0.000   0.000
# nats_single dc_pop                         -0.524   1.986
# nats_single sin_day_of_year                -0.007   3.058
# nats_single cos_day_of_year                 0.461   0.590
# nats_double dc_bike_event                   0.000   0.000
# nats_double dc_pop                         -0.084  12.275
# nats_double sin_day_of_year                 0.037  11.732
# nats_double cos_day_of_year                 0.073   0.073
# dc_bike_event dc_pop                       -0.114   8.960
# dc_bike_event sin_day_of_year              -0.015  11.711
# dc_bike_event cos_day_of_year               0.047  12.835
# dc_pop^2                                    0.194   1.594
# dc_pop sin_day_of_year                      0.073   1.401
# dc_pop cos_day_of_year                     -0.046   1.486

# %%
from yellowbrick.features import Rank2D

visualizer = Rank2D(features=feature_cols, algorithm='pearson')

Xt = Xtrain[feature_cols]

visualizer.fit(Xt, ytrain)                # Fit the data to the visualizer
visualizer.transform(Xt)             # Transform the data
visualizer.poof()                   # Draw/show/poof the data

# %% [markdown]
# ## 2. Model Fitting
#
# * Define functions for scoring
# * Score model using 5-fold cross-validation
# * Fit on training data and predict on test data
#   * Check residuals and prediction error graphs (yellowbrick)
# * Plot predicted values vs actuals (yhat, ytest)
# * Calculate and plot residuals (ytest - yhat)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import median_absolute_error as medae
from sklearn.metrics import explained_variance_score as evs
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
def cv_score(model, n_splits=5):
    """
    Evaluates a model by 5-fold cross-validation and prints mean and 2*stdev of scores.
    Shuffles before cross-validation but sets random_state=7 for reproducibility.
    """
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=7)
    scores = cross_val_score(model, Xtrain, ytrain, cv=kf, 
                             scoring=None, 
                             n_jobs=-1, verbose=3)
    print(scores)
    print("R^2: {:0.3f} (+/- {:0.3f})".format(scores.mean(), scores.std() * 2))
    
def score_model(model):
    """ 
    Fits a model using the training set, predicts using the test set, and then calculates 
    and reports goodness of fit metrics and alpha.
    """
    model.fit(Xtrain, ytrain)
    yhat = model.predict(Xtest)
    r2 = r2_score(ytest, yhat)
    me = mse(ytest, yhat)
    ae = mae(ytest, yhat)
    mede = medae(ytest, yhat)
    ev = evs(ytest, yhat)
    print("Results from {}: \nr2={:0.3f} \nMSE={:0.3f} \
          \nMAE={:0.3f} \nMEDAE={:0.3f} \nEVS={:0.3f} \nalpha={:0.3f}".format(model, r2, me, ae, mede, ev, model.alpha_))

# %% [markdown]
# * Specify hyperparameters
# * Instantiate model
# * Score model by 5-fold cross-validation

# %%
from sklearn.linear_model import LassoCV

# Alphas to search over
# Alpha usually settles around 5
alphas = np.logspace(-2, 1, 250)

# Instantiate model
cv = KFold(n_splits=5, shuffle=True, random_state=7)
lasso = LassoCV(alphas=alphas, n_alphas=250, fit_intercept=True, normalize=False,
                cv=cv, tol=0.0001, n_jobs=-1, verbose=1)

# Cross-validation
cv_score(lasso)
# Out:
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   40.0s remaining:   60.0s
# [0.86270107 0.85318826 0.81873184 0.87058807 0.85521213]
# R^2: 0.852 (+/- 0.036)
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   44.3s finished

# %%
from yellowbrick.regressor import AlphaSelection

visualizer = AlphaSelection(lasso)

visualizer.fit(Xtrain, ytrain)
g = visualizer.poof()
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   10.8s remaining:   16.3s
# ......[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   11.1s finished
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# Which variables were selected?

# %%
lasso.fit(Xtrain, ytrain)

# Put coefficients and variable names in df
lassodf = pd.DataFrame(lasso.coef_, index=Xtrain.columns)

# Select nonzeros
results = lassodf[(lassodf.T != 0).any()]

# Sort by magnitude
results['sorted'] = results[0].abs()
results.sort_values(by='sorted', inplace=True, ascending=False)

print("Lasso chooses {} variables".format(len(results)))
print(results)
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   13.9s remaining:   20.9s
# .....[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.2s finished
# Lasso chooses 75 variables
#                                                       0       sorted
# apparenttemperaturehigh dc_pop              2400.060578  2400.060578
# dc_pop cos_day_of_year                     -2266.026775  2266.026775
# daylight_hours cos_day_of_year              1422.029252  1422.029252
# visibility cos_day_of_year                 -1253.968185  1253.968185
# apparenttemperaturehigh sin_day_of_year     1252.190977  1252.190977
# apparenttemperaturehigh^2                  -1242.398852  1242.398852
# apparenttemperaturehigh cos_day_of_year     1121.388217  1121.388217
# humidity precipprobability                 -1003.039685  1003.039685
# visibility sin_day_of_year                  -732.413495   732.413495
# precipprobability visibility                 588.336161   588.336161
# humidity sin_day_of_year                    -522.884948   522.884948
# precipprobability^2                         -349.143799   349.143799
# dc_pop                                       339.388751   339.388751
# daylight_hours sin_day_of_year              -310.300428   310.300428
# daylight_hours dc_pop                        305.228107   305.228107
# cloudcover precipintensitymax               -292.108845   292.108845
# nats_single dc_pop                           196.837061   196.837061
# humidity us_holiday                         -187.703993   187.703993
# precipprobability snow                       183.087271   183.087271
# apparenttemperaturehigh snow                -178.005202   178.005202
# dc_pop^2                                     167.463067   167.463067
# us_holiday cos_day_of_year                  -154.409252   154.409252
# windspeed cos_day_of_year                    150.569912   150.569912
# humidity^2                                  -146.845027   146.845027
# cloudcover cos_day_of_year                   131.665034   131.665034
# cloudcover dc_bike_event                    -115.761980   115.761980
# precipaccumulation precipprobability        -108.034408   108.034408
# precipintensitymax^2                         107.377476   107.377476
# precipprobability cos_day_of_year            106.530561   106.530561
# precipprobability nats_single                102.810340   102.810340
# apparenttemperaturehigh nats_single          -86.480485    86.480485
# visibility dc_bike_event                      79.257277    79.257277
# precipintensitymax nats_double                78.427107    78.427107
# cloudcover snow                               76.939260    76.939260
# snow sin_day_of_year                         -73.689600    73.689600
# rain windspeed                               -69.644900    69.644900
# windspeed sin_day_of_year                     69.580094    69.580094
# precipprobability windspeed                   68.697937    68.697937
# nats_single sin_day_of_year                   66.840191    66.840191
# windspeed nats_single                        -58.627565    58.627565
# windspeed us_holiday                          57.943298    57.943298
# apparenttemperaturehigh precipaccumulation   -48.367158    48.367158
# snow cos_day_of_year                          44.930752    44.930752
# daylight_hours^2                             -41.608949    41.608949
# snow windspeed                                40.757314    40.757314
# precipintensitymax sin_day_of_year            39.856515    39.856515
# precipintensitymax precipprobability          37.403658    37.403658
# precipprobability nats_double                -36.926629    36.926629
# precipaccumulation us_holiday                 34.906480    34.906480
# cloudcover windspeed                         -33.709674    33.709674
# apparenttemperaturehigh windspeed            -31.659429    31.659429
# visibility dc_pop                             29.841849    29.841849
# dc_bike_event sin_day_of_year                 26.770131    26.770131
# rain sin_day_of_year                         -25.755238    25.755238
# nats_double sin_day_of_year                  -25.366417    25.366417
# cloudcover precipaccumulation                -24.790499    24.790499
# precipintensitymax us_holiday                 24.576976    24.576976
# precipintensitymax cos_day_of_year            24.442059    24.442059
# windspeed dc_bike_event                      -23.737413    23.737413
# cloudcover sin_day_of_year                    22.167026    22.167026
# nats_single cos_day_of_year                   20.574144    20.574144
# precipaccumulation cos_day_of_year            20.194005    20.194005
# precipintensitymax nats_single               -18.315577    18.315577
# windspeed nats_double                         17.280618    17.280618
# precipintensitymax dc_bike_event              16.270307    16.270307
# cloudcover rain                              -15.337889    15.337889
# humidity rain                                -12.977826    12.977826
# windspeed^2                                   -7.531933     7.531933
# us_holiday sin_day_of_year                     7.097130     7.097130
# nats_double cos_day_of_year                   -6.581264     6.581264
# precipprobability us_holiday                  -5.643396     5.643396
# apparenttemperaturehigh dc_bike_event          4.083348     4.083348
# humidity visibility                            3.411956     3.411956
# apparenttemperaturehigh cloudcover            -2.574441     2.574441
# cloudcover us_holiday                         -2.240284     2.240284
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\Sebastian\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Sebastian\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
import matplotlib.pyplot as plt
from yellowbrick.features.importances import FeatureImportances

# Create a new matplotlib figure
fig = plt.figure()
ax = fig.add_subplot()

viz = FeatureImportances(lasso, ax=ax, labels=None)
viz.fit(Xtrain, ytrain)
viz.poof()
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   13.9s remaining:   20.8s
# ..............[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.3s finished
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# What was our value of alpha?

# %%
print(lasso.alpha_)
# Out:
# 4.598864379394484

# %% [markdown]
# How does our model perform on the test data?

# %%
score_model(lasso)
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   11.7s remaining:   17.6s
# .........[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.0s finished
# Results from LassoCV(alphas=array([ 0.01   ,  0.01028, ...,  9.72639, 10.     ]),
#     copy_X=True, cv=KFold(n_splits=5, random_state=7, shuffle=True),
#     eps=0.001, fit_intercept=True, max_iter=1000, n_alphas=250, n_jobs=-1,
#     normalize=False, positive=False, precompute='auto', random_state=None,
#     selection='cyclic', tol=0.0001, verbose=1):
# r2=0.819
# MSE=1831192.482
# MAE=1031.276
# MEDAE=744.539
# EVS=0.819
# alpha=4.599
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# What do our residuals look like?

# %%
from yellowbrick.regressor import ResidualsPlot

resplot = ResidualsPlot(lasso)

resplot.fit(Xtrain, ytrain)
resplot.score(Xtest, ytest)
g = resplot.poof()
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   14.3s remaining:   21.6s
# ......[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.6s finished
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# What does our prediction error look like?

# %%
from yellowbrick.regressor import PredictionError

prederr = PredictionError(lasso)

prederr.fit(Xtrain, ytrain)
prederr.score(Xtest, ytest)
g = prederr.poof()
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   13.8s remaining:   20.8s
# ......[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   14.1s finished
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# Next, we pull out our fitted values (yhat) and actuals (ytest) to see how they compare.
#
# We also calculate our residuals by subtracting our fitted values from the actuals.

# %%
import matplotlib.pyplot as plt

lasso.fit(Xtrain, ytrain)

yhat = lasso.predict(Xtest)
error = ytest - yhat

data = pd.DataFrame({'t': range(1, len(yhat) + 1), 
                     'ytest': ytest, 
                     'yhat': yhat,
                     'error': error})

plt.plot('t', 'ytest', data=data, color='blue', linewidth=1, label='actual')
plt.plot('t', 'yhat', data=data, color='orange', marker='o', linestyle="None", label='predicted', alpha=0.5)
plt.plot('t', 'error', data=data, color='gray')
plt.legend()
plt.show()
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# .................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   12.2s remaining:   18.3s
# .................[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.8s finished
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
plt.plot('t', 'ytest', data=data, color='blue', linewidth=1, label='actual')
plt.plot('t', 'yhat', data=data, color='orange', marker='o', linestyle="None", label='predicted', alpha=0.5)
plt.legend()

# %%
plt.title('Actual minus predicted values')
plt.plot('t', 'error', data=data, color='gray')
plt.legend()

# %%
# On net, actuals minus predicted is negative
# This means our model overpredicted on average

data['error'].sum()
# Out:
# -9693.551542626356

# %%
data['abs_error'] = np.abs(error)

plt.title('Absolute value of error')
plt.plot('t', 'abs_error', data=data, color='blue')
plt.legend()

# %%
from yellowbrick.features.importances import FeatureImportances

fig = plt.figure()
ax = fig.add_subplot()

viz = FeatureImportances(lasso, ax=ax)
viz.fit(Xtrain, ytrain)
viz.poof()
# Out:
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   14.4s remaining:   21.6s
# ........................[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   15.2s finished
# C:\Users\Sebastian\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
from sklearn.externals import joblib
joblib.dump(lasso, 'lasso_total.pkl') 
# To get it out later,
# model = joblib.load('lasso_total.pkl')
# Out:
# ['lasso_total.pkl']

# %%
end_time = (time.perf_counter() - start_time)/60
print("This notebook took {:0.2f} minutes to run".format(end_time))
# Out:
# This notebook took 3.00 minutes to run
