# %% [markdown]
# # OLS regressions - baseline for Capstone analysis
# In this notebook, I perform OLS regressions using DC to DC CaBi trips as the dependent variable.

# %%
from util_functions import *
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style('darkgrid')
import statsmodels.graphics.gofplots as gofplots
# %matplotlib inline

set_env_path()
conn, cur = aws_connect()
query = """
SELECT *,
CASE day_of_week WHEN 5 THEN 1 WHEN 6 THEN 1 ELSE 0 END AS weekend_dummy
from final_db
"""
df = pd.read_sql(query, con=conn)
df.shape
# Out:
# (2750, 834)

# %% [markdown]
# ### First specification attempt - theory based

# %%
def fitOLS(equation, cov='nonrobust'):
    '''
    This function uses statsmodels.ols to estimate OLS regressions using R/patsy-style syntax.
    
    Args:
        equation (str): A patsy-style regression equation.
                        e.g. 'cabi_trips ~ apparenttemperaturehigh + daylight_hours + rain'
        cov      (str): A specific covariance matrix type. Default is 'nonrobust'. 
                        HC0-HC3 available for heteroskedasticity-robust standard errors.
    Returns:
        results: A RegressionResults object which summarizes the fit of a linear regression model.
    '''
    model = smf.ols('{}'.format(equation), df)
    results = model.fit(cov_type='{}'.format(cov), use_t=True)
    return results

# %% [markdown]
# We know that a lot of trips depend on weather, but we should be careful to avoid multicollinearity. X below contains all of the variables in question.

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
X = df[['cabi_trips', 'cabi_trips_casual', 'cabi_trips_member',
        'cabi_trips_wdc_to_wdc', 'cabi_trips_wdc_to_wdc_member',
        'cabi_trip_dur_avg_casual', 'cabi_trip_dur_avg_member',
        'cabi_trip_dist_avg_casual', 'cabi_trip_dist_avg_member',
        'cabi_bikes_avail', 'cabi_stations_wdc', 'cabi_docks_wdc',
        'cabi_dur_empty_wdc', 'cabi_dur_full_wdc', 'cabi_util_rate',
        'cabi_active_members_monthly', 'dless_trips_all', 'dless_tripdist_avg_all',
        'date', 'dc_pop', 'quarter', 'month', 'daylight_hours', 
        'apparenttemperaturehigh', 'apparenttemperaturelow',
        'apparenttemperaturehightime', 'cloudcover', 'humidity',
        'rain', 'snow', 'nats_single', 'nats_double', 
        'us_holiday', 'dc_bike_event', 'day_of_week']]
X.describe().round(0).transpose()
# Out:
#                                count      mean       std       min       25%  \
# cabi_trips                    2750.0    7166.0    3742.0       0.0    4220.0
# cabi_trips_casual             2750.0    1552.0    1519.0       0.0     424.0
# cabi_trips_member             2750.0    5614.0    2768.0       0.0    3519.0
# cabi_trips_wdc_to_wdc         2750.0    6341.0    3174.0       0.0    3882.0
# cabi_trips_wdc_to_wdc_member  2750.0    4959.0    2317.0       0.0    3252.0
# cabi_trip_dur_avg_casual      2750.0    2246.0     495.0       0.0    1983.0
# cabi_trip_dur_avg_member      2750.0     714.0      86.0       0.0     662.0
# cabi_trip_dist_avg_casual     2750.0    1748.0     149.0       0.0    1679.0
# cabi_trip_dist_avg_member     2750.0    1774.0     124.0       0.0    1720.0
# cabi_bikes_avail              2750.0    2841.0    1255.0      97.0    1658.0
# cabi_stations_wdc             2750.0     181.0      54.0      32.0     140.0
# cabi_docks_wdc                2750.0    3911.0    1140.0     678.0    3117.0
# cabi_dur_empty_wdc            2750.0  903306.0  722708.0       0.0  341980.0
# cabi_dur_full_wdc             2750.0  474381.0  360851.0       0.0  193130.0
# cabi_util_rate                2750.0       3.0       1.0       0.0       2.0
# cabi_active_members_monthly   2750.0     210.0     135.0      15.0      83.0
# dless_trips_all               2750.0      75.0     329.0       0.0       0.0
# dless_tripdist_avg_all        2750.0      79.0     316.0       0.0       0.0
# dc_pop                        2750.0  662034.0   26237.0  607733.0  640884.0
# quarter                       2750.0       3.0       1.0       1.0       1.0
# month                         2750.0       7.0       4.0       1.0       3.0
# daylight_hours                2750.0      12.0       2.0       9.0      10.0
# apparenttemperaturehigh       2750.0      64.0      21.0       2.0      50.0
# apparenttemperaturelow        2750.0      49.0      20.0     -11.0      32.0
# apparenttemperaturehightime   2750.0      15.0       2.0       7.0      15.0
# cloudcover                    2750.0       0.0       0.0       0.0       0.0
# humidity                      2750.0       1.0       0.0       0.0       1.0
# rain                          2750.0       0.0       0.0       0.0       0.0
# snow                          2750.0       0.0       0.0       0.0       0.0
# nats_single                   2750.0       0.0       0.0       0.0       0.0
# nats_double                   2750.0       0.0       0.0       0.0       0.0
# us_holiday                    2750.0       0.0       0.0       0.0       0.0
# dc_bike_event                 2750.0       0.0       0.0       0.0       0.0
# day_of_week                   2750.0       3.0       2.0       0.0       1.0
#
#                                    50%        75%        max
# cabi_trips                      6868.0    10331.0    16896.0
# cabi_trips_casual               1083.0     2192.0    10173.0
# cabi_trips_member               5586.0     7646.0    11848.0
# cabi_trips_wdc_to_wdc           6190.0     9041.0    14964.0
# cabi_trips_wdc_to_wdc_member    4982.0     6755.0     9979.0
# cabi_trip_dur_avg_casual        2257.0     2515.0     7085.0
# cabi_trip_dur_avg_member         708.0      756.0     1272.0
# cabi_trip_dist_avg_casual       1748.0     1824.0     2863.0
# cabi_trip_dist_avg_member       1796.0     1849.0     2238.0
# cabi_bikes_avail                3115.0     3900.0     4612.0
# cabi_stations_wdc                192.0      218.0      268.0
# cabi_docks_wdc                  4067.0     4666.0     5820.0
# cabi_dur_empty_wdc            757416.0  1345700.0  4059972.0
# cabi_dur_full_wdc             417741.0   691932.0  2040066.0
# cabi_util_rate                     3.0        3.0        6.0
# cabi_active_members_monthly      207.0      300.0      607.0
# dless_trips_all                    0.0        0.0     2917.0
# dless_tripdist_avg_all             0.0        0.0     3703.0
# dc_pop                        664226.0   684743.0   701239.0
# quarter                            3.0        4.0        4.0
# month                              7.0       10.0       12.0
# daylight_hours                    12.0       14.0       15.0
# apparenttemperaturehigh           66.0       82.0      114.0
# apparenttemperaturelow            51.0       66.0       90.0
# apparenttemperaturehightime       16.0       17.0       19.0
# cloudcover                         0.0        0.0        1.0
# humidity                           1.0        1.0        1.0
# rain                               0.0        1.0        1.0
# snow                               0.0        0.0        1.0
# nats_single                        0.0        0.0        1.0
# nats_double                        0.0        0.0        1.0
# us_holiday                         0.0        0.0        1.0
# dc_bike_event                      0.0        0.0        1.0
# day_of_week                        3.0        5.0        6.0

# %%
X.corr().round(3)
# Out:
#                               cabi_trips  cabi_trips_casual  \
# cabi_trips                         1.000              0.761
# cabi_trips_casual                  0.761              1.000
# cabi_trips_member                  0.934              0.480
# cabi_trips_wdc_to_wdc              0.999              0.768
# cabi_trips_wdc_to_wdc_member       0.933              0.480
# cabi_trip_dur_avg_casual           0.163              0.357
# cabi_trip_dur_avg_member           0.368              0.546
# cabi_trip_dist_avg_casual          0.142              0.154
# cabi_trip_dist_avg_member          0.495              0.284
# cabi_bikes_avail                   0.634              0.417
# cabi_stations_wdc                  0.617              0.391
# cabi_docks_wdc                     0.616              0.392
# cabi_dur_empty_wdc                 0.856              0.499
# cabi_dur_full_wdc                  0.753              0.313
# cabi_util_rate                     0.477              0.410
# cabi_active_members_monthly        0.678              0.576
# dless_trips_all                    0.127              0.022
# dless_tripdist_avg_all             0.102              0.021
# dc_pop                             0.624              0.393
# quarter                            0.119              0.078
# month                              0.112              0.063
# daylight_hours                     0.503              0.499
# apparenttemperaturehigh            0.584              0.529
# apparenttemperaturelow             0.549              0.499
# apparenttemperaturehightime        0.184              0.188
# cloudcover                        -0.429             -0.323
# humidity                          -0.001             -0.013
# rain                              -0.076             -0.084
# snow                              -0.243             -0.193
# nats_single                        0.274              0.308
# nats_double                        0.046              0.073
# us_holiday                        -0.098              0.028
# dc_bike_event                      0.052              0.078
# day_of_week                        0.044              0.048
#
#                               cabi_trips_member  cabi_trips_wdc_to_wdc  \
# cabi_trips                                0.934                  0.999
# cabi_trips_casual                         0.480                  0.768
# cabi_trips_member                         1.000                  0.929
# cabi_trips_wdc_to_wdc                     0.929                  1.000
# cabi_trips_wdc_to_wdc_member              0.998                  0.930
# cabi_trip_dur_avg_casual                  0.024                  0.170
# cabi_trip_dur_avg_member                  0.199                  0.376
# cabi_trip_dist_avg_casual                 0.107                  0.146
# cabi_trip_dist_avg_member                 0.513                  0.505
# cabi_bikes_avail                          0.628                  0.613
# cabi_stations_wdc                         0.619                  0.598
# cabi_docks_wdc                            0.617                  0.597
# cabi_dur_empty_wdc                        0.884                  0.843
# cabi_dur_full_wdc                         0.846                  0.742
# cabi_util_rate                            0.419                  0.505
# cabi_active_members_monthly               0.600                  0.682
# dless_trips_all                           0.159                  0.117
# dless_tripdist_avg_all                    0.127                  0.091
# dc_pop                                    0.628                  0.604
# quarter                                   0.119                  0.119
# month                                     0.117                  0.111
# daylight_hours                            0.406                  0.515
# apparenttemperaturehigh                   0.499                  0.595
# apparenttemperaturelow                    0.468                  0.559
# apparenttemperaturehightime               0.145                  0.191
# cloudcover                               -0.403                 -0.429
# humidity                                  0.005                 -0.005
# rain                                     -0.057                 -0.075
# snow                                     -0.222                 -0.249
# nats_single                               0.201                  0.281
# nats_double                               0.022                  0.048
# us_holiday                               -0.147                 -0.102
# dc_bike_event                             0.028                  0.052
# day_of_week                               0.033                  0.050
#
#                               cabi_trips_wdc_to_wdc_member  \
# cabi_trips                                           0.933
# cabi_trips_casual                                    0.480
# cabi_trips_member                                    0.998
# cabi_trips_wdc_to_wdc                                0.930
# cabi_trips_wdc_to_wdc_member                         1.000
# cabi_trip_dur_avg_casual                             0.026
# cabi_trip_dur_avg_member                             0.203
# cabi_trip_dist_avg_casual                            0.116
# cabi_trip_dist_avg_member                            0.528
# cabi_bikes_avail                                     0.605
# cabi_stations_wdc                                    0.599
# cabi_docks_wdc                                       0.597
# cabi_dur_empty_wdc                                   0.871
# cabi_dur_full_wdc                                    0.839
# cabi_util_rate                                       0.451
# cabi_active_members_monthly                          0.603
# dless_trips_all                                      0.149
# dless_tripdist_avg_all                               0.115
# dc_pop                                               0.607
# quarter                                              0.117
# month                                                0.115
# daylight_hours                                       0.416
# apparenttemperaturehigh                              0.509
# apparenttemperaturelow                               0.477
# apparenttemperaturehightime                          0.152
# cloudcover                                          -0.403
# humidity                                             0.000
# rain                                                -0.056
# snow                                                -0.229
# nats_single                                          0.207
# nats_double                                          0.024
# us_holiday                                          -0.154
# dc_bike_event                                        0.027
# day_of_week                                          0.039
#
#                               cabi_trip_dur_avg_casual  \
# cabi_trips                                       0.163
# cabi_trips_casual                                0.357
# cabi_trips_member                                0.024
# cabi_trips_wdc_to_wdc                            0.170
# cabi_trips_wdc_to_wdc_member                     0.026
# cabi_trip_dur_avg_casual                         1.000
# cabi_trip_dur_avg_member                         0.660
# cabi_trip_dist_avg_casual                        0.130
# cabi_trip_dist_avg_member                        0.324
# cabi_bikes_avail                                -0.156
# cabi_stations_wdc                               -0.197
# cabi_docks_wdc                                  -0.197
# cabi_dur_empty_wdc                               0.041
# cabi_dur_full_wdc                                0.016
# cabi_util_rate                                   0.381
# cabi_active_members_monthly                      0.288
# dless_trips_all                                 -0.096
# dless_tripdist_avg_all                          -0.112
# dc_pop                                          -0.175
# quarter                                          0.076
# month                                            0.069
# daylight_hours                                   0.332
# apparenttemperaturehigh                          0.427
# apparenttemperaturelow                           0.377
# apparenttemperaturehightime                      0.221
# cloudcover                                      -0.159
# humidity                                        -0.068
# rain                                            -0.034
# snow                                            -0.234
# nats_single                                      0.184
# nats_double                                      0.042
# us_holiday                                       0.094
# dc_bike_event                                    0.006
# day_of_week                                      0.021
#
#                               cabi_trip_dur_avg_member  \
# cabi_trips                                       0.368
# cabi_trips_casual                                0.546
# cabi_trips_member                                0.199
# cabi_trips_wdc_to_wdc                            0.376
# cabi_trips_wdc_to_wdc_member                     0.203
# cabi_trip_dur_avg_casual                         0.660
# cabi_trip_dur_avg_member                         1.000
# cabi_trip_dist_avg_casual                        0.291
# cabi_trip_dist_avg_member                        0.583
# cabi_bikes_avail                                -0.059
# cabi_stations_wdc                               -0.099
# cabi_docks_wdc                                  -0.097
# cabi_dur_empty_wdc                               0.239
# cabi_dur_full_wdc                                0.203
# cabi_util_rate                                   0.546
# cabi_active_members_monthly                      0.451
# dless_trips_all                                 -0.001
# dless_tripdist_avg_all                          -0.007
# dc_pop                                          -0.079
# quarter                                          0.102
# month                                            0.098
# daylight_hours                                   0.472
# apparenttemperaturehigh                          0.558
# apparenttemperaturelow                           0.506
# apparenttemperaturehightime                      0.233
# cloudcover                                      -0.172
# humidity                                        -0.009
# rain                                            -0.036
# snow                                            -0.247
# nats_single                                      0.271
# nats_double                                      0.056
# us_holiday                                       0.044
# dc_bike_event                                    0.028
# day_of_week                                      0.036
#
#                               cabi_trip_dist_avg_casual  \
# cabi_trips                                        0.142
# cabi_trips_casual                                 0.154
# cabi_trips_member                                 0.107
# cabi_trips_wdc_to_wdc                             0.146
# cabi_trips_wdc_to_wdc_member                      0.116
# cabi_trip_dur_avg_casual                          0.130
# cabi_trip_dur_avg_member                          0.291
# cabi_trip_dist_avg_casual                         1.000
# cabi_trip_dist_avg_member                         0.401
# cabi_bikes_avail                                 -0.035
# cabi_stations_wdc                                -0.036
# cabi_docks_wdc                                   -0.035
# cabi_dur_empty_wdc                                0.069
# cabi_dur_full_wdc                                 0.064
# cabi_util_rate                                    0.204
# cabi_active_members_monthly                       0.030
# dless_trips_all                                   0.003
# dless_tripdist_avg_all                           -0.020
# dc_pop                                           -0.045
# quarter                                           0.037
# month                                             0.042
# daylight_hours                                   -0.001
# apparenttemperaturehigh                           0.015
# apparenttemperaturelow                           -0.002
# apparenttemperaturehightime                       0.004
# cloudcover                                       -0.008
# humidity                                         -0.064
# rain                                             -0.062
# snow                                             -0.050
# nats_single                                       0.013
# nats_double                                       0.018
# us_holiday                                       -0.052
# dc_bike_event                                     0.018
# day_of_week                                       0.112
#
#                               cabi_trip_dist_avg_member  cabi_bikes_avail  \
# cabi_trips                                        0.495             0.634
# cabi_trips_casual                                 0.284             0.417
# cabi_trips_member                                 0.513             0.628
# cabi_trips_wdc_to_wdc                             0.505             0.613
# cabi_trips_wdc_to_wdc_member                      0.528             0.605
# cabi_trip_dur_avg_casual                          0.324            -0.156
# cabi_trip_dur_avg_member                          0.583            -0.059
# cabi_trip_dist_avg_casual                         0.401            -0.035
# cabi_trip_dist_avg_member                         1.000            -0.053
# cabi_bikes_avail                                 -0.053             1.000
# cabi_stations_wdc                                -0.073             0.987
# cabi_docks_wdc                                   -0.070             0.983
# cabi_dur_empty_wdc                                0.434             0.622
# cabi_dur_full_wdc                                 0.481             0.503
# cabi_util_rate                                    0.673            -0.286
# cabi_active_members_monthly                       0.452             0.283
# dless_trips_all                                  -0.074             0.295
# dless_tripdist_avg_all                           -0.120             0.323
# dc_pop                                           -0.056             0.985
# quarter                                           0.099            -0.016
# month                                             0.099            -0.012
# daylight_hours                                    0.443             0.038
# apparenttemperaturehigh                           0.541             0.024
# apparenttemperaturelow                            0.504             0.022
# apparenttemperaturehightime                       0.187            -0.063
# cloudcover                                       -0.110            -0.351
# humidity                                          0.014             0.045
# rain                                              0.047            -0.051
# snow                                             -0.352             0.004
# nats_single                                       0.211             0.011
# nats_double                                       0.026             0.004
# us_holiday                                       -0.107            -0.005
# dc_bike_event                                    -0.005             0.072
# day_of_week                                      -0.003             0.002
#
#                               cabi_stations_wdc  cabi_docks_wdc  \
# cabi_trips                                0.617           0.616
# cabi_trips_casual                         0.391           0.392
# cabi_trips_member                         0.619           0.617
# cabi_trips_wdc_to_wdc                     0.598           0.597
# cabi_trips_wdc_to_wdc_member              0.599           0.597
# cabi_trip_dur_avg_casual                 -0.197          -0.197
# cabi_trip_dur_avg_member                 -0.099          -0.097
# cabi_trip_dist_avg_casual                -0.036          -0.035
# cabi_trip_dist_avg_member                -0.073          -0.070
# cabi_bikes_avail                          0.987           0.983
# cabi_stations_wdc                         1.000           0.999
# cabi_docks_wdc                            0.999           1.000
# cabi_dur_empty_wdc                        0.608           0.611
# cabi_dur_full_wdc                         0.494           0.497
# cabi_util_rate                           -0.277          -0.268
# cabi_active_members_monthly               0.241           0.240
# dless_trips_all                           0.357           0.369
# dless_tripdist_avg_all                    0.390           0.403
# dc_pop                                    0.987           0.987
# quarter                                  -0.027          -0.031
# month                                    -0.022          -0.025
# daylight_hours                            0.006           0.008
# apparenttemperaturehigh                  -0.011          -0.010
# apparenttemperaturelow                   -0.012          -0.011
# apparenttemperaturehightime              -0.069          -0.069
# cloudcover                               -0.344          -0.335
# humidity                                  0.038           0.038
# rain                                     -0.058          -0.058
# snow                                      0.010           0.007
# nats_single                              -0.011          -0.012
# nats_double                               0.005           0.005
# us_holiday                               -0.004          -0.004
# dc_bike_event                             0.066           0.064
# day_of_week                               0.002           0.003
#
#                               cabi_dur_empty_wdc  cabi_dur_full_wdc  \
# cabi_trips                                 0.856              0.753
# cabi_trips_casual                          0.499              0.313
# cabi_trips_member                          0.884              0.846
# cabi_trips_wdc_to_wdc                      0.843              0.742
# cabi_trips_wdc_to_wdc_member               0.871              0.839
# cabi_trip_dur_avg_casual                   0.041              0.016
# cabi_trip_dur_avg_member                   0.239              0.203
# cabi_trip_dist_avg_casual                  0.069              0.064
# cabi_trip_dist_avg_member                  0.434              0.481
# cabi_bikes_avail                           0.622              0.503
# cabi_stations_wdc                          0.608              0.494
# cabi_docks_wdc                             0.611              0.497
# cabi_dur_empty_wdc                         1.000              0.840
# cabi_dur_full_wdc                          0.840              1.000
# cabi_util_rate                             0.323              0.355
# cabi_active_members_monthly                0.557              0.504
# dless_trips_all                            0.236              0.191
# dless_tripdist_avg_all                     0.222              0.161
# dc_pop                                     0.607              0.508
# quarter                                    0.141              0.054
# month                                      0.136              0.061
# daylight_hours                             0.389              0.361
# apparenttemperaturehigh                    0.494              0.437
# apparenttemperaturelow                     0.469              0.409
# apparenttemperaturehightime                0.122              0.105
# cloudcover                                -0.345             -0.281
# humidity                                   0.081              0.049
# rain                                      -0.047             -0.014
# snow                                      -0.168             -0.165
# nats_single                                0.193              0.179
# nats_double                                0.020              0.000
# us_holiday                                -0.105             -0.133
# dc_bike_event                              0.016              0.004
# day_of_week                               -0.030             -0.002
#
#                               cabi_util_rate  cabi_active_members_monthly  \
# cabi_trips                             0.477                        0.678
# cabi_trips_casual                      0.410                        0.576
# cabi_trips_member                      0.419                        0.600
# cabi_trips_wdc_to_wdc                  0.505                        0.682
# cabi_trips_wdc_to_wdc_member           0.451                        0.603
# cabi_trip_dur_avg_casual               0.381                        0.288
# cabi_trip_dur_avg_member               0.546                        0.451
# cabi_trip_dist_avg_casual              0.204                        0.030
# cabi_trip_dist_avg_member              0.673                        0.452
# cabi_bikes_avail                      -0.286                        0.283
# cabi_stations_wdc                     -0.277                        0.241
# cabi_docks_wdc                        -0.268                        0.240
# cabi_dur_empty_wdc                     0.323                        0.557
# cabi_dur_full_wdc                      0.355                        0.504
# cabi_util_rate                         1.000                        0.515
# cabi_active_members_monthly            0.515                        1.000
# dless_trips_all                       -0.123                       -0.110
# dless_tripdist_avg_all                -0.162                       -0.117
# dc_pop                                -0.260                        0.270
# quarter                                0.134                        0.020
# month                                  0.121                        0.024
# daylight_hours                         0.598                        0.840
# apparenttemperaturehigh                0.696                        0.735
# apparenttemperaturelow                 0.655                        0.740
# apparenttemperaturehightime            0.290                        0.203
# cloudcover                            -0.158                       -0.161
# humidity                              -0.056                        0.144
# rain                                  -0.025                        0.128
# snow                                  -0.305                       -0.209
# nats_single                            0.322                        0.389
# nats_double                            0.052                        0.058
# us_holiday                            -0.117                       -0.073
# dc_bike_event                         -0.019                        0.044
# day_of_week                            0.056                       -0.000
#
#                               dless_trips_all  dless_tripdist_avg_all  dc_pop  \
# cabi_trips                              0.127                   0.102   0.624
# cabi_trips_casual                       0.022                   0.021   0.393
# cabi_trips_member                       0.159                   0.127   0.628
# cabi_trips_wdc_to_wdc                   0.117                   0.091   0.604
# cabi_trips_wdc_to_wdc_member            0.149                   0.115   0.607
# cabi_trip_dur_avg_casual               -0.096                  -0.112  -0.175
# cabi_trip_dur_avg_member               -0.001                  -0.007  -0.079
# cabi_trip_dist_avg_casual               0.003                  -0.020  -0.045
# cabi_trip_dist_avg_member              -0.074                  -0.120  -0.056
# cabi_bikes_avail                        0.295                   0.323   0.985
# cabi_stations_wdc                       0.357                   0.390   0.987
# cabi_docks_wdc                          0.369                   0.403   0.987
# cabi_dur_empty_wdc                      0.236                   0.222   0.607
# cabi_dur_full_wdc                       0.191                   0.161   0.508
# cabi_util_rate                         -0.123                  -0.162  -0.260
# cabi_active_members_monthly            -0.110                  -0.117   0.270
# dless_trips_all                         1.000                   0.888   0.316
# dless_tripdist_avg_all                  0.888                   1.000   0.347
# dc_pop                                  0.316                   0.347   1.000
# quarter                                 0.119                   0.092  -0.034
# month                                   0.105                   0.084  -0.028
# daylight_hours                         -0.198                  -0.207   0.020
# apparenttemperaturehigh                -0.076                  -0.109   0.006
# apparenttemperaturelow                 -0.092                  -0.116   0.006
# apparenttemperaturehightime            -0.055                  -0.059  -0.068
# cloudcover                             -0.079                  -0.081  -0.332
# humidity                                0.047                   0.051   0.047
# rain                                   -0.065                  -0.081  -0.046
# snow                                   -0.010                   0.024  -0.003
# nats_single                            -0.098                  -0.088  -0.000
# nats_double                            -0.018                  -0.020   0.002
# us_holiday                              0.000                   0.018  -0.007
# dc_bike_event                           0.003                   0.030   0.069
# day_of_week                             0.009                   0.005   0.001
#
#                               quarter  month  daylight_hours  \
# cabi_trips                      0.119  0.112           0.503
# cabi_trips_casual               0.078  0.063           0.499
# cabi_trips_member               0.119  0.117           0.406
# cabi_trips_wdc_to_wdc           0.119  0.111           0.515
# cabi_trips_wdc_to_wdc_member    0.117  0.115           0.416
# cabi_trip_dur_avg_casual        0.076  0.069           0.332
# cabi_trip_dur_avg_member        0.102  0.098           0.472
# cabi_trip_dist_avg_casual       0.037  0.042          -0.001
# cabi_trip_dist_avg_member       0.099  0.099           0.443
# cabi_bikes_avail               -0.016 -0.012           0.038
# cabi_stations_wdc              -0.027 -0.022           0.006
# cabi_docks_wdc                 -0.031 -0.025           0.008
# cabi_dur_empty_wdc              0.141  0.136           0.389
# cabi_dur_full_wdc               0.054  0.061           0.361
# cabi_util_rate                  0.134  0.121           0.598
# cabi_active_members_monthly     0.020  0.024           0.840
# dless_trips_all                 0.119  0.105          -0.198
# dless_tripdist_avg_all          0.092  0.084          -0.207
# dc_pop                         -0.034 -0.028           0.020
# quarter                         1.000  0.973          -0.180
# month                           0.973  1.000          -0.173
# daylight_hours                 -0.180 -0.173           1.000
# apparenttemperaturehigh         0.249  0.238           0.739
# apparenttemperaturelow          0.267  0.258           0.739
# apparenttemperaturehightime    -0.063 -0.059           0.264
# cloudcover                     -0.055 -0.051          -0.067
# humidity                        0.219  0.214           0.079
# rain                           -0.015 -0.013           0.177
# snow                           -0.174 -0.174          -0.186
# nats_single                     0.017  0.016           0.432
# nats_double                     0.013  0.016           0.068
# us_holiday                      0.038  0.028          -0.100
# dc_bike_event                   0.006  0.015           0.047
# day_of_week                     0.000  0.002           0.001
#
#                               apparenttemperaturehigh  apparenttemperaturelow  \
# cabi_trips                                      0.584                   0.549
# cabi_trips_casual                               0.529                   0.499
# cabi_trips_member                               0.499                   0.468
# cabi_trips_wdc_to_wdc                           0.595                   0.559
# cabi_trips_wdc_to_wdc_member                    0.509                   0.477
# cabi_trip_dur_avg_casual                        0.427                   0.377
# cabi_trip_dur_avg_member                        0.558                   0.506
# cabi_trip_dist_avg_casual                       0.015                  -0.002
# cabi_trip_dist_avg_member                       0.541                   0.504
# cabi_bikes_avail                                0.024                   0.022
# cabi_stations_wdc                              -0.011                  -0.012
# cabi_docks_wdc                                 -0.010                  -0.011
# cabi_dur_empty_wdc                              0.494                   0.469
# cabi_dur_full_wdc                               0.437                   0.409
# cabi_util_rate                                  0.696                   0.655
# cabi_active_members_monthly                     0.735                   0.740
# dless_trips_all                                -0.076                  -0.092
# dless_tripdist_avg_all                         -0.109                  -0.116
# dc_pop                                          0.006                   0.006
# quarter                                         0.249                   0.267
# month                                           0.238                   0.258
# daylight_hours                                  0.739                   0.739
# apparenttemperaturehigh                         1.000                   0.937
# apparenttemperaturelow                          0.937                   1.000
# apparenttemperaturehightime                     0.235                   0.275
# cloudcover                                     -0.142                  -0.026
# humidity                                        0.266                   0.356
# rain                                            0.182                   0.192
# snow                                           -0.365                  -0.342
# nats_single                                     0.391                   0.404
# nats_double                                     0.048                   0.049
# us_holiday                                     -0.055                  -0.054
# dc_bike_event                                   0.025                   0.025
# day_of_week                                    -0.018                  -0.022
#
#                               apparenttemperaturehightime  cloudcover  \
# cabi_trips                                          0.184      -0.429
# cabi_trips_casual                                   0.188      -0.323
# cabi_trips_member                                   0.145      -0.403
# cabi_trips_wdc_to_wdc                               0.191      -0.429
# cabi_trips_wdc_to_wdc_member                        0.152      -0.403
# cabi_trip_dur_avg_casual                            0.221      -0.159
# cabi_trip_dur_avg_member                            0.233      -0.172
# cabi_trip_dist_avg_casual                           0.004      -0.008
# cabi_trip_dist_avg_member                           0.187      -0.110
# cabi_bikes_avail                                   -0.063      -0.351
# cabi_stations_wdc                                  -0.069      -0.344
# cabi_docks_wdc                                     -0.069      -0.335
# cabi_dur_empty_wdc                                  0.122      -0.345
# cabi_dur_full_wdc                                   0.105      -0.281
# cabi_util_rate                                      0.290      -0.158
# cabi_active_members_monthly                         0.203      -0.161
# dless_trips_all                                    -0.055      -0.079
# dless_tripdist_avg_all                             -0.059      -0.081
# dc_pop                                             -0.068      -0.332
# quarter                                            -0.063      -0.055
# month                                              -0.059      -0.051
# daylight_hours                                      0.264      -0.067
# apparenttemperaturehigh                             0.235      -0.142
# apparenttemperaturelow                              0.275      -0.026
# apparenttemperaturehightime                         1.000      -0.138
# cloudcover                                         -0.138       1.000
# humidity                                           -0.095       0.535
# rain                                               -0.114       0.442
# snow                                               -0.117       0.055
# nats_single                                         0.150      -0.036
# nats_double                                         0.010       0.005
# us_holiday                                         -0.016      -0.019
# dc_bike_event                                      -0.002      -0.017
# day_of_week                                        -0.041      -0.026
#
#                               humidity   rain   snow  nats_single  \
# cabi_trips                      -0.001 -0.076 -0.243        0.274
# cabi_trips_casual               -0.013 -0.084 -0.193        0.308
# cabi_trips_member                0.005 -0.057 -0.222        0.201
# cabi_trips_wdc_to_wdc           -0.005 -0.075 -0.249        0.281
# cabi_trips_wdc_to_wdc_member     0.000 -0.056 -0.229        0.207
# cabi_trip_dur_avg_casual        -0.068 -0.034 -0.234        0.184
# cabi_trip_dur_avg_member        -0.009 -0.036 -0.247        0.271
# cabi_trip_dist_avg_casual       -0.064 -0.062 -0.050        0.013
# cabi_trip_dist_avg_member        0.014  0.047 -0.352        0.211
# cabi_bikes_avail                 0.045 -0.051  0.004        0.011
# cabi_stations_wdc                0.038 -0.058  0.010       -0.011
# cabi_docks_wdc                   0.038 -0.058  0.007       -0.012
# cabi_dur_empty_wdc               0.081 -0.047 -0.168        0.193
# cabi_dur_full_wdc                0.049 -0.014 -0.165        0.179
# cabi_util_rate                  -0.056 -0.025 -0.305        0.322
# cabi_active_members_monthly      0.144  0.128 -0.209        0.389
# dless_trips_all                  0.047 -0.065 -0.010       -0.098
# dless_tripdist_avg_all           0.051 -0.081  0.024       -0.088
# dc_pop                           0.047 -0.046 -0.003       -0.000
# quarter                          0.219 -0.015 -0.174        0.017
# month                            0.214 -0.013 -0.174        0.016
# daylight_hours                   0.079  0.177 -0.186        0.432
# apparenttemperaturehigh          0.266  0.182 -0.365        0.391
# apparenttemperaturelow           0.356  0.192 -0.342        0.404
# apparenttemperaturehightime     -0.095 -0.114 -0.117        0.150
# cloudcover                       0.535  0.442  0.055       -0.036
# humidity                         1.000  0.457 -0.035        0.053
# rain                             0.457  1.000 -0.187        0.080
# snow                            -0.035 -0.187  1.000       -0.102
# nats_single                      0.053  0.080 -0.102        1.000
# nats_double                      0.015  0.031 -0.016       -0.039
# us_holiday                       0.005 -0.038  0.006       -0.010
# dc_bike_event                    0.025  0.024 -0.019        0.003
# day_of_week                     -0.023 -0.032  0.014        0.028
#
#                               nats_double  us_holiday  dc_bike_event  \
# cabi_trips                          0.046      -0.098          0.052
# cabi_trips_casual                   0.073       0.028          0.078
# cabi_trips_member                   0.022      -0.147          0.028
# cabi_trips_wdc_to_wdc               0.048      -0.102          0.052
# cabi_trips_wdc_to_wdc_member        0.024      -0.154          0.027
# cabi_trip_dur_avg_casual            0.042       0.094          0.006
# cabi_trip_dur_avg_member            0.056       0.044          0.028
# cabi_trip_dist_avg_casual           0.018      -0.052          0.018
# cabi_trip_dist_avg_member           0.026      -0.107         -0.005
# cabi_bikes_avail                    0.004      -0.005          0.072
# cabi_stations_wdc                   0.005      -0.004          0.066
# cabi_docks_wdc                      0.005      -0.004          0.064
# cabi_dur_empty_wdc                  0.020      -0.105          0.016
# cabi_dur_full_wdc                   0.000      -0.133          0.004
# cabi_util_rate                      0.052      -0.117         -0.019
# cabi_active_members_monthly         0.058      -0.073          0.044
# dless_trips_all                    -0.018       0.000          0.003
# dless_tripdist_avg_all             -0.020       0.018          0.030
# dc_pop                              0.002      -0.007          0.069
# quarter                             0.013       0.038          0.006
# month                               0.016       0.028          0.015
# daylight_hours                      0.068      -0.100          0.047
# apparenttemperaturehigh             0.048      -0.055          0.025
# apparenttemperaturelow              0.049      -0.054          0.025
# apparenttemperaturehightime         0.010      -0.016         -0.002
# cloudcover                          0.005      -0.019         -0.017
# humidity                            0.015       0.005          0.025
# rain                                0.031      -0.038          0.024
# snow                               -0.016       0.006         -0.019
# nats_single                        -0.039      -0.010          0.003
# nats_double                         1.000      -0.014         -0.007
# us_holiday                         -0.014       1.000         -0.017
# dc_bike_event                      -0.007      -0.017          1.000
# day_of_week                        -0.016      -0.076          0.053
#
#                               day_of_week
# cabi_trips                          0.044
# cabi_trips_casual                   0.048
# cabi_trips_member                   0.033
# cabi_trips_wdc_to_wdc               0.050
# cabi_trips_wdc_to_wdc_member        0.039
# cabi_trip_dur_avg_casual            0.021
# cabi_trip_dur_avg_member            0.036
# cabi_trip_dist_avg_casual           0.112
# cabi_trip_dist_avg_member          -0.003
# cabi_bikes_avail                    0.002
# cabi_stations_wdc                   0.002
# cabi_docks_wdc                      0.003
# cabi_dur_empty_wdc                 -0.030
# cabi_dur_full_wdc                  -0.002
# cabi_util_rate                      0.056
# cabi_active_members_monthly        -0.000
# dless_trips_all                     0.009
# dless_tripdist_avg_all              0.005
# dc_pop                              0.001
# quarter                             0.000
# month                               0.002
# daylight_hours                      0.001
# apparenttemperaturehigh            -0.018
# apparenttemperaturelow             -0.022
# apparenttemperaturehightime        -0.041
# cloudcover                         -0.026
# humidity                           -0.023
# rain                               -0.032
# snow                                0.014
# nats_single                         0.028
# nats_double                        -0.016
# us_holiday                         -0.076
# dc_bike_event                       0.053
# day_of_week                         1.000

# %% [markdown]
# From here, we can pare down the variables further.
# We are mainly interested in cabi_trips_wdc_to_wdc, so we can drop a lot of CaBi variables that are highly correlated with our dependent variable.
# dc_pop is highly correlated with CaBi bikes, stations, and docks, as well as year.

# %%
#corr = X.corr()
#sns.heatmap(corr)
X0 = X[['cabi_trips_wdc_to_wdc', 'cabi_dur_empty_wdc', 'cabi_dur_full_wdc', 
        'cabi_util_rate', 'cabi_active_members_monthly', 'dless_trips_all',
        'dc_pop', 'daylight_hours', 'apparenttemperaturehigh', 'cloudcover']]
print(X0.corr().round(3))
# Out:
#                              cabi_trips_wdc_to_wdc  cabi_dur_empty_wdc  \
# cabi_trips_wdc_to_wdc                        1.000               0.843
# cabi_dur_empty_wdc                           0.843               1.000
# cabi_dur_full_wdc                            0.742               0.840
# cabi_util_rate                               0.505               0.323
# cabi_active_members_monthly                  0.682               0.557
# dless_trips_all                              0.117               0.236
# dc_pop                                       0.604               0.607
# daylight_hours                               0.515               0.389
# apparenttemperaturehigh                      0.595               0.494
# cloudcover                                  -0.429              -0.345
#
#                              cabi_dur_full_wdc  cabi_util_rate  \
# cabi_trips_wdc_to_wdc                    0.742           0.505
# cabi_dur_empty_wdc                       0.840           0.323
# cabi_dur_full_wdc                        1.000           0.355
# cabi_util_rate                           0.355           1.000
# cabi_active_members_monthly              0.504           0.515
# dless_trips_all                          0.191          -0.123
# dc_pop                                   0.508          -0.260
# daylight_hours                           0.361           0.598
# apparenttemperaturehigh                  0.437           0.696
# cloudcover                              -0.281          -0.158
#
#                              cabi_active_members_monthly  dless_trips_all  \
# cabi_trips_wdc_to_wdc                              0.682            0.117
# cabi_dur_empty_wdc                                 0.557            0.236
# cabi_dur_full_wdc                                  0.504            0.191
# cabi_util_rate                                     0.515           -0.123
# cabi_active_members_monthly                        1.000           -0.110
# dless_trips_all                                   -0.110            1.000
# dc_pop                                             0.270            0.316
# daylight_hours                                     0.840           -0.198
# apparenttemperaturehigh                            0.735           -0.076
# cloudcover                                        -0.161           -0.079
#
#                              dc_pop  daylight_hours  apparenttemperaturehigh  \
# cabi_trips_wdc_to_wdc         0.604           0.515                    0.595
# cabi_dur_empty_wdc            0.607           0.389                    0.494
# cabi_dur_full_wdc             0.508           0.361                    0.437
# cabi_util_rate               -0.260           0.598                    0.696
# cabi_active_members_monthly   0.270           0.840                    0.735
# dless_trips_all               0.316          -0.198                   -0.076
# dc_pop                        1.000           0.020                    0.006
# daylight_hours                0.020           1.000                    0.739
# apparenttemperaturehigh       0.006           0.739                    1.000
# cloudcover                   -0.332          -0.067                   -0.142
#
#                              cloudcover
# cabi_trips_wdc_to_wdc            -0.429
# cabi_dur_empty_wdc               -0.345
# cabi_dur_full_wdc                -0.281
# cabi_util_rate                   -0.158
# cabi_active_members_monthly      -0.161
# dless_trips_all                  -0.079
# dc_pop                           -0.332
# daylight_hours                   -0.067
# apparenttemperaturehigh          -0.142
# cloudcover                        1.000

# %% [markdown]
# Next I drop some correlated X variables and run the regression.
#
# After expanding the specification, day of week didn't reflect the data so I dropped it.
#
# Utilization rate is highly correlated with trips, but what does it mean again? (Question for Mark or Noah)

# %%
results = fitOLS('cabi_trips_wdc_to_wdc ~ cabi_dur_empty_wdc + '
                 'cabi_dur_full_wdc + '
                 'cabi_active_members_monthly + dc_pop + '
                 'apparenttemperaturehigh*snow + '
                 'rain + cloudcover + nats_single + '
                 'nats_double + us_holiday', cov='HC0')
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     cabi_trips_wdc_to_wdc   R-squared:                       0.843
# Model:                               OLS   Adj. R-squared:                  0.843
# Method:                    Least Squares   F-statistic:                     1452.
# Date:                   Sun, 06 May 2018   Prob (F-statistic):               0.00
# Time:                           15:00:18   Log-Likelihood:                -23525.
# No. Observations:                   2750   AIC:                         4.708e+04
# Df Residuals:                       2737   BIC:                         4.715e+04
# Df Model:                             12
# Covariance Type:                     HC0
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                    -1.869e+04    936.571    -19.959      0.000   -2.05e+04   -1.69e+04
# cabi_dur_empty_wdc               0.0016   9.68e-05     16.040      0.000       0.001       0.002
# cabi_dur_full_wdc                0.0007      0.000      4.926      0.000       0.000       0.001
# cabi_active_members_monthly      4.3247      0.310     13.938      0.000       3.716       4.933
# dc_pop                           0.0318      0.001     22.878      0.000       0.029       0.035
# apparenttemperaturehigh         31.4637      2.254     13.959      0.000      27.044      35.884
# snow                         -1480.2451    359.964     -4.112      0.000   -2186.073    -774.417
# apparenttemperaturehigh:snow    14.2000     13.138      1.081      0.280     -11.562      39.962
# rain                          -505.7973     56.816     -8.902      0.000    -617.204    -394.391
# cloudcover                   -1302.8329    115.123    -11.317      0.000   -1528.569   -1077.097
# nats_single                    349.6729     72.743      4.807      0.000     207.036     492.310
# nats_double                    914.3988    241.728      3.783      0.000     440.410    1388.388
# us_holiday                    -579.4341    155.620     -3.723      0.000    -884.579    -274.289
# ==============================================================================
# Omnibus:                      100.022   Durbin-Watson:                   0.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              289.019
# Skew:                           0.021   Prob(JB):                     1.74e-63
# Kurtosis:                       4.588   Cond. No.                     5.44e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The condition number is large, 5.44e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Our Rsquared is 0.84 which is pretty great. Everything except for the temperature/snow interaction term is statistically significant, which implies that the effect of snow is the same at all levels of apparenttemperaturehigh.
#
# cabi_dur_empty and full are statistically significant, but their coefficients are so small they aren't really worth considering. In the case of the full variable, 0 is in the 95% CI.
#
# The positive coefficients on monthly active members and DC population make intuitive sense. More members and more people means more bike rides.
#
# The weather variables also make sense. Snowy, cloudy, rainy, and cold days are unpleasant for biking.
#
# The Nats related variable coefficients show that Nationals games are a huge driver of CaBi use, but the US holiday coefficient is counterintuitive and statistically significant.

# %%
'''Homoskedasticity is when the variance/scatter/spread of the residuals is 
constant for all values of the fitted values. It is an assumption under OLS.

Heteroskedasticity is when the variance of the residuals changes as the fitted values change.
If not addressed, it can lead to biased estimators.
If our residuals were heteroskedastic, we would expect a scatter plot to form a funnel shape,
and a regression line to have a slope.
'''

# Regplot fits a regression line to a scatterplot
plt.title('Residuals vs Fitted Values')
sns.regplot(results.fittedvalues, results.resid)
plt.xlabel('Y-hat')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# It doesn't look like there's heteroskedasticity, and the regression line is flat. However I think given our sample size and the significance of our variables, it couldn't hurt to specify heteroskedasticity-robust standard errors (the cov=HC0 argument in fitOLS).
#
# In practice I rarely see standard errors that aren't robust to either heteroskedasticity or clustering. (If we wanted to cluster, we would have to choose variables to cluster on, and I haven't looked into that for our data).

# %%
'''Normality of the residuals with mean 0 is another assumption under OLS.
If residuals are nonnormal and not approximately centered at 0, the model is probably misspecified.
The first chart is a kernel density estimation and the second is a Q-Q plot.

Q-Q plots compare two datasets to see whether or not they come from the same distribution.
If they do, the points should form a straight line.
Here, we have a Normal Q-Q plot, where our residuals are being compared against a normal distribution.
'''

# How are our residuals distributed?
plt.title('Density Plot of Residuals')
sns.kdeplot(results.resid)
plt.show()

# How close are our residuals to normal?
fig = gofplots.qqplot(results.resid, line='s')
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# The residuals appear to be approximately centered around 0.
#
# The third chart shows that our residuals are close to normal, but at the extreme ends of our distribution we get farther from a normal distribution.
